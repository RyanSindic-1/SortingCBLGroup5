# %% [markdown]
# PosiSorterSystem:
# -

# %% [markdown]
# Import packages:

# %%
import pandas as pd
from datetime import timedelta
import random

# %% [markdown]
# System parameters:

# %%
base_time       =   4.5
delay_small     =   0
delay_medium    =   1  
delay_large     =   2

# %% [markdown]
# Parcel information:

# %%
class Parcel:
    def __init__(self, parcel_id, arrival_time, length, width, height, weight, feasible_outfeeds):
        self.id = parcel_id                 #Stores parcel number
        self.arrival_time = arrival_time    #Stores arrival time
        self.length = length                #Stores length
        self.width = width                  #Stores width
        self.height = height                #Stores height
        self.weight = weight                #Stores weight
        self.feasible_outfeeds = feasible_outfeeds  #Stores the possible outfeeds
        self.sorted = False                 #Checks if a package gets sorted 
        self.recirculated = False           #Counts if a package gets recirculated 
        self.travel_time = None             #Time it takes to get from the scanner to the outfeed
        self.outfeed_entry_time = None      #Time it takes to get for a parcel to get to the outfeed
        self.removal_time = None            #Time it takes for a parcel to get removed from the outfeed
        self.time_in_system = None          #Total time the parcel spends in the system, so travel time + time in outfeed
        self.orientation_length = 0.0
    
    def effective_length(self):         #Determines in which way the packages go into the outfeed
          if self.orientation == 'sequential':     
            return self.width
          elif self.orientation == 'parallel':
            return self.length
        
    def get_volume(self):               #Calculates volume of the packages 
        return self.length * self.width * self.height
    
def compute_outfeed_time(parcel):       #Determines the amount of time it costs to get unloaded from the outfeeed
    volume = parcel.get_volume()        #Get the volume of parcels and catergorize it
    if volume < 0.303:
        volume_delay = delay_small
    elif volume < 0.375:
        volume_delay = delay_medium
    else:
        volume_delay = delay_large

    weight = parcel.weight              #Get the weight of parcels and catergorize it
    if weight < 2826:
        weight_delay = delay_small
    elif weight < 3817:
        weight_delay = delay_medium
    else:
        weight_delay = delay_large

    return base_time + volume_delay + weight_delay

# %% [markdown]
# Outfeed:

# %%
class Outfeed:
    def __init__(self, max_length=3.0):
        self.max_length = max_length            # Maximum lenght of the outfeed
        self.current_parcels = []               # Stores the occupied length of the outfeed 
        self.current_length = 0.0               # Current length set to 0 at start
        self.time_until_next_discharge = 0.0    # Current waiting time, before package gets unloaded, set to 0 at start

    def can_accept(self, parcel):               # Determines if package can be execpted in a outfeed
        fits = self.current_length + parcel.orientation_length <= self.max_length
        print(f"[DEBUG] Parcel {parcel.id} → needed: {parcel.orientation_length:.2f}, used: {self.current_length:.2f}, fits: {fits}")
        return fits

    def add_parcel(self, parcel):                                               # Adds parcel at certain outfeed
        self.current_parcels.append((parcel, compute_outfeed_time(parcel)))     
        self.current_length += parcel.orientation_length
        if len(self.current_parcels) == 1:
            self.time_until_next_discharge = self.current_parcels[0][1]         # Discharge timer for the parcel    

    def update(self, time_step, system_time):  # Keeping track of all timings in the system      
        if self.current_parcels:
            self.time_until_next_discharge -= time_step
            if self.time_until_next_discharge <= 0:
                parcel, _ = self.current_parcels.pop(0)
                self.current_length -= parcel.orientation_length       
                parcel.removal_time = system_time                   # Time in outfeed
                parcel.time_in_system = parcel.travel_time + (parcel.removal_time - parcel.outfeed_entry_time) # Time parcel spend in system
                print(f"Parcel {parcel.id} removed from outfeed"
                    f"(total system time: {parcel.time_in_system.total_seconds():.2f} s)")
                if self.current_parcels:
                    self.time_until_next_discharge = self.current_parcels[0][1] # Timer for the next parcel in line

# %% [markdown]
# The PosiSorterSystem with the algorithm:

# %%
class PosiSorterSystem:
    def __init__(self, layout_df, num_outfeeds, sorting_method, outfeed_distances, time_step):                # Collects all data/variables of the PosiSorter
        self.belt_speed = layout_df.loc[layout_df['Layout property'] == 'Belt Speed', 'Value'].values[0]  # Belt speed  
        self.num_outfeeds = num_outfeeds                       #Amount of outfeeds
        self.outfeeds = [Outfeed(max_length=3.0) for _ in range(self.num_outfeeds)] #Outfeed information
        self.recirculation_belt = []                # Stores recirculated packages
        self.processed_parcels = []                 # Tracks all parcels that go into the system
        self.sorting_method = sorting_method        # Sorting orientation
        self.outfeed_distances = outfeed_distances  # Distances to outfeeds
        self.time_step = time_step                  # Time step
    
    def calculate_travel_time(self, parcel, outfeed_index):     # Travel time calculation
        distance = self.outfeed_distances[outfeed_index]        # Distance to be travelled
        travel_seconds = distance / self.belt_speed             # Time takes to travel
        parcel.travel_time = timedelta(seconds=travel_seconds)  # Store the time it takes to travel 
     
    def set_parcel_timing(self, parcel, outfeed_index):         # Parcel timings
        parcel.outfeed_entry_time = self.current_time           # Record time parcel enters outfeed
        self.calculate_travel_time(parcel, outfeed_index)       # Calculate travel time to outfeed
        parcel.sorted = True                                     
 
    def sort_parcel(self, parcel):                              # Sorting the parcels (ALGORITHM)
        parcel.orientation = self.sorting_method                # Set orientation based on sorting method
        parcel.orientation_length = parcel.effective_length()   # Calculate effective lenght based on orientation
 
        for outfeed_index in parcel.feasible_outfeeds:          # The algorithm, to assign parcels to a proper outfeed
            outfeed = self.outfeeds[outfeed_index]              # Check if parcel can be accepted by outfeed
            if outfeed.can_accept(parcel):                      # If can be accepted, add parcel to outgeed
                outfeed.add_parcel(parcel)
                self.set_parcel_timing(parcel, outfeed_index)   #Set the parcel's timing information
                print((f"Parcel {parcel.id} sorted to outfeed {outfeed_index}"
                    f"(travel time: {parcel.travel_time.total_seconds():.2f} seconds)"))
                return   
        
        parcel.recirculated = True                              # If no outfeed can accept the parcel, it is recirculated
        self.recirculation_belt.append(parcel)                  
        print(f"Parcel {parcel.id} could not be sorted and was recirculated.")

    def remove_from_outfeeds(self, time_step):                  # Update each outfeed with the current time and timestep
        for outfeed in self.outfeeds:
            outfeed.update(time_step, self.current_time)

    def run_simulation(self, parcels):                              # Run the simulation
        current_time = parcels[0].arrival_time                      # Set current time
        self.current_time = current_time                         
        end_time = parcels[-1].arrival_time + timedelta(seconds=30) # Buffer to make sure all packages are sorted
        parcel_index = 0                                            # To track next parcel that must be processed

        while current_time <= end_time:
            print(f"\n--- Time: {current_time.time()} ---")

            # Check for arrivals
            while parcel_index < len(parcels) and parcels[parcel_index].arrival_time <= current_time:
                parcel = parcels[parcel_index]
                parcel_index += 1
                self.processed_parcels.append(parcel)
                print(f"Parcel {parcel.id} arrived – feasible outfeeds: {parcel.feasible_outfeeds}")
                self.sort_parcel(parcel)

            self.remove_from_outfeeds(self.time_step)
            current_time += timedelta(seconds = self.time_step)

        self.print_summary()  # Print summary                                  

    def print_summary(self):                                        # Get summary of simulation
        total = len(self.processed_parcels)                         # Get total length
        sorted_count = sum(p.sorted for p in self.processed_parcels)# Get count of amount of packages that are sorted
        recirculated_count = sum(p.recirculated for p in self.processed_parcels) # Get count of amount of packages that are recirculated
        total_time = [p.time_in_system for p in self.processed_parcels if p.time_in_system is not None] # Calculate the total time spent in the system for all parcels that were sorted
        if total_time:  # Calculate the average time spent in the system for all parcels that were sorted
            avg_total_time = sum(t.total_seconds() for t in total_time) / len(total_time)
        print("\n--- Simulation Summary ---") # Print everything 
        print(f"Total parcels processed: {total}")
        print(f"Parcels sorted: {sorted_count}")
        print(f"Parcels recirculated: {recirculated_count}")
        print(f"Sorting success rate: {sorted_count / total:.2%}")
        print(f"Average total system time per parcel: {avg_total_time:.2f} seconds")
        if hasattr(self, 'drop_info'):
           print("\n--- Removed Parcels ---")
           print(f"Initial amount of parcels: {self.drop_info['initial']}")
           print(f"Removed due to NaNs: {self.drop_info['na_dropped']}")
           print(f"Removed due to extreme outliers (data entry errors): {self.drop_info['outliers_dropped']}")
           print(f"Removed due to no feasible outfeeds: {self.drop_info['no_outfeeds_dropped']}")
           print(f"Removed due to non-chronological arrival times (scanning error): {self.drop_info.get('non_chrono_dropped', 0)}")
           print(f"Total parcels removed before processing: {self.drop_info['total_dropped']}")
        return

# %% [markdown]
# Excel data cleaning and loading:

# %%
def drop_non_chronological_arrivals(df):                  # Remove rows with non-chronological arrival times
    valid_times = []
    last_time = pd.Timestamp.min                          # Initialize with the earliest possible timestamp

    for i, time in enumerate(df["Arrival Time"]):         # Loop through each arrival time in the DataFrame
        if time >= last_time:
            valid_times.append(True)                      # If not chronogica, append
            last_time = time
        else:
            valid_times.append(False)                     # If not chronogical, don't append

    return df[valid_times].reset_index(drop=True)

def remove_outliers_iqr(df, columns):                       # Remove outliers from colums using IQR
    for col in columns:                                     
        Q1 = df[col].quantile(0.25)                         # First quartile
        Q3 = df[col].quantile(0.75)                         # Last quartile
        IQR = Q3 - Q1                                       # Interquertile range
        lower_bound = Q1 - 2 * IQR                          # Lower bound for outlier detection 
        upper_bound = Q3 + 2 * IQR                          # Upper bound for outlier detection 
        df = df[df[col].between(lower_bound, upper_bound)]  # Keep only rows that are in bound
    return df


def drop_rows_without_true_outfeed(df, prefix="Outfeed"):               # Removes columns that have no possible outfeed
    outfeed_cols = [col for col in df.columns if col.startswith(prefix)]# Get all columns
    if not outfeed_cols:                                                # Remove columns that have no outfeed
        return df        
    mask = df[outfeed_cols].any(axis=1)                                 # Store columns with outfeed                    
    return df[mask]                                                     


def clean_parcel_data(parcels_df):                              # Cleans the data
    drop_info = {}                                              # Store removed rows
    drop_info['initial'] = initial_count = len(parcels_df)      # Initialize count
 
    parcels_df = parcels_df.dropna().reset_index(drop=True)     # Remove rows with NaNs
    after_na = len(parcels_df) 
    drop_info['na_dropped'] = initial_count - after_na          # Track amount of rows dropped due to NaNs

    before_outliers = len(parcels_df)                                           # Remove rows with outliers
    parcels_df = remove_outliers_iqr(parcels_df, ["Length", "Width", "Height"])
    after_outliers = len(parcels_df)
    drop_info['outliers_dropped'] = before_outliers - after_outliers            # Track amount of rows dropped due to outlying values
 
    before_outfeeds = len(parcels_df)                                           # Remove rows with no feasible outfeeds
    parcels_df = drop_rows_without_true_outfeed(parcels_df)                      
    after_outfeeds = len(parcels_df) 
    drop_info['no_outfeeds_dropped'] = before_outfeeds - after_outfeeds         # Track amount of rows dropped due to no feasible outfeeds
 
    before_chrono = len(parcels_df)                                             # Remove rows with non-chronological arrival times
    parcels_df = drop_non_chronological_arrivals(parcels_df)
    after_chrono = len(parcels_df)
    drop_info['non_chrono_dropped'] = before_chrono - after_chrono              # Track amount of rows dropped due to no non-chronological arrival time
 

    drop_info['total_dropped'] = drop_info['na_dropped'] + drop_info['outliers_dropped'] + drop_info['no_outfeeds_dropped'] + drop_info['non_chrono_dropped']

    return parcels_df, drop_info

def load_parcels_from_clean_df(df):                             # Load the data from the excel sheet 
    parcels = []                                                # Store parcel information
    for _, row in df.iterrows():                                 
        parcel_id = int(row['Parcel Number'])                   # Parcel number
        arrival_time = pd.to_datetime(row['Arrival Time'])      # Arrival time package
        length = float(row['Length'])                           # Lenght of package
        width = float(row['Width'])                             # Width of package
        height = float(row['Height'])                           # Height of package
        weight = float(row['Weight'])                           # Weight of package
        feasible_outfeeds = [i for i in range(15) if row.get(f'Outfeed {i+1}', False)] # Feasible outfeeds
        parcels.append(Parcel(parcel_id, arrival_time, length, width, height, weight, feasible_outfeeds))
    return sorted(parcels, key=lambda p: p.arrival_time)

# %% [markdown]
# Main:

# %%
def main():
    xls = pd.ExcelFile("PosiSorterData2.xlsx")              # Load excel sheet with parcel data
    parcels_df = xls.parse('Parcels')                       # Gets Parcels sheet of Excel file
    layout_df = xls.parse('Layout')                         # Gets Layout sheet of Excel file
 
    parcels_df, drop_info = clean_parcel_data(parcels_df)   # Clear the data
 
    parcels = load_parcels_from_clean_df(parcels_df)        # Configurate the clean data into a list with parcel objects
    
    # Code parameters
    sorting_method = 'sequential'                 # Choose sorting method: 'parallel' or 'sequential'
    num_outfeeds = 15                            # Number of outfeeds 
    time_step = 0.1                             # Time step

    # Calculate outfeed distances
    outfeed_distances = {i: 5.5 + i * 2.5 for i in range(num_outfeeds)}
    # Gives all necessery information to PosiSorterSystem
    system = PosiSorterSystem(layout_df, sorting_method = sorting_method, num_outfeeds = num_outfeeds, outfeed_distances = outfeed_distances, time_step = time_step)
    system.drop_info = drop_info    # Get information for the removed parcels
    system.run_simulation(parcels)  # Runs the simulation    

# Entry point of the code    
if __name__ == "__main__":
    main()
# Out:
# --- Time: 09:00:00.018000 ---
# Parcel 1 arrived – feasible outfeeds: [1, 3, 4, 6, 9, 10, 12, 13]
# [DEBUG] Parcel 1 → needed: 0.62, used: 0.00, fits: True
# Parcel 1 sorted to outfeed 1(travel time: 6.15 seconds)
#
# --- Time: 09:00:00.118000 ---
#
# --- Time: 09:00:00.218000 ---
#
# --- Time: 09:00:00.318000 ---
#
# --- Time: 09:00:00.418000 ---
#
# --- Time: 09:00:00.518000 ---
#
# --- Time: 09:00:00.618000 ---
#
# --- Time: 09:00:00.718000 ---
#
# --- Time: 09:00:00.818000 ---
#
# --- Time: 09:00:00.918000 ---
# Parcel 2 arrived – feasible outfeeds: [0, 1, 4, 6, 11, 13]
# [DEBUG] Parcel 2 → needed: 0.65, used: 0.00, fits: True
# Parcel 2 sorted to outfeed 0(travel time: 4.23 seconds)
#
# --- Time: 09:00:01.018000 ---
#
# --- Time: 09:00:01.118000 ---
#
# --- Time: 09:00:01.218000 ---
#
# --- Time: 09:00:01.318000 ---
#
# --- Time: 09:00:01.418000 ---
#
# --- Time: 09:00:01.518000 ---
#
# --- Time: 09:00:01.618000 ---
#
# --- Time: 09:00:01.718000 ---
#
# --- Time: 09:00:01.818000 ---
# Parcel 3 arrived – feasible outfeeds: [1, 2, 9, 10, 11, 14]
# [DEBUG] Parcel 3 → needed: 0.77, used: 0.62, fits: True
# Parcel 3 sorted to outfeed 1(travel time: 6.15 seconds)
#
# --- Time: 09:00:01.918000 ---
#
# --- Time: 09:00:02.018000 ---
#
# --- Time: 09:00:02.118000 ---
#
# --- Time: 09:00:02.218000 ---
#
# --- Time: 09:00:02.318000 ---
#
# --- Time: 09:00:02.418000 ---
#
# --- Time: 09:00:02.518000 ---
#
# --- Time: 09:00:02.618000 ---
#
# --- Time: 09:00:02.718000 ---
#
# --- Time: 09:00:02.818000 ---
#
# --- Time: 09:00:02.918000 ---
# Parcel 4 arrived – feasible outfeeds: [1, 3, 6, 8, 9, 12, 13]
# [DEBUG] Parcel 4 → needed: 0.72, used: 1.40, fits: True
# Parcel 4 sorted to outfeed 1(travel time: 6.15 seconds)
#
# --- Time: 09:00:03.018000 ---
#
# --- Time: 09:00:03.118000 ---
#
# --- Time: 09:00:03.218000 ---
#
# --- Time: 09:00:03.318000 ---
#
# --- Time: 09:00:03.418000 ---
#
# --- Time: 09:00:03.518000 ---
#
# --- Time: 09:00:03.618000 ---
#
# --- Time: 09:00:03.718000 ---
#
# --- Time: 09:00:03.818000 ---
#
# --- Time: 09:00:03.918000 ---
# Parcel 5 arrived – feasible outfeeds: [1, 5, 8, 9, 10, 12, 14]
# [DEBUG] Parcel 5 → needed: 0.68, used: 2.12, fits: True
# Parcel 5 sorted to outfeed 1(travel time: 6.15 seconds)
#
# --- Time: 09:00:04.018000 ---
#
# --- Time: 09:00:04.118000 ---
#
# --- Time: 09:00:04.218000 ---
#
# --- Time: 09:00:04.318000 ---
#
# --- Time: 09:00:04.418000 ---
#
# --- Time: 09:00:04.518000 ---
#
# --- Time: 09:00:04.618000 ---
#
# --- Time: 09:00:04.718000 ---
#
# --- Time: 09:00:04.818000 ---
# Parcel 6 arrived – feasible outfeeds: [7, 9, 10, 11, 12, 13]
# [DEBUG] Parcel 6 → needed: 0.74, used: 0.00, fits: True
# Parcel 6 sorted to outfeed 7(travel time: 17.69 seconds)
#
# --- Time: 09:00:04.918000 ---
#
# --- Time: 09:00:05.018000 ---
#
# --- Time: 09:00:05.118000 ---
#
# --- Time: 09:00:05.218000 ---
#
# --- Time: 09:00:05.318000 ---
#
# --- Time: 09:00:05.418000 ---
#
# --- Time: 09:00:05.518000 ---
# Parcel 1 removed from outfeed(total system time: 6.15 s)
#
# --- Time: 09:00:05.618000 ---
#
# --- Time: 09:00:05.718000 ---
# Parcel 7 arrived – feasible outfeeds: [4, 6, 8, 9, 10, 11, 13]
# [DEBUG] Parcel 7 → needed: 0.67, used: 0.00, fits: True
# Parcel 7 sorted to outfeed 4(travel time: 11.92 seconds)
#
# --- Time: 09:00:05.818000 ---
#
# --- Time: 09:00:05.918000 ---
#
# --- Time: 09:00:06.018000 ---
#
# --- Time: 09:00:06.118000 ---
#
# --- Time: 09:00:06.218000 ---
#
# --- Time: 09:00:06.318000 ---
#
# --- Time: 09:00:06.418000 ---
#
# --- Time: 09:00:06.518000 ---
#
# --- Time: 09:00:06.618000 ---
# Parcel 8 arrived – feasible outfeeds: [1, 2, 4, 6, 9, 10]
# [DEBUG] Parcel 8 → needed: 0.62, used: 2.18, fits: True
# Parcel 8 sorted to outfeed 1(travel time: 6.15 seconds)
#
# --- Time: 09:00:06.718000 ---
#
# --- Time: 09:00:06.818000 ---
#
# --- Time: 09:00:06.918000 ---
#
# --- Time: 09:00:07.018000 ---
#
# --- Time: 09:00:07.118000 ---
#
# --- Time: 09:00:07.218000 ---
#
# --- Time: 09:00:07.318000 ---
#
# --- Time: 09:00:07.418000 ---
# Parcel 9 arrived – feasible outfeeds: [2, 6, 10, 13]
# [DEBUG] Parcel 9 → needed: 0.60, used: 0.00, fits: True
# Parcel 9 sorted to outfeed 2(travel time: 8.08 seconds)
#
# --- Time: 09:00:07.518000 ---
#
# --- Time: 09:00:07.618000 ---
#
# --- Time: 09:00:07.718000 ---
#
# --- Time: 09:00:07.818000 ---
#
# --- Time: 09:00:07.918000 ---
#
# --- Time: 09:00:08.018000 ---
#
# --- Time: 09:00:08.118000 ---
#
# --- Time: 09:00:08.218000 ---
#
# --- Time: 09:00:08.318000 ---
#
# --- Time: 09:00:08.418000 ---
# Parcel 10 arrived – feasible outfeeds: [1, 3, 4, 9, 10, 11]
# [DEBUG] Parcel 10 → needed: 0.70, used: 2.80, fits: False
# [DEBUG] Parcel 10 → needed: 0.70, used: 0.00, fits: True
# Parcel 10 sorted to outfeed 3(travel time: 10.00 seconds)
# Parcel 2 removed from outfeed(total system time: 4.23 s)
#
# --- Time: 09:00:08.518000 ---
#
# --- Time: 09:00:08.618000 ---
#
# --- Time: 09:00:08.718000 ---
#
# --- Time: 09:00:08.818000 ---
#
# --- Time: 09:00:08.918000 ---
#
# --- Time: 09:00:09.018000 ---
#
# --- Time: 09:00:09.118000 ---
#
# --- Time: 09:00:09.218000 ---
#
# --- Time: 09:00:09.318000 ---
#
# --- Time: 09:00:09.418000 ---
#
# --- Time: 09:00:09.518000 ---
# Parcel 11 arrived – feasible outfeeds: [1, 2, 3, 9, 10, 13]
# [DEBUG] Parcel 11 → needed: 0.61, used: 2.80, fits: False
# [DEBUG] Parcel 11 → needed: 0.61, used: 0.60, fits: True
# Parcel 11 sorted to outfeed 2(travel time: 8.08 seconds)
#
# --- Time: 09:00:09.618000 ---
#
# --- Time: 09:00:09.718000 ---
#
# --- Time: 09:00:09.818000 ---
#
# --- Time: 09:00:09.918000 ---
#
# --- Time: 09:00:10.018000 ---
#
# --- Time: 09:00:10.118000 ---
#
# --- Time: 09:00:10.218000 ---
#
# --- Time: 09:00:10.318000 ---
# Parcel 12 arrived – feasible outfeeds: [0, 1, 2, 3, 4, 5, 6, 8, 14]
# [DEBUG] Parcel 12 → needed: 0.62, used: 0.00, fits: True
# Parcel 12 sorted to outfeed 0(travel time: 4.23 seconds)
#
# --- Time: 09:00:10.418000 ---
#
# --- Time: 09:00:10.518000 ---
#
# --- Time: 09:00:10.618000 ---
#
# --- Time: 09:00:10.718000 ---
#
# --- Time: 09:00:10.818000 ---
#
# --- Time: 09:00:10.918000 ---
#
# --- Time: 09:00:11.018000 ---
#
# --- Time: 09:00:11.118000 ---
#
# --- Time: 09:00:11.218000 ---
# Parcel 13 arrived – feasible outfeeds: [1, 4, 9, 11, 12]
# [DEBUG] Parcel 13 → needed: 0.62, used: 2.80, fits: False
# [DEBUG] Parcel 13 → needed: 0.62, used: 0.67, fits: True
# Parcel 13 sorted to outfeed 4(travel time: 11.92 seconds)
#
# --- Time: 09:00:11.318000 ---
#
# --- Time: 09:00:11.418000 ---
#
# --- Time: 09:00:11.518000 ---
#
# --- Time: 09:00:11.618000 ---
#
# --- Time: 09:00:11.718000 ---
#
# --- Time: 09:00:11.818000 ---
#
# --- Time: 09:00:11.918000 ---
#
# --- Time: 09:00:12.018000 ---
#
# --- Time: 09:00:12.118000 ---
# Parcel 3 removed from outfeed(total system time: 6.15 s)
#
# --- Time: 09:00:12.218000 ---
# Parcel 14 arrived – feasible outfeeds: [1, 2, 4, 6, 9, 10, 11]
# [DEBUG] Parcel 14 → needed: 0.62, used: 2.03, fits: True
# Parcel 14 sorted to outfeed 1(travel time: 6.15 seconds)
# Parcel 7 removed from outfeed(total system time: 11.92 s)
#
# --- Time: 09:00:12.318000 ---
# Parcel 6 removed from outfeed(total system time: 17.69 s)
#
# --- Time: 09:00:12.418000 ---
#
# --- Time: 09:00:12.518000 ---
#
# --- Time: 09:00:12.618000 ---
#
# --- Time: 09:00:12.718000 ---
#
# --- Time: 09:00:12.818000 ---
#
# --- Time: 09:00:12.918000 ---
#
# --- Time: 09:00:13.018000 ---
# Parcel 15 arrived – feasible outfeeds: [1, 4, 6, 9, 10, 14]
# [DEBUG] Parcel 15 → needed: 0.56, used: 2.65, fits: False
# [DEBUG] Parcel 15 → needed: 0.56, used: 0.62, fits: True
# Parcel 15 sorted to outfeed 4(travel time: 11.92 seconds)
#
# --- Time: 09:00:13.118000 ---
#
# --- Time: 09:00:13.218000 ---
#
# --- Time: 09:00:13.318000 ---
#
# --- Time: 09:00:13.418000 ---
#
# --- Time: 09:00:13.518000 ---
#
# --- Time: 09:00:13.618000 ---
#
# --- Time: 09:00:13.718000 ---
#
# --- Time: 09:00:13.818000 ---
#
# --- Time: 09:00:13.918000 ---
#
# --- Time: 09:00:14.018000 ---
# Parcel 16 arrived – feasible outfeeds: [1, 2, 4, 6, 9, 13]
# [DEBUG] Parcel 16 → needed: 0.59, used: 2.65, fits: False
# [DEBUG] Parcel 16 → needed: 0.59, used: 1.22, fits: True
# Parcel 16 sorted to outfeed 2(travel time: 8.08 seconds)
#
# --- Time: 09:00:14.118000 ---
#
# --- Time: 09:00:14.218000 ---
#
# --- Time: 09:00:14.318000 ---
#
# --- Time: 09:00:14.418000 ---
#
# --- Time: 09:00:14.518000 ---
#
# --- Time: 09:00:14.618000 ---
#
# --- Time: 09:00:14.718000 ---
#
# --- Time: 09:00:14.818000 ---
#
# --- Time: 09:00:14.918000 ---
# Parcel 17 arrived – feasible outfeeds: [2, 4, 6, 11, 12]
# [DEBUG] Parcel 17 → needed: 0.65, used: 1.80, fits: True
# Parcel 17 sorted to outfeed 2(travel time: 8.08 seconds)
# Parcel 9 removed from outfeed(total system time: 8.08 s)
# Parcel 10 removed from outfeed(total system time: 10.00 s)
#
# --- Time: 09:00:15.018000 ---
#
# --- Time: 09:00:15.118000 ---
#
# --- Time: 09:00:15.218000 ---
#
# --- Time: 09:00:15.318000 ---
#
# --- Time: 09:00:15.418000 ---
#
# --- Time: 09:00:15.518000 ---
#
# --- Time: 09:00:15.618000 ---
#
# --- Time: 09:00:15.718000 ---
#
# --- Time: 09:00:15.818000 ---
# Parcel 18 arrived – feasible outfeeds: [1, 2, 6, 10, 12]
# [DEBUG] Parcel 18 → needed: 0.56, used: 2.65, fits: False
# [DEBUG] Parcel 18 → needed: 0.56, used: 1.85, fits: True
# Parcel 18 sorted to outfeed 2(travel time: 8.08 seconds)
# Parcel 12 removed from outfeed(total system time: 4.23 s)
#
# --- Time: 09:00:15.918000 ---
#
# --- Time: 09:00:16.018000 ---
#
# --- Time: 09:00:16.118000 ---
#
# --- Time: 09:00:16.218000 ---
#
# --- Time: 09:00:16.318000 ---
#
# --- Time: 09:00:16.418000 ---
#
# --- Time: 09:00:16.518000 ---
#
# --- Time: 09:00:16.618000 ---
# Parcel 19 arrived – feasible outfeeds: [0, 4, 6, 10, 13, 14]
# [DEBUG] Parcel 19 → needed: 0.54, used: 0.00, fits: True
# Parcel 19 sorted to outfeed 0(travel time: 4.23 seconds)
#
# --- Time: 09:00:16.718000 ---
#
# --- Time: 09:00:16.818000 ---
#
# --- Time: 09:00:16.918000 ---
#
# --- Time: 09:00:17.018000 ---
#
# --- Time: 09:00:17.118000 ---
#
# --- Time: 09:00:17.218000 ---
#
# --- Time: 09:00:17.318000 ---
#
# --- Time: 09:00:17.418000 ---
#
# --- Time: 09:00:17.518000 ---
# Parcel 20 arrived – feasible outfeeds: [0, 1, 4, 5, 9, 12, 13]
# [DEBUG] Parcel 20 → needed: 0.51, used: 0.54, fits: True
# Parcel 20 sorted to outfeed 0(travel time: 4.23 seconds)
#
# --- Time: 09:00:17.618000 ---
#
# --- Time: 09:00:17.718000 ---
#
# --- Time: 09:00:17.818000 ---
#
# --- Time: 09:00:17.918000 ---
#
# --- Time: 09:00:18.018000 ---
#
# --- Time: 09:00:18.118000 ---
#
# --- Time: 09:00:18.218000 ---
# Parcel 21 arrived – feasible outfeeds: [0, 1, 3, 6, 9, 10]
# [DEBUG] Parcel 21 → needed: 0.62, used: 1.05, fits: True
# Parcel 21 sorted to outfeed 0(travel time: 4.23 seconds)
#
# --- Time: 09:00:18.318000 ---
#
# --- Time: 09:00:18.418000 ---
#
# --- Time: 09:00:18.518000 ---
#
# --- Time: 09:00:18.618000 ---
#
# --- Time: 09:00:18.718000 ---
#
# --- Time: 09:00:18.818000 ---
#
# --- Time: 09:00:18.918000 ---
#
# --- Time: 09:00:19.018000 ---
#
# --- Time: 09:00:19.118000 ---
#
# --- Time: 09:00:19.218000 ---
#
# --- Time: 09:00:19.318000 ---
# Parcel 22 arrived – feasible outfeeds: [0, 1, 3, 6, 9, 10, 13, 14]
# [DEBUG] Parcel 22 → needed: 0.63, used: 1.67, fits: True
# Parcel 22 sorted to outfeed 0(travel time: 4.23 seconds)
#
# --- Time: 09:00:19.418000 ---
#
# --- Time: 09:00:19.518000 ---
#
# --- Time: 09:00:19.618000 ---
#
# --- Time: 09:00:19.718000 ---
#
# --- Time: 09:00:19.818000 ---
# Parcel 13 removed from outfeed(total system time: 11.92 s)
#
# --- Time: 09:00:19.918000 ---
#
# --- Time: 09:00:20.018000 ---
#
# --- Time: 09:00:20.118000 ---
#
# --- Time: 09:00:20.218000 ---
# Parcel 23 arrived – feasible outfeeds: [0, 4, 6, 10, 13]
# [DEBUG] Parcel 23 → needed: 0.62, used: 2.30, fits: True
# Parcel 23 sorted to outfeed 0(travel time: 4.23 seconds)
#
# --- Time: 09:00:20.318000 ---
#
# --- Time: 09:00:20.418000 ---
#
# --- Time: 09:00:20.518000 ---
# Parcel 11 removed from outfeed(total system time: 8.08 s)
#
# --- Time: 09:00:20.618000 ---
#
# --- Time: 09:00:20.718000 ---
# Parcel 4 removed from outfeed(total system time: 6.15 s)
#
# --- Time: 09:00:20.818000 ---
#
# --- Time: 09:00:20.918000 ---
#
# --- Time: 09:00:21.018000 ---
# Parcel 19 removed from outfeed(total system time: 4.23 s)
#
# --- Time: 09:00:21.118000 ---
#
# --- Time: 09:00:21.218000 ---
# Parcel 24 arrived – feasible outfeeds: [0, 1, 2, 4, 6, 11]
# [DEBUG] Parcel 24 → needed: 0.57, used: 2.39, fits: True
# Parcel 24 sorted to outfeed 0(travel time: 4.23 seconds)
#
# --- Time: 09:00:21.318000 ---
#
# --- Time: 09:00:21.418000 ---
#
# --- Time: 09:00:21.518000 ---
#
# --- Time: 09:00:21.618000 ---
#
# --- Time: 09:00:21.718000 ---
#
# --- Time: 09:00:21.818000 ---
#
# --- Time: 09:00:21.918000 ---
#
# --- Time: 09:00:22.018000 ---
# Parcel 25 arrived – feasible outfeeds: [0, 1, 6, 10, 12]
# [DEBUG] Parcel 25 → needed: 0.68, used: 2.96, fits: False
# [DEBUG] Parcel 25 → needed: 0.68, used: 1.93, fits: True
# Parcel 25 sorted to outfeed 1(travel time: 6.15 seconds)
#
# --- Time: 09:00:22.118000 ---
#
# --- Time: 09:00:22.218000 ---
#
# --- Time: 09:00:22.318000 ---
#
# --- Time: 09:00:22.418000 ---
#
# --- Time: 09:00:22.518000 ---
#
# --- Time: 09:00:22.618000 ---
#
# --- Time: 09:00:22.718000 ---
#
# --- Time: 09:00:22.818000 ---
#
# --- Time: 09:00:22.918000 ---
#
# --- Time: 09:00:23.018000 ---
# Parcel 26 arrived – feasible outfeeds: [1, 4, 9, 10, 11, 13]
# [DEBUG] Parcel 26 → needed: 0.68, used: 2.61, fits: False
# [DEBUG] Parcel 26 → needed: 0.68, used: 0.56, fits: True
# Parcel 26 sorted to outfeed 4(travel time: 11.92 seconds)
#
# --- Time: 09:00:23.118000 ---
#
# --- Time: 09:00:23.218000 ---
#
# --- Time: 09:00:23.318000 ---
#
# --- Time: 09:00:23.418000 ---
#
# --- Time: 09:00:23.518000 ---
#
# --- Time: 09:00:23.618000 ---
#
# --- Time: 09:00:23.718000 ---
#
# --- Time: 09:00:23.818000 ---
#
# --- Time: 09:00:23.918000 ---
#
# --- Time: 09:00:24.018000 ---
# Parcel 27 arrived – feasible outfeeds: [1, 2, 4, 6, 14]
# [DEBUG] Parcel 27 → needed: 0.68, used: 2.61, fits: False
# [DEBUG] Parcel 27 → needed: 0.68, used: 1.80, fits: True
# Parcel 27 sorted to outfeed 2(travel time: 8.08 seconds)
#
# --- Time: 09:00:24.118000 ---
#
# --- Time: 09:00:24.218000 ---
#
# --- Time: 09:00:24.318000 ---
#
# --- Time: 09:00:24.418000 ---
#
# --- Time: 09:00:24.518000 ---
#
# --- Time: 09:00:24.618000 ---
#
# --- Time: 09:00:24.718000 ---
#
# --- Time: 09:00:24.818000 ---
#
# --- Time: 09:00:24.918000 ---
#
# --- Time: 09:00:25.018000 ---
# Parcel 28 arrived – feasible outfeeds: [0, 1, 2, 3, 4, 9, 10, 11, 14]
# [DEBUG] Parcel 28 → needed: 0.63, used: 2.96, fits: False
# [DEBUG] Parcel 28 → needed: 0.63, used: 2.61, fits: False
# [DEBUG] Parcel 28 → needed: 0.63, used: 2.48, fits: False
# [DEBUG] Parcel 28 → needed: 0.63, used: 0.00, fits: True
# Parcel 28 sorted to outfeed 3(travel time: 10.00 seconds)
#
# --- Time: 09:00:25.118000 ---
#
# --- Time: 09:00:25.218000 ---
#
# --- Time: 09:00:25.318000 ---
#
# --- Time: 09:00:25.418000 ---
#
# --- Time: 09:00:25.518000 ---
#
# --- Time: 09:00:25.618000 ---
#
# --- Time: 09:00:25.718000 ---
#
# --- Time: 09:00:25.818000 ---
# Parcel 29 arrived – feasible outfeeds: [6, 9, 10]
# [DEBUG] Parcel 29 → needed: 0.58, used: 0.00, fits: True
# Parcel 29 sorted to outfeed 6(travel time: 15.77 seconds)
#
# --- Time: 09:00:25.918000 ---
#
# --- Time: 09:00:26.018000 ---
#
# --- Time: 09:00:26.118000 ---
#
# --- Time: 09:00:26.218000 ---
#
# --- Time: 09:00:26.318000 ---
#
# --- Time: 09:00:26.418000 ---
# Parcel 15 removed from outfeed(total system time: 11.92 s)
#
# --- Time: 09:00:26.518000 ---
#
# --- Time: 09:00:26.618000 ---
#
# --- Time: 09:00:26.718000 ---
#
# --- Time: 09:00:26.818000 ---
#
# --- Time: 09:00:26.918000 ---
#
# --- Time: 09:00:27.018000 ---
# Parcel 30 arrived – feasible outfeeds: [5, 10, 11, 13]
# [DEBUG] Parcel 30 → needed: 0.63, used: 0.00, fits: True
# Parcel 30 sorted to outfeed 5(travel time: 13.85 seconds)
#
# --- Time: 09:00:27.118000 ---
# Parcel 16 removed from outfeed(total system time: 8.08 s)
#
# --- Time: 09:00:27.218000 ---
#
# --- Time: 09:00:27.318000 ---
#
# --- Time: 09:00:27.418000 ---
#
# --- Time: 09:00:27.518000 ---
#
# --- Time: 09:00:27.618000 ---
# Parcel 20 removed from outfeed(total system time: 4.23 s)
#
# --- Time: 09:00:27.718000 ---
#
# --- Time: 09:00:27.818000 ---
# Parcel 31 arrived – feasible outfeeds: [0, 4, 5, 6, 8, 9, 10, 11, 12, 14]
# [DEBUG] Parcel 31 → needed: 0.70, used: 2.45, fits: False
# [DEBUG] Parcel 31 → needed: 0.70, used: 0.68, fits: True
# Parcel 31 sorted to outfeed 4(travel time: 11.92 seconds)
#
# --- Time: 09:00:27.918000 ---
#
# --- Time: 09:00:28.018000 ---
#
# --- Time: 09:00:28.118000 ---
#
# --- Time: 09:00:28.218000 ---
#
# --- Time: 09:00:28.318000 ---
# Parcel 5 removed from outfeed(total system time: 6.15 s)
#
# --- Time: 09:00:28.418000 ---
#
# --- Time: 09:00:28.518000 ---
#
# --- Time: 09:00:28.618000 ---
# Parcel 32 arrived – feasible outfeeds: [1, 2, 3, 4, 5, 8, 9, 10, 14]
# [DEBUG] Parcel 32 → needed: 0.74, used: 1.92, fits: True
# Parcel 32 sorted to outfeed 1(travel time: 6.15 seconds)
#
# --- Time: 09:00:28.718000 ---
#
# --- Time: 09:00:28.818000 ---
#
# --- Time: 09:00:28.918000 ---
#
# --- Time: 09:00:29.018000 ---
#
# --- Time: 09:00:29.118000 ---
#
# --- Time: 09:00:29.218000 ---
#
# --- Time: 09:00:29.318000 ---
#
# --- Time: 09:00:29.418000 ---
#
# --- Time: 09:00:29.518000 ---
#
# --- Time: 09:00:29.618000 ---
# Parcel 33 arrived – feasible outfeeds: [1, 2, 12]
# [DEBUG] Parcel 33 → needed: 0.64, used: 2.67, fits: False
# [DEBUG] Parcel 33 → needed: 0.64, used: 1.89, fits: True
# Parcel 33 sorted to outfeed 2(travel time: 8.08 seconds)
#
# --- Time: 09:00:29.718000 ---
#
# --- Time: 09:00:29.818000 ---
#
# --- Time: 09:00:29.918000 ---
#
# --- Time: 09:00:30.018000 ---
#
# --- Time: 09:00:30.118000 ---
#
# --- Time: 09:00:30.218000 ---
#
# --- Time: 09:00:30.318000 ---
#
# --- Time: 09:00:30.418000 ---
# Parcel 34 arrived – feasible outfeeds: [1, 3, 6, 8, 9]
# [DEBUG] Parcel 34 → needed: 0.60, used: 2.67, fits: False
# [DEBUG] Parcel 34 → needed: 0.60, used: 0.63, fits: True
# Parcel 34 sorted to outfeed 3(travel time: 10.00 seconds)
#
# --- Time: 09:00:30.518000 ---
# Parcel 28 removed from outfeed(total system time: 10.00 s)
#
# --- Time: 09:00:30.618000 ---
#
# --- Time: 09:00:30.718000 ---
#
# --- Time: 09:00:30.818000 ---
#
# --- Time: 09:00:30.918000 ---
#
# --- Time: 09:00:31.018000 ---
#
# --- Time: 09:00:31.118000 ---
#
# --- Time: 09:00:31.218000 ---
#
# --- Time: 09:00:31.318000 ---
#
# --- Time: 09:00:31.418000 ---
#
# --- Time: 09:00:31.518000 ---
#
# --- Time: 09:00:31.618000 ---
# Parcel 35 arrived – feasible outfeeds: [1, 2, 3, 6, 9, 11, 12, 13]
# [DEBUG] Parcel 35 → needed: 0.60, used: 2.67, fits: False
# [DEBUG] Parcel 35 → needed: 0.60, used: 2.53, fits: False
# [DEBUG] Parcel 35 → needed: 0.60, used: 0.60, fits: True
# Parcel 35 sorted to outfeed 3(travel time: 10.00 seconds)
#
# --- Time: 09:00:31.718000 ---
#
# --- Time: 09:00:31.818000 ---
#
# --- Time: 09:00:31.918000 ---
#
# --- Time: 09:00:32.018000 ---
#
# --- Time: 09:00:32.118000 ---
#
# --- Time: 09:00:32.218000 ---
#
# --- Time: 09:00:32.318000 ---
#
# --- Time: 09:00:32.418000 ---
# Parcel 36 arrived – feasible outfeeds: [0, 1, 3, 4, 13, 14]
# [DEBUG] Parcel 36 → needed: 0.67, used: 2.45, fits: False
# [DEBUG] Parcel 36 → needed: 0.67, used: 2.67, fits: False
# [DEBUG] Parcel 36 → needed: 0.67, used: 1.19, fits: True
# Parcel 36 sorted to outfeed 3(travel time: 10.00 seconds)
#
# --- Time: 09:00:32.518000 ---
# Parcel 30 removed from outfeed(total system time: 13.85 s)
#
# --- Time: 09:00:32.618000 ---
#
# --- Time: 09:00:32.718000 ---
#
# --- Time: 09:00:32.818000 ---
# Parcel 8 removed from outfeed(total system time: 6.15 s)
#
# --- Time: 09:00:32.918000 ---
#
# --- Time: 09:00:33.018000 ---
#
# --- Time: 09:00:33.118000 ---
#
# --- Time: 09:00:33.218000 ---
#
# --- Time: 09:00:33.318000 ---
# Parcel 29 removed from outfeed(total system time: 15.77 s)
#
# --- Time: 09:00:33.418000 ---
# Parcel 37 arrived – feasible outfeeds: [1, 2, 6, 9, 11, 14]
# [DEBUG] Parcel 37 → needed: 0.65, used: 2.04, fits: True
# Parcel 37 sorted to outfeed 1(travel time: 6.15 seconds)
#
# --- Time: 09:00:33.518000 ---
#
# --- Time: 09:00:33.618000 ---
#
# --- Time: 09:00:33.718000 ---
# Parcel 17 removed from outfeed(total system time: 8.08 s)
#
# --- Time: 09:00:33.818000 ---
#
# --- Time: 09:00:33.918000 ---
#
# --- Time: 09:00:34.018000 ---
# Parcel 26 removed from outfeed(total system time: 11.92 s)
#
# --- Time: 09:00:34.118000 ---
#
# --- Time: 09:00:34.218000 ---
# Parcel 38 arrived – feasible outfeeds: [1, 4, 8, 9, 11]
# [DEBUG] Parcel 38 → needed: 0.75, used: 2.69, fits: False
# [DEBUG] Parcel 38 → needed: 0.75, used: 0.70, fits: True
# Parcel 38 sorted to outfeed 4(travel time: 11.92 seconds)
#
# --- Time: 09:00:34.318000 ---
#
# --- Time: 09:00:34.418000 ---
#
# --- Time: 09:00:34.518000 ---
#
# --- Time: 09:00:34.618000 ---
#
# --- Time: 09:00:34.718000 ---
#
# --- Time: 09:00:34.818000 ---
#
# --- Time: 09:00:34.918000 ---
# Parcel 39 arrived – feasible outfeeds: [0, 1, 4, 5, 6, 8, 9, 10, 11]
# [DEBUG] Parcel 39 → needed: 0.62, used: 2.45, fits: False
# [DEBUG] Parcel 39 → needed: 0.62, used: 2.69, fits: False
# [DEBUG] Parcel 39 → needed: 0.62, used: 1.44, fits: True
# Parcel 39 sorted to outfeed 4(travel time: 11.92 seconds)
#
# --- Time: 09:00:35.018000 ---
#
# --- Time: 09:00:35.118000 ---
#
# --- Time: 09:00:35.218000 ---
#
# --- Time: 09:00:35.318000 ---
#
# --- Time: 09:00:35.418000 ---
#
# --- Time: 09:00:35.518000 ---
#
# --- Time: 09:00:35.618000 ---
#
# --- Time: 09:00:35.718000 ---
#
# --- Time: 09:00:35.818000 ---
#
# --- Time: 09:00:35.918000 ---
# Parcel 40 arrived – feasible outfeeds: [4, 6, 9, 10, 11, 14]
# [DEBUG] Parcel 40 → needed: 0.71, used: 2.07, fits: True
# Parcel 40 sorted to outfeed 4(travel time: 11.92 seconds)
#
# --- Time: 09:00:36.018000 ---
#
# --- Time: 09:00:36.118000 ---
#
# --- Time: 09:00:36.218000 ---
# Parcel 21 removed from outfeed(total system time: 4.23 s)
#
# --- Time: 09:00:36.318000 ---
#
# --- Time: 09:00:36.418000 ---
#
# --- Time: 09:00:36.518000 ---
#
# --- Time: 09:00:36.618000 ---
#
# --- Time: 09:00:36.718000 ---
#
# --- Time: 09:00:36.818000 ---
#
# --- Time: 09:00:36.918000 ---
# Parcel 41 arrived – feasible outfeeds: [0, 1, 4, 5, 9, 10]
# [DEBUG] Parcel 41 → needed: 0.61, used: 1.83, fits: True
# Parcel 41 sorted to outfeed 0(travel time: 4.23 seconds)
#
# --- Time: 09:00:37.018000 ---
#
# --- Time: 09:00:37.118000 ---
# Parcel 34 removed from outfeed(total system time: 10.00 s)
#
# --- Time: 09:00:37.218000 ---
#
# --- Time: 09:00:37.318000 ---
#
# --- Time: 09:00:37.418000 ---
#
# --- Time: 09:00:37.518000 ---
#
# --- Time: 09:00:37.618000 ---
#
# --- Time: 09:00:37.718000 ---
#
# --- Time: 09:00:37.818000 ---
# Parcel 42 arrived – feasible outfeeds: [0, 1, 4, 6, 7, 11, 14]
# [DEBUG] Parcel 42 → needed: 0.71, used: 2.44, fits: False
# [DEBUG] Parcel 42 → needed: 0.71, used: 2.69, fits: False
# [DEBUG] Parcel 42 → needed: 0.71, used: 2.78, fits: False
# [DEBUG] Parcel 42 → needed: 0.71, used: 0.00, fits: True
# Parcel 42 sorted to outfeed 6(travel time: 15.77 seconds)
#
# --- Time: 09:00:37.918000 ---
#
# --- Time: 09:00:38.018000 ---
#
# --- Time: 09:00:38.118000 ---
#
# --- Time: 09:00:38.218000 ---
#
# --- Time: 09:00:38.318000 ---
#
# --- Time: 09:00:38.418000 ---
#
# --- Time: 09:00:38.518000 ---
#
# --- Time: 09:00:38.618000 ---
#
# --- Time: 09:00:38.718000 ---
#
# --- Time: 09:00:38.818000 ---
# Parcel 43 arrived – feasible outfeeds: [0, 1, 2, 3, 4, 5, 9, 12, 13]
# [DEBUG] Parcel 43 → needed: 0.68, used: 2.44, fits: False
# [DEBUG] Parcel 43 → needed: 0.68, used: 2.69, fits: False
# [DEBUG] Parcel 43 → needed: 0.68, used: 1.89, fits: True
# Parcel 43 sorted to outfeed 2(travel time: 8.08 seconds)
#
# --- Time: 09:00:38.918000 ---
#
# --- Time: 09:00:39.018000 ---
#
# --- Time: 09:00:39.118000 ---
#
# --- Time: 09:00:39.218000 ---
#
# --- Time: 09:00:39.318000 ---
#
# --- Time: 09:00:39.418000 ---
# Parcel 14 removed from outfeed(total system time: 6.15 s)
#
# --- Time: 09:00:39.518000 ---
#
# --- Time: 09:00:39.618000 ---
# Parcel 44 arrived – feasible outfeeds: [1, 2, 3, 6, 8, 10]
# [DEBUG] Parcel 44 → needed: 0.62, used: 2.07, fits: True
# Parcel 44 sorted to outfeed 1(travel time: 6.15 seconds)
#
# --- Time: 09:00:39.718000 ---
#
# --- Time: 09:00:39.818000 ---
#
# --- Time: 09:00:39.918000 ---
#
# --- Time: 09:00:40.018000 ---
#
# --- Time: 09:00:40.118000 ---
#
# --- Time: 09:00:40.218000 ---
#
# --- Time: 09:00:40.318000 ---
# Parcel 18 removed from outfeed(total system time: 8.08 s)
#
# --- Time: 09:00:40.418000 ---
#
# --- Time: 09:00:40.518000 ---
#
# --- Time: 09:00:40.618000 ---
#
# --- Time: 09:00:40.718000 ---
#
# --- Time: 09:00:40.818000 ---
#
# --- Time: 09:00:40.918000 ---
#
# --- Time: 09:00:41.018000 ---
#
# --- Time: 09:00:41.118000 ---
#
# --- Time: 09:00:41.218000 ---
#
# --- Time: 09:00:41.318000 ---
#
# --- Time: 09:00:41.418000 ---
#
# --- Time: 09:00:41.518000 ---
#
# --- Time: 09:00:41.618000 ---
# Parcel 46 arrived – feasible outfeeds: [1, 4, 6, 8, 9, 10, 11, 12]
# [DEBUG] Parcel 46 → needed: 0.69, used: 2.69, fits: False
# [DEBUG] Parcel 46 → needed: 0.69, used: 2.78, fits: False
# [DEBUG] Parcel 46 → needed: 0.69, used: 0.71, fits: True
# Parcel 46 sorted to outfeed 6(travel time: 15.77 seconds)
# Parcel 31 removed from outfeed(total system time: 11.92 s)
#
# --- Time: 09:00:41.718000 ---
#
# --- Time: 09:00:41.818000 ---
#
# --- Time: 09:00:41.918000 ---
#
# --- Time: 09:00:42.018000 ---
#
# --- Time: 09:00:42.118000 ---
#
# --- Time: 09:00:42.218000 ---
#
# --- Time: 09:00:42.318000 ---
#
# --- Time: 09:00:42.418000 ---
# Parcel 47 arrived – feasible outfeeds: [0, 1, 2, 4, 5, 6, 8, 10]
# [DEBUG] Parcel 47 → needed: 0.61, used: 2.44, fits: False
# [DEBUG] Parcel 47 → needed: 0.61, used: 2.69, fits: False
# [DEBUG] Parcel 47 → needed: 0.61, used: 2.01, fits: True
# Parcel 47 sorted to outfeed 2(travel time: 8.08 seconds)
#
# --- Time: 09:00:42.518000 ---
#
# --- Time: 09:00:42.618000 ---
#
# --- Time: 09:00:42.718000 ---
# Parcel 35 removed from outfeed(total system time: 10.00 s)
#
# --- Time: 09:00:42.818000 ---
#
# --- Time: 09:00:42.918000 ---
#
# --- Time: 09:00:43.018000 ---
#
# --- Time: 09:00:43.118000 ---
#
# --- Time: 09:00:43.218000 ---
# Parcel 48 arrived – feasible outfeeds: [0, 2, 3, 4, 9, 10, 11, 12, 13, 14]
# [DEBUG] Parcel 48 → needed: 0.61, used: 2.44, fits: False
# [DEBUG] Parcel 48 → needed: 0.61, used: 2.61, fits: False
# [DEBUG] Parcel 48 → needed: 0.61, used: 0.67, fits: True
# Parcel 48 sorted to outfeed 3(travel time: 10.00 seconds)
#
# --- Time: 09:00:43.318000 ---
#
# --- Time: 09:00:43.418000 ---
#
# --- Time: 09:00:43.518000 ---
#
# --- Time: 09:00:43.618000 ---
#
# --- Time: 09:00:43.718000 ---
#
# --- Time: 09:00:43.818000 ---
# Parcel 22 removed from outfeed(total system time: 4.23 s)
#
# --- Time: 09:00:43.918000 ---
#
# --- Time: 09:00:44.018000 ---
#
# --- Time: 09:00:44.118000 ---
# Parcel 49 arrived – feasible outfeeds: [0, 2, 6, 8, 9, 10]
# [DEBUG] Parcel 49 → needed: 0.64, used: 1.80, fits: True
# Parcel 49 sorted to outfeed 0(travel time: 4.23 seconds)
#
# --- Time: 09:00:44.218000 ---
#
# --- Time: 09:00:44.318000 ---
#
# --- Time: 09:00:44.418000 ---
#
# --- Time: 09:00:44.518000 ---
#
# --- Time: 09:00:44.618000 ---
#
# --- Time: 09:00:44.718000 ---
#
# --- Time: 09:00:44.818000 ---
#
# --- Time: 09:00:44.918000 ---
#
# --- Time: 09:00:45.018000 ---
#
# --- Time: 09:00:45.118000 ---
#
# --- Time: 09:00:45.218000 ---
# Parcel 50 arrived – feasible outfeeds: [1, 4, 6, 9, 10, 12]
# [DEBUG] Parcel 50 → needed: 0.59, used: 2.69, fits: False
# [DEBUG] Parcel 50 → needed: 0.59, used: 2.08, fits: True
# Parcel 50 sorted to outfeed 4(travel time: 11.92 seconds)
#
# --- Time: 09:00:45.318000 ---
# Parcel 42 removed from outfeed(total system time: 15.77 s)
#
# --- Time: 09:00:45.418000 ---
#
# --- Time: 09:00:45.518000 ---
#
# --- Time: 09:00:45.618000 ---
#
# --- Time: 09:00:45.718000 ---
#
# --- Time: 09:00:45.818000 ---
#
# --- Time: 09:00:45.918000 ---
#
# --- Time: 09:00:46.018000 ---
#
# --- Time: 09:00:46.118000 ---
#
# --- Time: 09:00:46.218000 ---
#
# --- Time: 09:00:46.318000 ---
#
# --- Time: 09:00:46.418000 ---
#
# --- Time: 09:00:46.518000 ---
# Parcel 51 arrived – feasible outfeeds: [1, 3, 5, 8, 9, 10, 14]
# [DEBUG] Parcel 51 → needed: 0.51, used: 2.69, fits: False
# [DEBUG] Parcel 51 → needed: 0.51, used: 1.28, fits: True
# Parcel 51 sorted to outfeed 3(travel time: 10.00 seconds)
#
# --- Time: 09:00:46.618000 ---
#
# --- Time: 09:00:46.718000 ---
#
# --- Time: 09:00:46.818000 ---
#
# --- Time: 09:00:46.918000 ---
# Parcel 27 removed from outfeed(total system time: 8.08 s)
#
# --- Time: 09:00:47.018000 ---
#
# --- Time: 09:00:47.118000 ---
#
# --- Time: 09:00:47.218000 ---
# Parcel 36 removed from outfeed(total system time: 10.00 s)
# Parcel 38 removed from outfeed(total system time: 11.92 s)
#
# --- Time: 09:00:47.318000 ---
#
# --- Time: 09:00:47.418000 ---
#
# --- Time: 09:00:47.518000 ---
# Parcel 52 arrived – feasible outfeeds: [0, 1, 4, 6, 10]
# [DEBUG] Parcel 52 → needed: 0.54, used: 2.44, fits: True
# Parcel 52 sorted to outfeed 0(travel time: 4.23 seconds)
#
# --- Time: 09:00:47.618000 ---
#
# --- Time: 09:00:47.718000 ---
#
# --- Time: 09:00:47.818000 ---
#
# --- Time: 09:00:47.918000 ---
#
# --- Time: 09:00:48.018000 ---
# Parcel 25 removed from outfeed(total system time: 6.15 s)
#
# --- Time: 09:00:48.118000 ---
#
# --- Time: 09:00:48.218000 ---
#
# --- Time: 09:00:48.318000 ---
#
# --- Time: 09:00:48.418000 ---
# Parcel 53 arrived – feasible outfeeds: [4, 6, 11]
# [DEBUG] Parcel 53 → needed: 0.66, used: 1.93, fits: True
# Parcel 53 sorted to outfeed 4(travel time: 11.92 seconds)
#
# --- Time: 09:00:48.518000 ---
#
# --- Time: 09:00:48.618000 ---
#
# --- Time: 09:00:48.718000 ---
#
# --- Time: 09:00:48.818000 ---
#
# --- Time: 09:00:48.918000 ---
#
# --- Time: 09:00:49.018000 ---
#
# --- Time: 09:00:49.118000 ---
#
# --- Time: 09:00:49.218000 ---
#
# --- Time: 09:00:49.318000 ---
# Parcel 54 arrived – feasible outfeeds: [1, 6, 9]
# [DEBUG] Parcel 54 → needed: 0.61, used: 2.01, fits: True
# Parcel 54 sorted to outfeed 1(travel time: 6.15 seconds)
#
# --- Time: 09:00:49.418000 ---
# Parcel 23 removed from outfeed(total system time: 4.23 s)
#
# --- Time: 09:00:49.518000 ---
#
# --- Time: 09:00:49.618000 ---
#
# --- Time: 09:00:49.718000 ---
#
# --- Time: 09:00:49.818000 ---
#
# --- Time: 09:00:49.918000 ---
#
# --- Time: 09:00:50.018000 ---
#
# --- Time: 09:00:50.118000 ---
#
# --- Time: 09:00:50.218000 ---
#
# --- Time: 09:00:50.318000 ---
#
# --- Time: 09:00:50.418000 ---
#
# --- Time: 09:00:50.518000 ---
#
# --- Time: 09:00:50.618000 ---
# Parcel 55 arrived – feasible outfeeds: [1, 2, 3, 4, 6, 8, 10]
# [DEBUG] Parcel 55 → needed: 0.56, used: 2.62, fits: False
# [DEBUG] Parcel 55 → needed: 0.56, used: 1.93, fits: True
# Parcel 55 sorted to outfeed 2(travel time: 8.08 seconds)
#
# --- Time: 09:00:50.718000 ---
#
# --- Time: 09:00:50.818000 ---
#
# --- Time: 09:00:50.918000 ---
# Parcel 46 removed from outfeed(total system time: 15.77 s)
#
# --- Time: 09:00:51.018000 ---
#
# --- Time: 09:00:51.118000 ---
#
# --- Time: 09:00:51.218000 ---
#
# --- Time: 09:00:51.318000 ---
#
# --- Time: 09:00:51.418000 ---
# Parcel 33 removed from outfeed(total system time: 8.08 s)
#
# --- Time: 09:00:51.518000 ---
#
# --- Time: 09:00:51.618000 ---
#
# --- Time: 09:00:51.718000 ---
# Parcel 56 arrived – feasible outfeeds: [2, 9, 10, 12, 14]
# [DEBUG] Parcel 56 → needed: 0.59, used: 1.85, fits: True
# Parcel 56 sorted to outfeed 2(travel time: 8.08 seconds)
# Parcel 48 removed from outfeed(total system time: 10.00 s)
#
# --- Time: 09:00:51.818000 ---
#
# --- Time: 09:00:51.918000 ---
#
# --- Time: 09:00:52.018000 ---
#
# --- Time: 09:00:52.118000 ---
#
# --- Time: 09:00:52.218000 ---
#
# --- Time: 09:00:52.318000 ---
#
# --- Time: 09:00:52.418000 ---
# Parcel 57 arrived – feasible outfeeds: [2, 4, 6, 7, 10, 12]
# [DEBUG] Parcel 57 → needed: 0.68, used: 2.43, fits: False
# [DEBUG] Parcel 57 → needed: 0.68, used: 2.59, fits: False
# [DEBUG] Parcel 57 → needed: 0.68, used: 0.00, fits: True
# Parcel 57 sorted to outfeed 6(travel time: 15.77 seconds)
#
# --- Time: 09:00:52.518000 ---
#
# --- Time: 09:00:52.618000 ---
#
# --- Time: 09:00:52.718000 ---
#
# --- Time: 09:00:52.818000 ---
#
# --- Time: 09:00:52.918000 ---
#
# --- Time: 09:00:53.018000 ---
#
# --- Time: 09:00:53.118000 ---
#
# --- Time: 09:00:53.218000 ---
# Parcel 58 arrived – feasible outfeeds: [1, 2, 3, 6]
# [DEBUG] Parcel 58 → needed: 0.63, used: 2.62, fits: False
# [DEBUG] Parcel 58 → needed: 0.63, used: 2.43, fits: False
# [DEBUG] Parcel 58 → needed: 0.63, used: 0.51, fits: True
# Parcel 58 sorted to outfeed 3(travel time: 10.00 seconds)
#
# --- Time: 09:00:53.318000 ---
#
# --- Time: 09:00:53.418000 ---
#
# --- Time: 09:00:53.518000 ---
#
# --- Time: 09:00:53.618000 ---
# Parcel 32 removed from outfeed(total system time: 6.15 s)
#
# --- Time: 09:00:53.718000 ---
#
# --- Time: 09:00:53.818000 ---
# Parcel 39 removed from outfeed(total system time: 11.92 s)
#
# --- Time: 09:00:53.918000 ---
# Parcel 59 arrived – feasible outfeeds: [2, 3, 6, 9, 10, 11, 14]
# [DEBUG] Parcel 59 → needed: 0.61, used: 2.43, fits: False
# [DEBUG] Parcel 59 → needed: 0.61, used: 1.14, fits: True
# Parcel 59 sorted to outfeed 3(travel time: 10.00 seconds)
#
# --- Time: 09:00:54.018000 ---
#
# --- Time: 09:00:54.118000 ---
#
# --- Time: 09:00:54.218000 ---
#
# --- Time: 09:00:54.318000 ---
#
# --- Time: 09:00:54.418000 ---
#
# --- Time: 09:00:54.518000 ---
#
# --- Time: 09:00:54.618000 ---
#
# --- Time: 09:00:54.718000 ---
#
# --- Time: 09:00:54.818000 ---
#
# --- Time: 09:00:54.918000 ---
# Parcel 60 arrived – feasible outfeeds: [2, 3, 4, 6, 10]
# [DEBUG] Parcel 60 → needed: 0.54, used: 2.43, fits: True
# Parcel 60 sorted to outfeed 2(travel time: 8.08 seconds)
#
# --- Time: 09:00:55.018000 ---
#
# --- Time: 09:00:55.118000 ---
#
# --- Time: 09:00:55.218000 ---
#
# --- Time: 09:00:55.318000 ---
#
# --- Time: 09:00:55.418000 ---
#
# --- Time: 09:00:55.518000 ---
#
# --- Time: 09:00:55.618000 ---
#
# --- Time: 09:00:55.718000 ---
#
# --- Time: 09:00:55.818000 ---
#
# --- Time: 09:00:55.918000 ---
#
# --- Time: 09:00:56.018000 ---
# Parcel 61 arrived – feasible outfeeds: [2, 6, 9]
# [DEBUG] Parcel 61 → needed: 0.66, used: 2.97, fits: False
# [DEBUG] Parcel 61 → needed: 0.66, used: 0.68, fits: True
# Parcel 61 sorted to outfeed 6(travel time: 15.77 seconds)
# Parcel 24 removed from outfeed(total system time: 4.23 s)
#
# --- Time: 09:00:56.118000 ---
#
# --- Time: 09:00:56.218000 ---
# Parcel 51 removed from outfeed(total system time: 10.00 s)
#
# --- Time: 09:00:56.318000 ---
#
# --- Time: 09:00:56.418000 ---
#
# --- Time: 09:00:56.518000 ---
#
# --- Time: 09:00:56.618000 ---
#
# --- Time: 09:00:56.718000 ---
# Parcel 62 arrived – feasible outfeeds: [5, 6, 8, 9, 10]
# [DEBUG] Parcel 62 → needed: 0.60, used: 0.00, fits: True
# Parcel 62 sorted to outfeed 5(travel time: 13.85 seconds)
#
# --- Time: 09:00:56.818000 ---
#
# --- Time: 09:00:56.918000 ---
#
# --- Time: 09:00:57.018000 ---
#
# --- Time: 09:00:57.118000 ---
#
# --- Time: 09:00:57.218000 ---
#
# --- Time: 09:00:57.318000 ---
#
# --- Time: 09:00:57.418000 ---
#
# --- Time: 09:00:57.518000 ---
#
# --- Time: 09:00:57.618000 ---
#
# --- Time: 09:00:57.718000 ---
# Parcel 63 arrived – feasible outfeeds: [0, 1, 6, 10, 14]
# [DEBUG] Parcel 63 → needed: 0.61, used: 1.78, fits: True
# Parcel 63 sorted to outfeed 0(travel time: 4.23 seconds)
#
# --- Time: 09:00:57.818000 ---
#
# --- Time: 09:00:57.918000 ---
#
# --- Time: 09:00:58.018000 ---
#
# --- Time: 09:00:58.118000 ---
# Parcel 37 removed from outfeed(total system time: 6.15 s)
#
# --- Time: 09:00:58.218000 ---
#
# --- Time: 09:00:58.318000 ---
#
# --- Time: 09:00:58.418000 ---
#
# --- Time: 09:00:58.518000 ---
#
# --- Time: 09:00:58.618000 ---
#
# --- Time: 09:00:58.718000 ---
#
# --- Time: 09:00:58.818000 ---
#
# --- Time: 09:00:58.918000 ---
#
# --- Time: 09:00:59.018000 ---
# Parcel 43 removed from outfeed(total system time: 8.08 s)
#
# --- Time: 09:00:59.118000 ---
# Parcel 64 arrived – feasible outfeeds: [0, 1, 5, 6, 8, 10, 11]
# [DEBUG] Parcel 64 → needed: 0.73, used: 2.39, fits: False
# [DEBUG] Parcel 64 → needed: 0.73, used: 1.23, fits: True
# Parcel 64 sorted to outfeed 1(travel time: 6.15 seconds)
#
# --- Time: 09:00:59.218000 ---
#
# --- Time: 09:00:59.318000 ---
#
# --- Time: 09:00:59.418000 ---
#
# --- Time: 09:00:59.518000 ---
#
# --- Time: 09:00:59.618000 ---
#
# --- Time: 09:00:59.718000 ---
#
# --- Time: 09:00:59.818000 ---
#
# --- Time: 09:00:59.918000 ---
# Parcel 57 removed from outfeed(total system time: 15.77 s)
#
# --- Time: 09:01:00.018000 ---
# Parcel 65 arrived – feasible outfeeds: [3, 9, 13]
# [DEBUG] Parcel 65 → needed: 0.65, used: 1.25, fits: True
# Parcel 65 sorted to outfeed 3(travel time: 10.00 seconds)
#
# --- Time: 09:01:00.118000 ---
#
# --- Time: 09:01:00.218000 ---
#
# --- Time: 09:01:00.318000 ---
#
# --- Time: 09:01:00.418000 ---
#
# --- Time: 09:01:00.518000 ---
#
# --- Time: 09:01:00.618000 ---
#
# --- Time: 09:01:00.718000 ---
#
# --- Time: 09:01:00.818000 ---
#
# --- Time: 09:01:00.918000 ---
# Parcel 66 arrived – feasible outfeeds: [0, 2, 4, 5, 6, 10, 13]
# [DEBUG] Parcel 66 → needed: 0.71, used: 2.39, fits: False
# [DEBUG] Parcel 66 → needed: 0.71, used: 2.29, fits: False
# [DEBUG] Parcel 66 → needed: 0.71, used: 1.97, fits: True
# Parcel 66 sorted to outfeed 4(travel time: 11.92 seconds)
#
# --- Time: 09:01:01.018000 ---
#
# --- Time: 09:01:01.118000 ---
#
# --- Time: 09:01:01.218000 ---
#
# --- Time: 09:01:01.318000 ---
#
# --- Time: 09:01:01.418000 ---
#
# --- Time: 09:01:01.518000 ---
#
# --- Time: 09:01:01.618000 ---
#
# --- Time: 09:01:01.718000 ---
#
# --- Time: 09:01:01.818000 ---
#
# --- Time: 09:01:01.918000 ---
#
# --- Time: 09:01:02.018000 ---
# Parcel 67 arrived – feasible outfeeds: [4, 5, 6, 9, 11]
# [DEBUG] Parcel 67 → needed: 0.56, used: 2.68, fits: False
# [DEBUG] Parcel 67 → needed: 0.56, used: 0.60, fits: True
# Parcel 67 sorted to outfeed 5(travel time: 13.85 seconds)
#
# --- Time: 09:01:02.118000 ---
#
# --- Time: 09:01:02.218000 ---
#
# --- Time: 09:01:02.318000 ---
#
# --- Time: 09:01:02.418000 ---
# Parcel 40 removed from outfeed(total system time: 11.92 s)
#
# --- Time: 09:01:02.518000 ---
#
# --- Time: 09:01:02.618000 ---
# Parcel 41 removed from outfeed(total system time: 4.23 s)
#
# --- Time: 09:01:02.718000 ---
#
# --- Time: 09:01:02.818000 ---
# Parcel 58 removed from outfeed(total system time: 10.00 s)
#
# --- Time: 09:01:02.918000 ---
#
# --- Time: 09:01:03.018000 ---
#
# --- Time: 09:01:03.118000 ---
# Parcel 68 arrived – feasible outfeeds: [2, 5, 9, 10, 11, 12]
# [DEBUG] Parcel 68 → needed: 0.50, used: 2.29, fits: True
# Parcel 68 sorted to outfeed 2(travel time: 8.08 seconds)
#
# --- Time: 09:01:03.218000 ---
# Parcel 62 removed from outfeed(total system time: 13.85 s)
#
# --- Time: 09:01:03.318000 ---
#
# --- Time: 09:01:03.418000 ---
#
# --- Time: 09:01:03.518000 ---
#
# --- Time: 09:01:03.618000 ---
#
# --- Time: 09:01:03.718000 ---
# Parcel 44 removed from outfeed(total system time: 6.15 s)
#
# --- Time: 09:01:03.818000 ---
#
# --- Time: 09:01:03.918000 ---
#
# --- Time: 09:01:04.018000 ---
#
# --- Time: 09:01:04.118000 ---
#
# --- Time: 09:01:04.218000 ---
#
# --- Time: 09:01:04.318000 ---
#
# --- Time: 09:01:04.418000 ---
# Parcel 69 arrived – feasible outfeeds: [1, 2, 9, 10]
# [DEBUG] Parcel 69 → needed: 0.59, used: 1.34, fits: True
# Parcel 69 sorted to outfeed 1(travel time: 6.15 seconds)
#
# --- Time: 09:01:04.518000 ---
#
# --- Time: 09:01:04.618000 ---
# Parcel 47 removed from outfeed(total system time: 8.08 s)
#
# --- Time: 09:01:04.718000 ---
#
# --- Time: 09:01:04.818000 ---
#
# --- Time: 09:01:04.918000 ---
#
# --- Time: 09:01:05.018000 ---
#
# --- Time: 09:01:05.118000 ---
#
# --- Time: 09:01:05.218000 ---
# Parcel 70 arrived – feasible outfeeds: [3, 4, 6, 9, 12, 14]
# [DEBUG] Parcel 70 → needed: 0.71, used: 1.26, fits: True
# Parcel 70 sorted to outfeed 3(travel time: 10.00 seconds)
#
# --- Time: 09:01:05.318000 ---
#
# --- Time: 09:01:05.418000 ---
#
# --- Time: 09:01:05.518000 ---
#
# --- Time: 09:01:05.618000 ---
#
# --- Time: 09:01:05.718000 ---
#
# --- Time: 09:01:05.818000 ---
#
# --- Time: 09:01:05.918000 ---
#
# --- Time: 09:01:06.018000 ---
#
# --- Time: 09:01:06.118000 ---
#
# --- Time: 09:01:06.218000 ---
# Parcel 71 arrived – feasible outfeeds: [0, 3, 4, 6, 8, 9, 11, 12, 14]
# [DEBUG] Parcel 71 → needed: 0.62, used: 1.79, fits: True
# Parcel 71 sorted to outfeed 0(travel time: 4.23 seconds)
#
# --- Time: 09:01:06.318000 ---
#
# --- Time: 09:01:06.418000 ---
#
# --- Time: 09:01:06.518000 ---
#
# --- Time: 09:01:06.618000 ---
#
# --- Time: 09:01:06.718000 ---
#
# --- Time: 09:01:06.818000 ---
#
# --- Time: 09:01:06.918000 ---
# Parcel 50 removed from outfeed(total system time: 11.92 s)
#
# --- Time: 09:01:07.018000 ---
# Parcel 72 arrived – feasible outfeeds: [0, 1, 2, 4, 6, 10, 11]
# [DEBUG] Parcel 72 → needed: 0.76, used: 2.41, fits: False
# [DEBUG] Parcel 72 → needed: 0.76, used: 1.93, fits: True
# Parcel 72 sorted to outfeed 1(travel time: 6.15 seconds)
#
# --- Time: 09:01:07.118000 ---
#
# --- Time: 09:01:07.218000 ---
#
# --- Time: 09:01:07.318000 ---
#
# --- Time: 09:01:07.418000 ---
#
# --- Time: 09:01:07.518000 ---
# Parcel 61 removed from outfeed(total system time: 15.77 s)
#
# --- Time: 09:01:07.618000 ---
#
# --- Time: 09:01:07.718000 ---
# Parcel 73 arrived – feasible outfeeds: [0, 3, 4, 5, 9, 10, 11, 13, 14]
# [DEBUG] Parcel 73 → needed: 0.66, used: 2.41, fits: False
# [DEBUG] Parcel 73 → needed: 0.66, used: 1.97, fits: True
# Parcel 73 sorted to outfeed 3(travel time: 10.00 seconds)
#
# --- Time: 09:01:07.818000 ---
#
# --- Time: 09:01:07.918000 ---
#
# --- Time: 09:01:08.018000 ---
#
# --- Time: 09:01:08.118000 ---
#
# --- Time: 09:01:08.218000 ---
#
# --- Time: 09:01:08.318000 ---
#
# --- Time: 09:01:08.418000 ---
#
# --- Time: 09:01:08.518000 ---
#
# --- Time: 09:01:08.618000 ---
#
# --- Time: 09:01:08.718000 ---
#
# --- Time: 09:01:08.818000 ---
# Parcel 67 removed from outfeed(total system time: 13.85 s)
#
# --- Time: 09:01:08.918000 ---
# Parcel 74 arrived – feasible outfeeds: [4, 8, 10, 11, 12]
# [DEBUG] Parcel 74 → needed: 0.70, used: 1.38, fits: True
# Parcel 74 sorted to outfeed 4(travel time: 11.92 seconds)
#
# --- Time: 09:01:09.018000 ---
#
# --- Time: 09:01:09.118000 ---
#
# --- Time: 09:01:09.218000 ---
#
# --- Time: 09:01:09.318000 ---
#
# --- Time: 09:01:09.418000 ---
#
# --- Time: 09:01:09.518000 ---
#
# --- Time: 09:01:09.618000 ---
#
# --- Time: 09:01:09.718000 ---
# Parcel 75 arrived – feasible outfeeds: [0, 1, 2, 3, 4, 13, 14]
# [DEBUG] Parcel 75 → needed: 0.59, used: 2.41, fits: False
# [DEBUG] Parcel 75 → needed: 0.59, used: 2.69, fits: False
# [DEBUG] Parcel 75 → needed: 0.59, used: 2.18, fits: True
# Parcel 75 sorted to outfeed 2(travel time: 8.08 seconds)
#
# --- Time: 09:01:09.818000 ---
#
# --- Time: 09:01:09.918000 ---
#
# --- Time: 09:01:10.018000 ---
#
# --- Time: 09:01:10.118000 ---
#
# --- Time: 09:01:10.218000 ---
# Parcel 49 removed from outfeed(total system time: 4.23 s)
#
# --- Time: 09:01:10.318000 ---
# Parcel 54 removed from outfeed(total system time: 6.15 s)
#
# --- Time: 09:01:10.418000 ---
# Parcel 59 removed from outfeed(total system time: 10.00 s)
#
# --- Time: 09:01:10.518000 ---
#
# --- Time: 09:01:10.618000 ---
#
# --- Time: 09:01:10.718000 ---
#
# --- Time: 09:01:10.818000 ---
#
# --- Time: 09:01:10.918000 ---
#
# --- Time: 09:01:11.018000 ---
# Parcel 76 arrived – feasible outfeeds: [0, 1, 3, 6, 10, 13]
# [DEBUG] Parcel 76 → needed: 0.54, used: 1.77, fits: True
# Parcel 76 sorted to outfeed 0(travel time: 4.23 seconds)
#
# --- Time: 09:01:11.118000 ---
#
# --- Time: 09:01:11.218000 ---
#
# --- Time: 09:01:11.318000 ---
#
# --- Time: 09:01:11.418000 ---
#
# --- Time: 09:01:11.518000 ---
#
# --- Time: 09:01:11.618000 ---
#
# --- Time: 09:01:11.718000 ---
#
# --- Time: 09:01:11.818000 ---
#
# --- Time: 09:01:11.918000 ---
# Parcel 77 arrived – feasible outfeeds: [1, 2, 3, 8, 9, 11]
# [DEBUG] Parcel 77 → needed: 0.63, used: 2.08, fits: True
# Parcel 77 sorted to outfeed 1(travel time: 6.15 seconds)
#
# --- Time: 09:01:12.018000 ---
#
# --- Time: 09:01:12.118000 ---
#
# --- Time: 09:01:12.218000 ---
# Parcel 55 removed from outfeed(total system time: 8.08 s)
#
# --- Time: 09:01:12.318000 ---
#
# --- Time: 09:01:12.418000 ---
#
# --- Time: 09:01:12.518000 ---
# Parcel 53 removed from outfeed(total system time: 11.92 s)
#
# --- Time: 09:01:12.618000 ---
#
# --- Time: 09:01:12.718000 ---
#
# --- Time: 09:01:12.818000 ---
#
# --- Time: 09:01:12.918000 ---
# Parcel 78 arrived – feasible outfeeds: [4, 5, 6, 7, 10, 12, 13]
# [DEBUG] Parcel 78 → needed: 0.72, used: 1.41, fits: True
# Parcel 78 sorted to outfeed 4(travel time: 11.92 seconds)
#
# --- Time: 09:01:13.018000 ---
#
# --- Time: 09:01:13.118000 ---
#
# --- Time: 09:01:13.218000 ---
#
# --- Time: 09:01:13.318000 ---
#
# --- Time: 09:01:13.418000 ---
#
# --- Time: 09:01:13.518000 ---
#
# --- Time: 09:01:13.618000 ---
# Parcel 79 arrived – feasible outfeeds: [1, 4, 5, 6, 12]
# [DEBUG] Parcel 79 → needed: 0.64, used: 2.72, fits: False
# [DEBUG] Parcel 79 → needed: 0.64, used: 2.14, fits: True
# Parcel 79 sorted to outfeed 4(travel time: 11.92 seconds)
#
# --- Time: 09:01:13.718000 ---
#
# --- Time: 09:01:13.818000 ---
#
# --- Time: 09:01:13.918000 ---
#
# --- Time: 09:01:14.018000 ---
#
# --- Time: 09:01:14.118000 ---
#
# --- Time: 09:01:14.218000 ---
#
# --- Time: 09:01:14.318000 ---
#
# --- Time: 09:01:14.418000 ---
#
# --- Time: 09:01:14.518000 ---
#
# --- Time: 09:01:14.618000 ---
#
# --- Time: 09:01:14.718000 ---
# Parcel 52 removed from outfeed(total system time: 4.23 s)
#
# --- Time: 09:01:14.818000 ---
# Parcel 80 arrived – feasible outfeeds: [1, 2, 4, 6, 7, 9, 13]
# [DEBUG] Parcel 80 → needed: 0.49, used: 2.72, fits: False
# [DEBUG] Parcel 80 → needed: 0.49, used: 2.21, fits: True
# Parcel 80 sorted to outfeed 2(travel time: 8.08 seconds)
#
# --- Time: 09:01:14.918000 ---
#
# --- Time: 09:01:15.018000 ---
#
# --- Time: 09:01:15.118000 ---
#
# --- Time: 09:01:15.218000 ---
#
# --- Time: 09:01:15.318000 ---
#
# --- Time: 09:01:15.418000 ---
#
# --- Time: 09:01:15.518000 ---
#
# --- Time: 09:01:15.618000 ---
#
# --- Time: 09:01:15.718000 ---
# Parcel 81 arrived – feasible outfeeds: [0, 1, 3, 4, 5, 6, 8, 9, 10, 13, 14]
# [DEBUG] Parcel 81 → needed: 0.54, used: 1.77, fits: True
# Parcel 81 sorted to outfeed 0(travel time: 4.23 seconds)
#
# --- Time: 09:01:15.818000 ---
#
# --- Time: 09:01:15.918000 ---
#
# --- Time: 09:01:16.018000 ---
#
# --- Time: 09:01:16.118000 ---
#
# --- Time: 09:01:16.218000 ---
#
# --- Time: 09:01:16.318000 ---
#
# --- Time: 09:01:16.418000 ---
#
# --- Time: 09:01:16.518000 ---
#
# --- Time: 09:01:16.618000 ---
# Parcel 82 arrived – feasible outfeeds: [4, 9, 10]
# [DEBUG] Parcel 82 → needed: 0.54, used: 2.78, fits: False
# [DEBUG] Parcel 82 → needed: 0.54, used: 0.00, fits: True
# Parcel 82 sorted to outfeed 9(travel time: 21.54 seconds)
#
# --- Time: 09:01:16.718000 ---
#
# --- Time: 09:01:16.818000 ---
#
# --- Time: 09:01:16.918000 ---
#
# --- Time: 09:01:17.018000 ---
# Parcel 65 removed from outfeed(total system time: 10.00 s)
#
# --- Time: 09:01:17.118000 ---
#
# --- Time: 09:01:17.218000 ---
#
# --- Time: 09:01:17.318000 ---
#
# --- Time: 09:01:17.418000 ---
#
# --- Time: 09:01:17.518000 ---
# Parcel 83 arrived – feasible outfeeds: [1, 3, 4, 9, 11, 13]
# [DEBUG] Parcel 83 → needed: 0.68, used: 2.72, fits: False
# [DEBUG] Parcel 83 → needed: 0.68, used: 1.37, fits: True
# Parcel 83 sorted to outfeed 3(travel time: 10.00 seconds)
#
# --- Time: 09:01:17.618000 ---
#
# --- Time: 09:01:17.718000 ---
#
# --- Time: 09:01:17.818000 ---
#
# --- Time: 09:01:17.918000 ---
#
# --- Time: 09:01:18.018000 ---
#
# --- Time: 09:01:18.118000 ---
#
# --- Time: 09:01:18.218000 ---
#
# --- Time: 09:01:18.318000 ---
#
# --- Time: 09:01:18.418000 ---
#
# --- Time: 09:01:18.518000 ---
#
# --- Time: 09:01:18.618000 ---
#
# --- Time: 09:01:18.718000 ---
#
# --- Time: 09:01:18.818000 ---
# Parcel 84 arrived – feasible outfeeds: [1, 5, 6]
# [DEBUG] Parcel 84 → needed: 0.64, used: 2.72, fits: False
# [DEBUG] Parcel 84 → needed: 0.64, used: 0.00, fits: True
# Parcel 84 sorted to outfeed 5(travel time: 13.85 seconds)
# Parcel 56 removed from outfeed(total system time: 8.08 s)
#
# --- Time: 09:01:18.918000 ---
# Parcel 64 removed from outfeed(total system time: 6.15 s)
#
# --- Time: 09:01:19.018000 ---
#
# --- Time: 09:01:19.118000 ---
#
# --- Time: 09:01:19.218000 ---
#
# --- Time: 09:01:19.318000 ---
#
# --- Time: 09:01:19.418000 ---
#
# --- Time: 09:01:19.518000 ---
#
# --- Time: 09:01:19.618000 ---
#
# --- Time: 09:01:19.718000 ---
#
# --- Time: 09:01:19.818000 ---
# Parcel 85 arrived – feasible outfeeds: [1, 4, 6, 9, 10, 12]
# [DEBUG] Parcel 85 → needed: 0.62, used: 1.98, fits: True
# Parcel 85 sorted to outfeed 1(travel time: 6.15 seconds)
#
# --- Time: 09:01:19.918000 ---
#
# --- Time: 09:01:20.018000 ---
#
# --- Time: 09:01:20.118000 ---
#
# --- Time: 09:01:20.218000 ---
#
# --- Time: 09:01:20.318000 ---
#
# --- Time: 09:01:20.418000 ---
#
# --- Time: 09:01:20.518000 ---
#
# --- Time: 09:01:20.618000 ---
# Parcel 86 arrived – feasible outfeeds: [2, 3, 4, 14]
# [DEBUG] Parcel 86 → needed: 0.66, used: 2.12, fits: True
# Parcel 86 sorted to outfeed 2(travel time: 8.08 seconds)
#
# --- Time: 09:01:20.718000 ---
#
# --- Time: 09:01:20.818000 ---
#
# --- Time: 09:01:20.918000 ---
#
# --- Time: 09:01:21.018000 ---
# Parcel 82 removed from outfeed(total system time: 21.54 s)
#
# --- Time: 09:01:21.118000 ---
# Parcel 66 removed from outfeed(total system time: 11.92 s)
#
# --- Time: 09:01:21.218000 ---
#
# --- Time: 09:01:21.318000 ---
#
# --- Time: 09:01:21.418000 ---
#
# --- Time: 09:01:21.518000 ---
# Parcel 87 arrived – feasible outfeeds: [0, 1, 3, 6, 8, 9, 10]
# [DEBUG] Parcel 87 → needed: 0.61, used: 2.31, fits: True
# Parcel 87 sorted to outfeed 0(travel time: 4.23 seconds)
#
# --- Time: 09:01:21.618000 ---
#
# --- Time: 09:01:21.718000 ---
#
# --- Time: 09:01:21.818000 ---
#
# --- Time: 09:01:21.918000 ---
#
# --- Time: 09:01:22.018000 ---
#
# --- Time: 09:01:22.118000 ---
#
# --- Time: 09:01:22.218000 ---
#
# --- Time: 09:01:22.318000 ---
# Parcel 63 removed from outfeed(total system time: 4.23 s)
#
# --- Time: 09:01:22.418000 ---
#
# --- Time: 09:01:22.518000 ---
# Parcel 88 arrived – feasible outfeeds: [1, 2, 6, 8, 13]
# [DEBUG] Parcel 88 → needed: 0.62, used: 2.60, fits: False
# [DEBUG] Parcel 88 → needed: 0.62, used: 2.78, fits: False
# [DEBUG] Parcel 88 → needed: 0.62, used: 0.00, fits: True
# Parcel 88 sorted to outfeed 6(travel time: 15.77 seconds)
#
# --- Time: 09:01:22.618000 ---
# ...
# Parcel 1966 removed from outfeed(total system time: 8.08 s)
#
# --- Time: 09:31:20.318000 ---
#
# --- Time: 09:31:20.418000 ---
#
# --- Time: 09:31:20.518000 ---
#
# --- Time: 09:31:20.618000 ---
#
# --- Time: 09:31:20.718000 ---
#
# --- Time: 09:31:20.818000 ---
# Parcel 1993 arrived – feasible outfeeds: [4, 7, 8, 10, 12]
# [DEBUG] Parcel 1993 → needed: 0.64, used: 2.41, fits: False
# [DEBUG] Parcel 1993 → needed: 0.64, used: -0.00, fits: True
# Parcel 1993 sorted to outfeed 7(travel time: 17.69 seconds)
#
# --- Time: 09:31:20.918000 ---
#
# --- Time: 09:31:21.018000 ---
#
# --- Time: 09:31:21.118000 ---
# Parcel 1962 removed from outfeed(total system time: 4.23 s)
#
# --- Time: 09:31:21.218000 ---
#
# --- Time: 09:31:21.318000 ---
#
# --- Time: 09:31:21.418000 ---
#
# --- Time: 09:31:21.518000 ---
#
# --- Time: 09:31:21.618000 ---
#
# --- Time: 09:31:21.718000 ---
# Parcel 1994 arrived – feasible outfeeds: [3, 5, 6, 9, 10]
# [DEBUG] Parcel 1994 → needed: 0.55, used: 1.96, fits: True
# Parcel 1994 sorted to outfeed 3(travel time: 10.00 seconds)
#
# --- Time: 09:31:21.818000 ---
#
# --- Time: 09:31:21.918000 ---
#
# --- Time: 09:31:22.018000 ---
#
# --- Time: 09:31:22.118000 ---
#
# --- Time: 09:31:22.218000 ---
#
# --- Time: 09:31:22.318000 ---
#
# --- Time: 09:31:22.418000 ---
#
# --- Time: 09:31:22.518000 ---
#
# --- Time: 09:31:22.618000 ---
# Parcel 1985 removed from outfeed(total system time: 13.85 s)
#
# --- Time: 09:31:22.718000 ---
#
# --- Time: 09:31:22.818000 ---
#
# --- Time: 09:31:22.918000 ---
#
# --- Time: 09:31:23.018000 ---
#
# --- Time: 09:31:23.118000 ---
# Parcel 1995 arrived – feasible outfeeds: [0, 12, 14]
# [DEBUG] Parcel 1995 → needed: 0.60, used: 1.89, fits: True
# Parcel 1995 sorted to outfeed 0(travel time: 4.23 seconds)
#
# --- Time: 09:31:23.218000 ---
#
# --- Time: 09:31:23.318000 ---
#
# --- Time: 09:31:23.418000 ---
#
# --- Time: 09:31:23.518000 ---
#
# --- Time: 09:31:23.618000 ---
#
# --- Time: 09:31:23.718000 ---
#
# --- Time: 09:31:23.818000 ---
#
# --- Time: 09:31:23.918000 ---
#
# --- Time: 09:31:24.018000 ---
# Parcel 1996 arrived – feasible outfeeds: [0, 1, 3, 4, 5, 9, 12]
# [DEBUG] Parcel 1996 → needed: 0.66, used: 2.49, fits: False
# [DEBUG] Parcel 1996 → needed: 0.66, used: 2.41, fits: False
# [DEBUG] Parcel 1996 → needed: 0.66, used: 2.51, fits: False
# [DEBUG] Parcel 1996 → needed: 0.66, used: 2.41, fits: False
# [DEBUG] Parcel 1996 → needed: 0.66, used: 0.60, fits: True
# Parcel 1996 sorted to outfeed 5(travel time: 13.85 seconds)
#
# --- Time: 09:31:24.118000 ---
# Parcel 1975 removed from outfeed(total system time: 10.00 s)
#
# --- Time: 09:31:24.218000 ---
#
# --- Time: 09:31:24.318000 ---
#
# --- Time: 09:31:24.418000 ---
# Parcel 1977 removed from outfeed(total system time: 15.77 s)
#
# --- Time: 09:31:24.518000 ---
#
# --- Time: 09:31:24.618000 ---
#
# --- Time: 09:31:24.718000 ---
# Parcel 1970 removed from outfeed(total system time: 8.08 s)
#
# --- Time: 09:31:24.818000 ---
#
# --- Time: 09:31:24.918000 ---
#
# --- Time: 09:31:25.018000 ---
#
# --- Time: 09:31:25.118000 ---
#
# --- Time: 09:31:25.218000 ---
#
# --- Time: 09:31:25.318000 ---
# Parcel 1973 removed from outfeed(total system time: 11.92 s)
#
# --- Time: 09:31:25.418000 ---
#
# --- Time: 09:31:25.518000 ---
# Parcel 1997 arrived – feasible outfeeds: [0, 4, 6, 9, 11, 12]
# [DEBUG] Parcel 1997 → needed: 0.55, used: 2.49, fits: False
# [DEBUG] Parcel 1997 → needed: 0.55, used: 1.84, fits: True
# Parcel 1997 sorted to outfeed 4(travel time: 11.92 seconds)
#
# --- Time: 09:31:25.618000 ---
# Parcel 1965 removed from outfeed(total system time: 6.15 s)
#
# --- Time: 09:31:25.718000 ---
#
# --- Time: 09:31:25.818000 ---
#
# --- Time: 09:31:25.918000 ---
#
# --- Time: 09:31:26.018000 ---
#
# --- Time: 09:31:26.118000 ---
#
# --- Time: 09:31:26.218000 ---
#
# --- Time: 09:31:26.318000 ---
#
# --- Time: 09:31:26.418000 ---
# Parcel 1998 arrived – feasible outfeeds: [1, 6, 9, 10, 13]
# [DEBUG] Parcel 1998 → needed: 0.52, used: 1.80, fits: True
# Parcel 1998 sorted to outfeed 1(travel time: 6.15 seconds)
#
# --- Time: 09:31:26.518000 ---
#
# --- Time: 09:31:26.618000 ---
#
# --- Time: 09:31:26.718000 ---
#
# --- Time: 09:31:26.818000 ---
#
# --- Time: 09:31:26.918000 ---
#
# --- Time: 09:31:27.018000 ---
#
# --- Time: 09:31:27.118000 ---
#
# --- Time: 09:31:27.218000 ---
#
# --- Time: 09:31:27.318000 ---
# Parcel 1999 arrived – feasible outfeeds: [0, 2, 4, 8, 9, 10, 11, 13]
# [DEBUG] Parcel 1999 → needed: 0.59, used: 2.49, fits: False
# [DEBUG] Parcel 1999 → needed: 0.59, used: 1.40, fits: True
# Parcel 1999 sorted to outfeed 2(travel time: 8.08 seconds)
#
# --- Time: 09:31:27.418000 ---
#
# --- Time: 09:31:27.518000 ---
#
# --- Time: 09:31:27.618000 ---
#
# --- Time: 09:31:27.718000 ---
# Parcel 1978 removed from outfeed(total system time: 4.23 s)
#
# --- Time: 09:31:27.818000 ---
#
# --- Time: 09:31:27.918000 ---
#
# --- Time: 09:31:28.018000 ---
#
# --- Time: 09:31:28.118000 ---
#
# --- Time: 09:31:28.218000 ---
# Parcel 1991 removed from outfeed(total system time: 13.85 s)
#
# --- Time: 09:31:28.318000 ---
# Parcel 2000 arrived – feasible outfeeds: [0, 1, 2, 4, 6, 9, 10, 13]
# [DEBUG] Parcel 2000 → needed: 0.68, used: 1.89, fits: True
# Parcel 2000 sorted to outfeed 0(travel time: 4.23 seconds)
# Parcel 1993 removed from outfeed(total system time: 17.69 s)
#
# --- Time: 09:31:28.418000 ---
#
# --- Time: 09:31:28.518000 ---
#
# --- Time: 09:31:28.618000 ---
#
# --- Time: 09:31:28.718000 ---
#
# --- Time: 09:31:28.818000 ---
#
# --- Time: 09:31:28.918000 ---
#
# --- Time: 09:31:29.018000 ---
#
# --- Time: 09:31:29.118000 ---
#
# --- Time: 09:31:29.218000 ---
#
# --- Time: 09:31:29.318000 ---
#
# --- Time: 09:31:29.418000 ---
#
# --- Time: 09:31:29.518000 ---
#
# --- Time: 09:31:29.618000 ---
#
# --- Time: 09:31:29.718000 ---
#
# --- Time: 09:31:29.818000 ---
#
# --- Time: 09:31:29.918000 ---
#
# --- Time: 09:31:30.018000 ---
#
# --- Time: 09:31:30.118000 ---
#
# --- Time: 09:31:30.218000 ---
#
# --- Time: 09:31:30.318000 ---
#
# --- Time: 09:31:30.418000 ---
#
# --- Time: 09:31:30.518000 ---
#
# --- Time: 09:31:30.618000 ---
#
# --- Time: 09:31:30.718000 ---
#
# --- Time: 09:31:30.818000 ---
#
# --- Time: 09:31:30.918000 ---
#
# --- Time: 09:31:31.018000 ---
#
# --- Time: 09:31:31.118000 ---
#
# --- Time: 09:31:31.218000 ---
#
# --- Time: 09:31:31.318000 ---
#
# --- Time: 09:31:31.418000 ---
#
# --- Time: 09:31:31.518000 ---
#
# --- Time: 09:31:31.618000 ---
#
# --- Time: 09:31:31.718000 ---
# Parcel 1979 removed from outfeed(total system time: 10.00 s)
#
# --- Time: 09:31:31.818000 ---
#
# --- Time: 09:31:31.918000 ---
#
# --- Time: 09:31:32.018000 ---
# Parcel 1992 removed from outfeed(total system time: 15.77 s)
#
# --- Time: 09:31:32.118000 ---
#
# --- Time: 09:31:32.218000 ---
# Parcel 1972 removed from outfeed(total system time: 6.15 s)
#
# --- Time: 09:31:32.318000 ---
# Parcel 1980 removed from outfeed(total system time: 8.08 s)
#
# --- Time: 09:31:32.418000 ---
#
# --- Time: 09:31:32.518000 ---
#
# --- Time: 09:31:32.618000 ---
#
# --- Time: 09:31:32.718000 ---
#
# --- Time: 09:31:32.818000 ---
#
# --- Time: 09:31:32.918000 ---
# Parcel 1982 removed from outfeed(total system time: 11.92 s)
#
# --- Time: 09:31:33.018000 ---
#
# --- Time: 09:31:33.118000 ---
#
# --- Time: 09:31:33.218000 ---
#
# --- Time: 09:31:33.318000 ---
#
# --- Time: 09:31:33.418000 ---
#
# --- Time: 09:31:33.518000 ---
#
# --- Time: 09:31:33.618000 ---
#
# --- Time: 09:31:33.718000 ---
#
# --- Time: 09:31:33.818000 ---
#
# --- Time: 09:31:33.918000 ---
#
# --- Time: 09:31:34.018000 ---
#
# --- Time: 09:31:34.118000 ---
#
# --- Time: 09:31:34.218000 ---
#
# --- Time: 09:31:34.318000 ---
#
# --- Time: 09:31:34.418000 ---
#
# --- Time: 09:31:34.518000 ---
#
# --- Time: 09:31:34.618000 ---
#
# --- Time: 09:31:34.718000 ---
#
# --- Time: 09:31:34.818000 ---
# Parcel 1996 removed from outfeed(total system time: 13.85 s)
#
# --- Time: 09:31:34.918000 ---
#
# --- Time: 09:31:35.018000 ---
#
# --- Time: 09:31:35.118000 ---
#
# --- Time: 09:31:35.218000 ---
#
# --- Time: 09:31:35.318000 ---
# Parcel 1981 removed from outfeed(total system time: 4.23 s)
#
# --- Time: 09:31:35.418000 ---
#
# --- Time: 09:31:35.518000 ---
#
# --- Time: 09:31:35.618000 ---
#
# --- Time: 09:31:35.718000 ---
#
# --- Time: 09:31:35.818000 ---
#
# --- Time: 09:31:35.918000 ---
#
# --- Time: 09:31:36.018000 ---
#
# --- Time: 09:31:36.118000 ---
#
# --- Time: 09:31:36.218000 ---
#
# --- Time: 09:31:36.318000 ---
#
# --- Time: 09:31:36.418000 ---
#
# --- Time: 09:31:36.518000 ---
#
# --- Time: 09:31:36.618000 ---
#
# --- Time: 09:31:36.718000 ---
#
# --- Time: 09:31:36.818000 ---
#
# --- Time: 09:31:36.918000 ---
#
# --- Time: 09:31:37.018000 ---
#
# --- Time: 09:31:37.118000 ---
#
# --- Time: 09:31:37.218000 ---
#
# --- Time: 09:31:37.318000 ---
#
# --- Time: 09:31:37.418000 ---
#
# --- Time: 09:31:37.518000 ---
#
# --- Time: 09:31:37.618000 ---
#
# --- Time: 09:31:37.718000 ---
#
# --- Time: 09:31:37.818000 ---
# Parcel 1983 removed from outfeed(total system time: 6.15 s)
#
# --- Time: 09:31:37.918000 ---
#
# --- Time: 09:31:38.018000 ---
#
# --- Time: 09:31:38.118000 ---
#
# --- Time: 09:31:38.218000 ---
#
# --- Time: 09:31:38.318000 ---
#
# --- Time: 09:31:38.418000 ---
#
# --- Time: 09:31:38.518000 ---
# Parcel 1984 removed from outfeed(total system time: 11.92 s)
#
# --- Time: 09:31:38.618000 ---
#
# --- Time: 09:31:38.718000 ---
#
# --- Time: 09:31:38.818000 ---
#
# --- Time: 09:31:38.918000 ---
#
# --- Time: 09:31:39.018000 ---
#
# --- Time: 09:31:39.118000 ---
#
# --- Time: 09:31:39.218000 ---
#
# --- Time: 09:31:39.318000 ---
# Parcel 1986 removed from outfeed(total system time: 10.00 s)
#
# --- Time: 09:31:39.418000 ---
#
# --- Time: 09:31:39.518000 ---
#
# --- Time: 09:31:39.618000 ---
#
# --- Time: 09:31:39.718000 ---
#
# --- Time: 09:31:39.818000 ---
#
# --- Time: 09:31:39.918000 ---
#
# --- Time: 09:31:40.018000 ---
#
# --- Time: 09:31:40.118000 ---
#
# --- Time: 09:31:40.218000 ---
#
# --- Time: 09:31:40.318000 ---
#
# --- Time: 09:31:40.418000 ---
#
# --- Time: 09:31:40.518000 ---
#
# --- Time: 09:31:40.618000 ---
#
# --- Time: 09:31:40.718000 ---
#
# --- Time: 09:31:40.818000 ---
#
# --- Time: 09:31:40.918000 ---
# Parcel 1987 removed from outfeed(total system time: 8.08 s)
#
# --- Time: 09:31:41.018000 ---
#
# --- Time: 09:31:41.118000 ---
#
# --- Time: 09:31:41.218000 ---
#
# --- Time: 09:31:41.318000 ---
#
# --- Time: 09:31:41.418000 ---
#
# --- Time: 09:31:41.518000 ---
#
# --- Time: 09:31:41.618000 ---
#
# --- Time: 09:31:41.718000 ---
#
# --- Time: 09:31:41.818000 ---
#
# --- Time: 09:31:41.918000 ---
# Parcel 1989 removed from outfeed(total system time: 4.23 s)
#
# --- Time: 09:31:42.018000 ---
#
# --- Time: 09:31:42.118000 ---
#
# --- Time: 09:31:42.218000 ---
#
# --- Time: 09:31:42.318000 ---
#
# --- Time: 09:31:42.418000 ---
#
# --- Time: 09:31:42.518000 ---
#
# --- Time: 09:31:42.618000 ---
#
# --- Time: 09:31:42.718000 ---
#
# --- Time: 09:31:42.818000 ---
#
# --- Time: 09:31:42.918000 ---
#
# --- Time: 09:31:43.018000 ---
# Parcel 1990 removed from outfeed(total system time: 11.92 s)
#
# --- Time: 09:31:43.118000 ---
#
# --- Time: 09:31:43.218000 ---
#
# --- Time: 09:31:43.318000 ---
#
# --- Time: 09:31:43.418000 ---
# Parcel 1988 removed from outfeed(total system time: 6.15 s)
#
# --- Time: 09:31:43.518000 ---
#
# --- Time: 09:31:43.618000 ---
#
# --- Time: 09:31:43.718000 ---
#
# --- Time: 09:31:43.818000 ---
#
# --- Time: 09:31:43.918000 ---
#
# --- Time: 09:31:44.018000 ---
#
# --- Time: 09:31:44.118000 ---
#
# --- Time: 09:31:44.218000 ---
#
# --- Time: 09:31:44.318000 ---
#
# --- Time: 09:31:44.418000 ---
#
# --- Time: 09:31:44.518000 ---
#
# --- Time: 09:31:44.618000 ---
#
# --- Time: 09:31:44.718000 ---
#
# --- Time: 09:31:44.818000 ---
#
# --- Time: 09:31:44.918000 ---
#
# --- Time: 09:31:45.018000 ---
#
# --- Time: 09:31:45.118000 ---
#
# --- Time: 09:31:45.218000 ---
#
# --- Time: 09:31:45.318000 ---
#
# --- Time: 09:31:45.418000 ---
#
# --- Time: 09:31:45.518000 ---
#
# --- Time: 09:31:45.618000 ---
#
# --- Time: 09:31:45.718000 ---
#
# --- Time: 09:31:45.818000 ---
#
# --- Time: 09:31:45.918000 ---
#
# --- Time: 09:31:46.018000 ---
#
# --- Time: 09:31:46.118000 ---
#
# --- Time: 09:31:46.218000 ---
#
# --- Time: 09:31:46.318000 ---
#
# --- Time: 09:31:46.418000 ---
#
# --- Time: 09:31:46.518000 ---
#
# --- Time: 09:31:46.618000 ---
#
# --- Time: 09:31:46.718000 ---
#
# --- Time: 09:31:46.818000 ---
#
# --- Time: 09:31:46.918000 ---
# Parcel 1994 removed from outfeed(total system time: 10.00 s)
#
# --- Time: 09:31:47.018000 ---
#
# --- Time: 09:31:47.118000 ---
#
# --- Time: 09:31:47.218000 ---
#
# --- Time: 09:31:47.318000 ---
#
# --- Time: 09:31:47.418000 ---
#
# --- Time: 09:31:47.518000 ---
# Parcel 1995 removed from outfeed(total system time: 4.23 s)
# Parcel 1999 removed from outfeed(total system time: 8.08 s)
#
# --- Time: 09:31:47.618000 ---
#
# --- Time: 09:31:47.718000 ---
#
# --- Time: 09:31:47.818000 ---
#
# --- Time: 09:31:47.918000 ---
#
# --- Time: 09:31:48.018000 ---
#
# --- Time: 09:31:48.118000 ---
#
# --- Time: 09:31:48.218000 ---
#
# --- Time: 09:31:48.318000 ---
#
# --- Time: 09:31:48.418000 ---
#
# --- Time: 09:31:48.518000 ---
#
# --- Time: 09:31:48.618000 ---
#
# --- Time: 09:31:48.718000 ---
#
# --- Time: 09:31:48.818000 ---
#
# --- Time: 09:31:48.918000 ---
#
# --- Time: 09:31:49.018000 ---
#
# --- Time: 09:31:49.118000 ---
#
# --- Time: 09:31:49.218000 ---
#
# --- Time: 09:31:49.318000 ---
#
# --- Time: 09:31:49.418000 ---
#
# --- Time: 09:31:49.518000 ---
#
# --- Time: 09:31:49.618000 ---
#
# --- Time: 09:31:49.718000 ---
#
# --- Time: 09:31:49.818000 ---
#
# --- Time: 09:31:49.918000 ---
#
# --- Time: 09:31:50.018000 ---
# Parcel 1998 removed from outfeed(total system time: 6.15 s)
#
# --- Time: 09:31:50.118000 ---
#
# --- Time: 09:31:50.218000 ---
#
# --- Time: 09:31:50.318000 ---
#
# --- Time: 09:31:50.418000 ---
#
# --- Time: 09:31:50.518000 ---
#
# --- Time: 09:31:50.618000 ---
# Parcel 1997 removed from outfeed(total system time: 11.92 s)
#
# --- Time: 09:31:50.718000 ---
#
# --- Time: 09:31:50.818000 ---
#
# --- Time: 09:31:50.918000 ---
#
# --- Time: 09:31:51.018000 ---
#
# --- Time: 09:31:51.118000 ---
#
# --- Time: 09:31:51.218000 ---
#
# --- Time: 09:31:51.318000 ---
#
# --- Time: 09:31:51.418000 ---
#
# --- Time: 09:31:51.518000 ---
#
# --- Time: 09:31:51.618000 ---
#
# --- Time: 09:31:51.718000 ---
#
# --- Time: 09:31:51.818000 ---
#
# --- Time: 09:31:51.918000 ---
#
# --- Time: 09:31:52.018000 ---
#
# --- Time: 09:31:52.118000 ---
#
# --- Time: 09:31:52.218000 ---
#
# --- Time: 09:31:52.318000 ---
#
# --- Time: 09:31:52.418000 ---
#
# --- Time: 09:31:52.518000 ---
#
# --- Time: 09:31:52.618000 ---
#
# --- Time: 09:31:52.718000 ---
#
# --- Time: 09:31:52.818000 ---
#
# --- Time: 09:31:52.918000 ---
#
# --- Time: 09:31:53.018000 ---
#
# --- Time: 09:31:53.118000 ---
#
# --- Time: 09:31:53.218000 ---
#
# --- Time: 09:31:53.318000 ---
#
# --- Time: 09:31:53.418000 ---
#
# --- Time: 09:31:53.518000 ---
#
# --- Time: 09:31:53.618000 ---
#
# --- Time: 09:31:53.718000 ---
#
# --- Time: 09:31:53.818000 ---
#
# --- Time: 09:31:53.918000 ---
#
# --- Time: 09:31:54.018000 ---
#
# --- Time: 09:31:54.118000 ---
#
# --- Time: 09:31:54.218000 ---
#
# --- Time: 09:31:54.318000 ---
#
# --- Time: 09:31:54.418000 ---
#
# --- Time: 09:31:54.518000 ---
#
# --- Time: 09:31:54.618000 ---
#
# --- Time: 09:31:54.718000 ---
#
# --- Time: 09:31:54.818000 ---
#
# --- Time: 09:31:54.918000 ---
#
# --- Time: 09:31:55.018000 ---
#
# --- Time: 09:31:55.118000 ---
#
# --- Time: 09:31:55.218000 ---
#
# --- Time: 09:31:55.318000 ---
#
# --- Time: 09:31:55.418000 ---
#
# --- Time: 09:31:55.518000 ---
#
# --- Time: 09:31:55.618000 ---
#
# --- Time: 09:31:55.718000 ---
#
# --- Time: 09:31:55.818000 ---
#
# --- Time: 09:31:55.918000 ---
#
# --- Time: 09:31:56.018000 ---
#
# --- Time: 09:31:56.118000 ---
# Parcel 2000 removed from outfeed(total system time: 4.23 s)
#
# --- Time: 09:31:56.218000 ---
#
# --- Time: 09:31:56.318000 ---
#
# --- Time: 09:31:56.418000 ---
#
# --- Time: 09:31:56.518000 ---
#
# --- Time: 09:31:56.618000 ---
#
# --- Time: 09:31:56.718000 ---
#
# --- Time: 09:31:56.818000 ---
#
# --- Time: 09:31:56.918000 ---
#
# --- Time: 09:31:57.018000 ---
#
# --- Time: 09:31:57.118000 ---
#
# --- Time: 09:31:57.218000 ---
#
# --- Time: 09:31:57.318000 ---
#
# --- Time: 09:31:57.418000 ---
#
# --- Time: 09:31:57.518000 ---
#
# --- Time: 09:31:57.618000 ---
#
# --- Time: 09:31:57.718000 ---
#
# --- Time: 09:31:57.818000 ---
#
# --- Time: 09:31:57.918000 ---
#
# --- Time: 09:31:58.018000 ---
#
# --- Time: 09:31:58.118000 ---
#
# --- Time: 09:31:58.218000 ---
#
# --- Simulation Summary ---
# Total parcels processed: 1991
# Parcels sorted: 1985
# Parcels recirculated: 6
# Sorting success rate: 99.70%
# Average total system time per parcel: 10.47 seconds
#
# --- Removed Parcels ---
# Initial amount of parcels: 2000
# Removed due to NaNs: 0
# Removed due to extreme outliers (data entry errors): 4
# Removed due to no feasible outfeeds: 2
# Removed due to non-chronological arrival times (scanning error): 3
# Total parcels removed before processing: 9
