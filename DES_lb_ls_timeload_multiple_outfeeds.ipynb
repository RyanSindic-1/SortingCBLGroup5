# %%
import heapq
import pandas as pd
import random
from datetime import datetime, timedelta
from collections import deque

# --------------------------------------------------------------------------
# DATA CLEANING FUNCTIONS
# --------------------------------------------------------------------------
def remove_outliers_iqr(df, cols):
    for c in cols:
        Q1, Q3 = df[c].quantile([0.25, 0.75])
        IQR = Q3 - Q1
        df = df[df[c].between(Q1 - 2 * IQR, Q3 + 2 * IQR)]
    return df

def drop_rows_without_true_outfeed(df, prefix="Outfeed"):
    cols = [c for c in df.columns if c.startswith(prefix)]
    return df[df[cols].any(axis=1)] if cols else df

def clean_parcel_data(df):
    df = df.dropna().reset_index(drop=True)
    df = remove_outliers_iqr(df, ["Length", "Width", "Height"])
    df = drop_rows_without_true_outfeed(df)
    return df

def load_parcels_from_clean_df(df):
    parcels = []
    # 1) Find every column that starts with "Outfeed " and sort by the numeric suffix
    outfeed_columns = sorted(
        [col for col in df.columns if col.startswith("Outfeed ")],
        key=lambda c: int(c.split(" ")[1])
    )
    # 2) Now 'num_outfeeds' is simply how many of those columns exist
    num_outfeeds = len(outfeed_columns)

    # 3) For each row, record the parcel attributes + any outfeed columns that are True/1
    for _, r in df.iterrows():
        # Build a list of indices [0..num_outfeeds-1] where that column is truthy
        feasible = [
            idx
            for idx, col_name in enumerate(outfeed_columns)
            if bool(r[col_name])
        ]
        parcels.append(
            Parcel(
                pid=int(r["Parcel Number"]),
                arrival_time=pd.to_datetime(r["Arrival Time"]),
                length=float(r["Length"]),
                width=float(r["Width"]),
                height=float(r["Height"]),
                weight=float(r["Weight"]),
                feasible=feasible
            )
        )

    # 4) Return the parcels sorted by arrival_time, plus how many outfeeds we found
    return sorted(parcels, key=lambda p: p.arrival_time), num_outfeeds

# --------------------------------------------------------------------------
# EVENT, FES, PARCEL
# --------------------------------------------------------------------------
class Event:
    ARRIVAL = 0
    ENTER_SCANNER = 1
    ENTER_OUTFEED = 2
    EXIT_OUTFEED = 3
    RECIRCULATE = 4
    def __init__(self, typ, time, parcel, outfeed_id=None):
        self.type = typ
        self.time = time
        self.parcel = parcel
        self.outfeed_id = outfeed_id
    def __lt__(self, other):
        return self.time < other.time

class FES:
    def __init__(self): self.events = []
    def add(self, e): heapq.heappush(self.events, e)
    def next(self): return heapq.heappop(self.events)
    def isEmpty(self): return not self.events

class Parcel:
    def __init__(self, pid, arrival_time, length, width, height, weight, feasible):
        self.id = pid
        self.arrival_time = arrival_time
        self.length = length
        self.width = width
        self.height = height
        self.weight = weight
        self.feasible_outfeeds = feasible
        self.recirculation_count = 0
    def get_volume(self): return self.length * self.width * self.height

# --------------------------------------------------------------------------
# OUTFEED MODEL
# --------------------------------------------------------------------------
def compute_outfeed_time(parcel):
    base_time = 4.5
    volume = parcel.get_volume()
    if volume < 0.035:
        volume_class_delay = 0
    elif volume < 0.055:
        volume_class_delay = 1
    else:
        volume_class_delay = 2
    weight = parcel.weight
    if weight < 1700:
        weight_class_delay = 0
    elif weight < 2800:
        weight_class_delay = 1
    else:
        weight_class_delay = 2
    return base_time + volume_class_delay + weight_class_delay

class Outfeed:
    def __init__(self, max_length=4.5):
        self.max_length = max_length
        self.current_length = 0.0
        self.queue = []   # list of (Parcel, service_time)
        self.next_time = 0.0
    def can_accept(self, parcel):
        return self.current_length + parcel.length <= self.max_length
    def add_parcel(self, parcel):
        service_t = compute_outfeed_time(parcel)
        self.queue.append((parcel, service_t))
        self.current_length += parcel.length
        if len(self.queue) == 1:
            self.next_time = service_t
        return service_t
    def update(self, dt):
        self.next_time -= dt
        if self.next_time <= 0 and self.queue:
            p, _ = self.queue.pop(0)
            self.current_length -= p.length
            if self.queue:
                self.next_time = self.queue[0][1]

# --------------------------------------------------------------------------
# POSISORTER WITH TIME-BASED LOAD BALANCING
# --------------------------------------------------------------------------
class PosiSorterSystem:
    REBALANCE_INTERVAL = 100  # (you already set this high)
    
    def __init__(self, layout_df, num_outfeeds):
        L = layout_df.set_index("Layout property")["Value"]
        self.belt_speed = L["Belt Speed"]
        self.d_in_sc = L["Distance Infeeds to Scanner"]
        self.d_sc_of = L["Distance Scanner to Outfeeds"]
        self.d_between = L["Distance between Outfeeds"]
        self.d_of_in = L["Distance Outfeeds to Infeeds"]
        self.num_outfeeds = num_outfeeds
        
        # Create each outfeed with the given max_length
        self.outfeeds = [Outfeed() for _ in range(self.num_outfeeds)]
        
        # Statistics
        self.recirculated_count = 0
        self.outfeed_counts = [0] * self.num_outfeeds
        self.first_pass_failures = set()
        
        # Load‐balancing structures
        self.loads = {k: 0.0 for k in range(self.num_outfeeds)}
        self.service_times = {}   # parcel.id → service_time
        self.assignment = {}      # parcel.id → outfeed index (or None)
        
        # Sliding window to hold (arrival_to_scanner_time, Parcel)
        self.WINDOW_DURATION = self.d_sc_of / self.belt_speed
        self.window = deque()
        self.rebal_ctr = 0

    def greedy(self, p):
        feas = [k for k in p.feasible_outfeeds if self.outfeeds[k].can_accept(p)]
        if not feas:
            return None
        return min(feas, key=lambda k: self.loads[k])

    def imbalance(self, loads):
        return max(loads.values()) - min(loads.values())

    def run_local_search(self, max_iters=100):
        loads = self.loads.copy()
        assign_w = {}
        # 1) Greedy‐initialize assignments within the current window
        for _, p in self.window:
            k = self.greedy(p)
            assign_w[p.id] = k
            if k is not None:
                loads[k] += self.service_times.get(p.id, 0)
        # 2) Hill‐climb to reduce max(loads)-min(loads)
        for _ in range(max_iters):
            improved = False
            for _, p in self.window:
                cur = assign_w[p.id]
                for k in p.feasible_outfeeds:
                    if k == cur or not self.outfeeds[k].can_accept(p):
                        continue
                    st = self.service_times.get(p.id, 0)
                    new_loads = loads.copy()
                    if cur is not None:
                        new_loads[cur] -= st
                    new_loads[k] += st
                    if self.imbalance(new_loads) < self.imbalance(loads):
                        loads, assign_w[p.id] = new_loads, k
                        improved = True
                        break
                if improved:
                    break
            if not improved:
                break
        # 3) Write the (possibly rebalanced) assignments back
        for pid, k in assign_w.items():
            self.assignment[pid] = k

    def handle_enter_scanner(self, evt, fes):
        p = evt.parcel
        
        k0 = self.greedy(p)
        self.assignment[p.id] = k0
        if k0 is None:
            # If it can fit but all channels are currently “full,” record first‐pass failure
            # and schedule a recirculation below.
            self.first_pass_failures.add(p.id)

        # Update the sliding window with the current time and parcel
        self.window.append((evt.time, p))
        while self.window and (evt.time - self.window[0][0] > self.WINDOW_DURATION):
            self.window.popleft()

        self.rebal_ctr += 1
        if self.rebal_ctr >= self.REBALANCE_INTERVAL:
            self.run_local_search()
            self.rebal_ctr = 0

        # If we have a feasible outfeed, schedule the parcel to enter it
        t = evt.time
        if k0 is None:
            # It can physically fit on some outfeed eventually, but none are open right now.
            self.recirculated_count += 1
            dt = (self.d_sc_of + self.d_between * self.num_outfeeds) / self.belt_speed
            fes.add(Event(Event.RECIRCULATE, t + dt, p))
        else:
            # Schedule the time it takes to travel from scanner to the chosen outfeed gate
            dt = (self.d_sc_of + k0 * self.d_between) / self.belt_speed
            fes.add(Event(Event.ENTER_OUTFEED, t + dt, p, outfeed_id=k0))

    def simulate(self, parcels):
        fes = FES()
        t0 = parcels[0].arrival_time

        # Seed all ARRIVAL events (times relative to t0)
        for p in parcels:
            delta = (p.arrival_time - t0).total_seconds()
            fes.add(Event(Event.ARRIVAL, delta, p))

        # Main event loop
        while not fes.isEmpty():
            e = fes.next()

            if e.type == Event.ARRIVAL:
                # Parcel travels from inlet to scanner
                dt = self.d_in_sc / self.belt_speed
                fes.add(Event(Event.ENTER_SCANNER, e.time + dt, e.parcel))

            elif e.type == Event.ENTER_SCANNER:
                # Parcel arrives at scanner; pick an outfeed or recirculate
                self.handle_enter_scanner(e, fes)

            elif e.type == Event.ENTER_OUTFEED:
                k, p = e.outfeed_id, e.parcel
                f = self.outfeeds[k]
                st = f.add_parcel(p)
                self.service_times[p.id] = st
                self.outfeed_counts[k] += 1
                self.loads[k] += st

                #Only if this parcel is now the first in the queue
                if len(f.queue) == 1:
                    # plan for the exit of this parcel
                    fes.add(Event(Event.EXIT_OUTFEED, e.time + st, p, outfeed_id=k))

                actual_enter = t0 + timedelta(seconds=e.time)
                print(
                    f"[{actual_enter.time()}] "
                    f"Parcel {p.id} ENTERS outfeed {k} with service_time={st:.3f}s"
                )

            elif e.type == Event.EXIT_OUTFEED:
                k, p = e.outfeed_id, e.parcel
                f = self.outfeeds[k]
                f.update(f.next_time)
                self.loads[k] -= self.service_times.pop(p.id)

                actual_time = t0 + timedelta(seconds=e.time)
                print(f"[{actual_time.time()}] Parcel {p.id} removed from outfeed {k}")
                if f.queue:
                # plan next exit if queue is not empty
                    fes.add(Event(Event.EXIT_OUTFEED, e.time + f.queue[0][1], f.queue[0][0], outfeed_id=k))
            elif e.type == Event.RECIRCULATE:
                # Parcel travels from the outfeed end all the way back to the scanner
                dt = (self.d_of_in + self.d_in_sc) / self.belt_speed
                fes.add(Event(Event.ENTER_SCANNER, e.time + dt, e.parcel))
        # stats
        total=len(parcels); sorted_total=sum(self.outfeed_counts)
        success=(total-len(self.first_pass_failures))/total*100
        print(f"\nTotal parcels: {total}")
        print(f"Recirculated: {self.recirculated_count}")
        print(f"Success rate: {success:.2f}%")
        for i,c in enumerate(self.outfeed_counts):
            pct=c/sorted_total*100 if sorted_total else 0
            print(f"Outfeed {i}: {c} parcels, {pct:.2f}%")
        print(f"Throughput: {sorted_total+self.recirculated_count}")

if __name__=="__main__":
    xls=pd.ExcelFile("PosiSorterData2(1).xlsx")
    df_p=clean_parcel_data(xls.parse("Parcels"))
    df_l=xls.parse("Layout")
    parcels, num_outfeeds =load_parcels_from_clean_df(df_p)
    system=PosiSorterSystem(df_l, num_outfeeds)
    system.simulate(parcels)
# Out:
# [09:00:15.615385] Parcel 277 ENTERS outfeed 0 with service_time=8.500s
# [09:00:16.481385] Parcel 2 ENTERS outfeed 0 with service_time=8.500s
# [09:00:17.171846] Parcel 1 ENTERS outfeed 1 with service_time=8.500s
# [09:00:18.943846] Parcel 3 ENTERS outfeed 1 with service_time=6.500s
# [09:00:20.012846] Parcel 4 ENTERS outfeed 1 with service_time=8.500s
# [09:00:20.230769] Parcel 1926 ENTERS outfeed 3 with service_time=6.500s
# [09:00:21.059846] Parcel 5 ENTERS outfeed 1 with service_time=8.500s
# [09:00:23.307692] Parcel 1585 ENTERS outfeed 5 with service_time=7.500s
# [09:00:24.115385] Parcel 277 removed from outfeed 0
# [09:00:25.220308] Parcel 8 ENTERS outfeed 2 with service_time=7.500s
# [09:00:25.671846] Parcel 1 removed from outfeed 1
# [09:00:26.099308] Parcel 9 ENTERS outfeed 2 with service_time=8.500s
# [09:00:26.730769] Parcel 1926 removed from outfeed 3
# [09:00:27.400231] Parcel 7 ENTERS outfeed 4 with service_time=7.500s
# [09:00:28.135308] Parcel 11 ENTERS outfeed 2 with service_time=6.500s
# [09:00:28.623769] Parcel 10 ENTERS outfeed 3 with service_time=7.500s
# [09:00:28.955308] Parcel 12 ENTERS outfeed 2 with service_time=7.500s
# [09:00:30.807692] Parcel 1585 removed from outfeed 5
# [09:00:30.817308] Parcel 14 ENTERS outfeed 2 with service_time=6.500s
# [09:00:31.142615] Parcel 6 ENTERS outfeed 7 with service_time=8.500s
# [09:00:32.171846] Parcel 3 removed from outfeed 1
# [09:00:32.615385] Parcel 2 removed from outfeed 0
# [09:00:32.720308] Parcel 8 removed from outfeed 2
# [09:00:32.895231] Parcel 13 ENTERS outfeed 4 with service_time=8.500s
# [09:00:34.761231] Parcel 15 ENTERS outfeed 4 with service_time=8.500s
# [09:00:34.900231] Parcel 7 removed from outfeed 4
# [09:00:35.705231] Parcel 16 ENTERS outfeed 4 with service_time=8.500s
# [09:00:36.123769] Parcel 10 removed from outfeed 3
# [09:00:36.589231] Parcel 17 ENTERS outfeed 4 with service_time=8.500s
# [09:00:36.748385] Parcel 24 ENTERS outfeed 0 with service_time=8.500s
# [09:00:37.547385] Parcel 25 ENTERS outfeed 0 with service_time=8.500s
# [09:00:39.642615] Parcel 6 removed from outfeed 7
# [09:00:40.593385] Parcel 28 ENTERS outfeed 0 with service_time=7.500s
# [09:00:40.623154] Parcel 18 ENTERS outfeed 6 with service_time=8.500s
# [09:00:40.671846] Parcel 4 removed from outfeed 1
# [09:00:41.220308] Parcel 9 removed from outfeed 2
# [09:00:41.381154] Parcel 19 ENTERS outfeed 6 with service_time=7.500s
# [09:00:43.060154] Parcel 21 ENTERS outfeed 6 with service_time=8.500s
# [09:00:43.400231] Parcel 13 removed from outfeed 4
# [09:00:44.146154] Parcel 22 ENTERS outfeed 6 with service_time=8.500s
# [09:00:45.060154] Parcel 23 ENTERS outfeed 6 with service_time=7.500s
# [09:00:45.248385] Parcel 24 removed from outfeed 0
# [09:00:46.895538] Parcel 20 ENTERS outfeed 9 with service_time=8.500s
# [09:00:47.720308] Parcel 11 removed from outfeed 2
# [09:00:48.794769] Parcel 32 ENTERS outfeed 3 with service_time=7.500s
# [09:00:48.818154] Parcel 27 ENTERS outfeed 6 with service_time=7.500s
# [09:00:49.123154] Parcel 18 removed from outfeed 6
# [09:00:49.171846] Parcel 5 removed from outfeed 1
# [09:00:50.231692] Parcel 30 ENTERS outfeed 5 with service_time=8.500s
# [09:00:50.621154] Parcel 29 ENTERS outfeed 6 with service_time=8.500s
# [09:00:50.633769] Parcel 34 ENTERS outfeed 3 with service_time=8.500s
# [09:00:51.104692] Parcel 31 ENTERS outfeed 5 with service_time=8.500s
# [09:00:51.797769] Parcel 35 ENTERS outfeed 3 with service_time=8.500s
# [09:00:51.900231] Parcel 15 removed from outfeed 4
# [09:00:52.466538] Parcel 26 ENTERS outfeed 9 with service_time=8.500s
# [09:00:52.587769] Parcel 36 ENTERS outfeed 3 with service_time=7.500s
# [09:00:53.748385] Parcel 25 removed from outfeed 0
# [09:00:54.905846] Parcel 42 ENTERS outfeed 1 with service_time=8.500s
# [09:00:55.220308] Parcel 12 removed from outfeed 2
# [09:00:55.395538] Parcel 20 removed from outfeed 9
# [09:00:55.918846] Parcel 43 ENTERS outfeed 1 with service_time=8.500s
# [09:00:56.294769] Parcel 32 removed from outfeed 3
# [09:00:56.623154] Parcel 19 removed from outfeed 6
# [09:00:56.764846] Parcel 44 ENTERS outfeed 1 with service_time=6.500s
# [09:00:58.223692] Parcel 39 ENTERS outfeed 5 with service_time=8.500s
# [09:00:58.731692] Parcel 30 removed from outfeed 5
# [09:00:58.769846] Parcel 46 ENTERS outfeed 1 with service_time=7.500s
# [09:00:59.512846] Parcel 47 ENTERS outfeed 1 with service_time=8.500s
# [09:01:00.182692] Parcel 41 ENTERS outfeed 5 with service_time=8.500s
# [09:01:00.400231] Parcel 16 removed from outfeed 4
# [09:01:01.248385] Parcel 28 removed from outfeed 0
# [09:01:01.720308] Parcel 14 removed from outfeed 2
# [09:01:02.092077] Parcel 38 ENTERS outfeed 8 with service_time=7.500s
# [09:01:02.839538] Parcel 37 ENTERS outfeed 9 with service_time=6.500s
# [09:01:03.405846] Parcel 42 removed from outfeed 1
# [09:01:03.651923] Parcel 33 ENTERS outfeed 12 with service_time=6.500s
# [09:01:03.895538] Parcel 26 removed from outfeed 9
# [09:01:04.794769] Parcel 34 removed from outfeed 3
# [09:01:05.123154] Parcel 21 removed from outfeed 6
# [09:01:06.889000] Parcel 40 ENTERS outfeed 10 with service_time=8.500s
# [09:01:07.231692] Parcel 31 removed from outfeed 5
# [09:01:08.900231] Parcel 17 removed from outfeed 4
# [09:01:09.237308] Parcel 55 ENTERS outfeed 2 with service_time=8.500s
# [09:01:09.592077] Parcel 38 removed from outfeed 8
# [09:01:10.151923] Parcel 33 removed from outfeed 12
# [09:01:10.311308] Parcel 56 ENTERS outfeed 2 with service_time=8.500s
# [09:01:10.395538] Parcel 37 removed from outfeed 9
# [09:01:11.040308] Parcel 57 ENTERS outfeed 2 with service_time=8.500s
# [09:01:11.858308] Parcel 58 ENTERS outfeed 2 with service_time=8.500s
# [09:01:11.905846] Parcel 43 removed from outfeed 1
# [09:01:12.027077] Parcel 49 ENTERS outfeed 8 with service_time=8.500s
# [09:01:12.570308] Parcel 59 ENTERS outfeed 2 with service_time=8.500s
# [09:01:13.294769] Parcel 35 removed from outfeed 3
# [09:01:13.331385] Parcel 63 ENTERS outfeed 0 with service_time=8.500s
# [09:01:13.541308] Parcel 60 ENTERS outfeed 2 with service_time=8.500s
# [09:01:13.623154] Parcel 22 removed from outfeed 6
# [09:01:14.195000] Parcel 48 ENTERS outfeed 10 with service_time=7.500s
# [09:01:14.385077] Parcel 51 ENTERS outfeed 8 with service_time=7.500s
# [09:01:14.661385] Parcel 64 ENTERS outfeed 0 with service_time=8.500s
# [09:01:14.704308] Parcel 61 ENTERS outfeed 2 with service_time=8.500s
# [09:01:15.389000] Parcel 40 removed from outfeed 10
# [09:01:15.731692] Parcel 39 removed from outfeed 5
# [09:01:16.142000] Parcel 50 ENTERS outfeed 10 with service_time=7.500s
# [09:01:16.511385] Parcel 66 ENTERS outfeed 0 with service_time=8.500s
# [09:01:17.737308] Parcel 55 removed from outfeed 2
# [09:01:18.405846] Parcel 44 removed from outfeed 1
# [09:01:18.453000] Parcel 52 ENTERS outfeed 10 with service_time=6.500s
# [09:01:18.714538] Parcel 54 ENTERS outfeed 9 with service_time=7.500s
# [09:01:20.527077] Parcel 49 removed from outfeed 8
# [09:01:20.794769] Parcel 36 removed from outfeed 3
# [09:01:20.934462] Parcel 53 ENTERS outfeed 11 with service_time=7.500s
# [09:01:21.123154] Parcel 23 removed from outfeed 6
# [09:01:21.831385] Parcel 63 removed from outfeed 0
# [09:01:22.889000] Parcel 48 removed from outfeed 10
# [09:01:23.702231] Parcel 67 ENTERS outfeed 4 with service_time=7.500s
# [09:01:24.231692] Parcel 41 removed from outfeed 5
# [09:01:25.905846] Parcel 46 removed from outfeed 1
# [09:01:26.122538] Parcel 62 ENTERS outfeed 9 with service_time=8.500s
# [09:01:26.214538] Parcel 54 removed from outfeed 9
# [09:01:26.237308] Parcel 56 removed from outfeed 2
# [09:01:26.899231] Parcel 70 ENTERS outfeed 4 with service_time=7.500s
# [09:01:27.891231] Parcel 71 ENTERS outfeed 4 with service_time=6.500s
# [09:01:28.027077] Parcel 51 removed from outfeed 8
# [09:01:28.434462] Parcel 53 removed from outfeed 11
# [09:01:28.623154] Parcel 27 removed from outfeed 6
# [09:01:28.768231] Parcel 72 ENTERS outfeed 4 with service_time=6.500s
# [09:01:29.384538] Parcel 65 ENTERS outfeed 9 with service_time=7.500s
# [09:01:29.483231] Parcel 73 ENTERS outfeed 4 with service_time=7.500s
# [09:01:29.861769] Parcel 75 ENTERS outfeed 3 with service_time=8.500s
# [09:01:30.331385] Parcel 64 removed from outfeed 0
# [09:01:30.389000] Parcel 50 removed from outfeed 10
# [09:01:30.592231] Parcel 74 ENTERS outfeed 4 with service_time=8.500s
# [09:01:31.199769] Parcel 76 ENTERS outfeed 3 with service_time=8.500s
# [09:01:31.202231] Parcel 67 removed from outfeed 4
# [09:01:32.117769] Parcel 77 ENTERS outfeed 3 with service_time=8.500s
# [09:01:32.532538] Parcel 68 ENTERS outfeed 9 with service_time=7.500s
# [09:01:33.811538] Parcel 69 ENTERS outfeed 9 with service_time=8.500s
# [09:01:34.405846] Parcel 47 removed from outfeed 1
# [09:01:34.714538] Parcel 62 removed from outfeed 9
# [09:01:34.737308] Parcel 57 removed from outfeed 2
# [09:01:35.873769] Parcel 81 ENTERS outfeed 3 with service_time=8.500s
# [09:01:36.143692] Parcel 78 ENTERS outfeed 5 with service_time=8.500s
# [09:01:36.889000] Parcel 52 removed from outfeed 10
# [09:01:36.907692] Parcel 79 ENTERS outfeed 5 with service_time=8.500s
# [09:01:37.123154] Parcel 29 removed from outfeed 6
# [09:01:37.662769] Parcel 83 ENTERS outfeed 3 with service_time=7.500s
# [09:01:38.361769] Parcel 75 removed from outfeed 3
# [09:01:38.702231] Parcel 70 removed from outfeed 4
# [09:01:38.831385] Parcel 66 removed from outfeed 0
# [09:01:40.418846] Parcel 89 ENTERS outfeed 1 with service_time=7.500s
# [09:01:41.190615] Parcel 80 ENTERS outfeed 7 with service_time=8.500s
# [09:01:41.438846] Parcel 90 ENTERS outfeed 1 with service_time=8.500s
# [09:01:42.026692] Parcel 84 ENTERS outfeed 5 with service_time=8.500s
# [09:01:42.214538] Parcel 65 removed from outfeed 9
# [09:01:43.190846] Parcel 92 ENTERS outfeed 1 with service_time=7.500s
# [09:01:43.237308] Parcel 58 removed from outfeed 2
# [09:01:44.643692] Parcel 78 removed from outfeed 5
# [09:01:44.930846] Parcel 94 ENTERS outfeed 1 with service_time=7.500s
# [09:01:45.202231] Parcel 71 removed from outfeed 4
# [09:01:45.714846] Parcel 95 ENTERS outfeed 1 with service_time=8.500s
# [09:01:46.043538] Parcel 82 ENTERS outfeed 9 with service_time=7.500s
# [09:01:46.861769] Parcel 76 removed from outfeed 3
# [09:01:47.072385] Parcel 98 ENTERS outfeed 0 with service_time=7.500s
# [09:01:47.918846] Parcel 89 removed from outfeed 1
# [09:01:49.387077] Parcel 87 ENTERS outfeed 8 with service_time=8.500s
# [09:01:49.690615] Parcel 80 removed from outfeed 7
# [09:01:49.714538] Parcel 68 removed from outfeed 9
# [09:01:50.355077] Parcel 88 ENTERS outfeed 8 with service_time=7.500s
# [09:01:51.686154] Parcel 93 ENTERS outfeed 6 with service_time=8.500s
# [09:01:51.702231] Parcel 72 removed from outfeed 4
# [09:01:51.737308] Parcel 59 removed from outfeed 2
# [09:01:53.143692] Parcel 79 removed from outfeed 5
# [09:01:53.809923] Parcel 85 ENTERS outfeed 12 with service_time=7.500s
# [09:01:54.409154] Parcel 96 ENTERS outfeed 6 with service_time=8.500s
# [09:01:54.572385] Parcel 98 removed from outfeed 0
# [09:01:55.361769] Parcel 77 removed from outfeed 3
# [09:01:55.366154] Parcel 97 ENTERS outfeed 6 with service_time=8.500s
# [09:01:56.418846] Parcel 90 removed from outfeed 1
# [09:01:57.180154] Parcel 99 ENTERS outfeed 6 with service_time=8.500s
# [09:01:57.696846] Parcel 86 ENTERS outfeed 14 with service_time=7.500s
# [09:01:57.887077] Parcel 87 removed from outfeed 8
# [09:01:58.066385] Parcel 109 ENTERS outfeed 0 with service_time=8.500s
# [09:01:58.167154] Parcel 100 ENTERS outfeed 6 with service_time=6.500s
# [09:01:58.214538] Parcel 69 removed from outfeed 9
# [09:01:59.202231] Parcel 73 removed from outfeed 4
# [09:01:59.514154] Parcel 101 ENTERS outfeed 6 with service_time=8.500s
# [09:02:00.186154] Parcel 93 removed from outfeed 6
# [09:02:00.237308] Parcel 60 removed from outfeed 2
# [09:02:00.728385] Parcel 91 ENTERS outfeed 13 with service_time=8.500s
# [09:02:01.309923] Parcel 85 removed from outfeed 12
# [09:02:01.391154] Parcel 103 ENTERS outfeed 6 with service_time=7.500s
# [09:02:01.643692] Parcel 84 removed from outfeed 5
# [09:02:01.789385] Parcel 113 ENTERS outfeed 0 with service_time=8.500s
# [09:02:02.296154] Parcel 104 ENTERS outfeed 6 with service_time=8.500s
# [09:02:02.986154] Parcel 105 ENTERS outfeed 6 with service_time=8.500s
# [09:02:03.861769] Parcel 81 removed from outfeed 3
# [09:02:03.918846] Parcel 92 removed from outfeed 1
# [09:02:04.010154] Parcel 106 ENTERS outfeed 6 with service_time=7.500s
# [09:02:05.196846] Parcel 86 removed from outfeed 14
# [09:02:05.387077] Parcel 88 removed from outfeed 8
# [09:02:05.714538] Parcel 82 removed from outfeed 9
# [09:02:06.566385] Parcel 109 removed from outfeed 0
# [09:02:07.702231] Parcel 74 removed from outfeed 4
# [09:02:08.686154] Parcel 96 removed from outfeed 6
# [09:02:08.737308] Parcel 61 removed from outfeed 2
# [09:02:09.228385] Parcel 91 removed from outfeed 13
# [09:02:09.723615] Parcel 110 ENTERS outfeed 7 with service_time=8.500s
# [09:02:09.752923] Parcel 102 ENTERS outfeed 12 with service_time=8.500s
# [09:02:10.904308] Parcel 119 ENTERS outfeed 2 with service_time=7.500s
# [09:02:11.361769] Parcel 83 removed from outfeed 3
# [09:02:11.418846] Parcel 94 removed from outfeed 1
# [09:02:14.021462] Parcel 108 ENTERS outfeed 11 with service_time=8.500s
# [09:02:14.607923] Parcel 107 ENTERS outfeed 12 with service_time=8.500s
# [09:02:15.066385] Parcel 113 removed from outfeed 0
# [09:02:16.243000] Parcel 112 ENTERS outfeed 10 with service_time=8.500s
# [09:02:17.186154] Parcel 97 removed from outfeed 6
# [09:02:18.223615] Parcel 110 removed from outfeed 7
# [09:02:18.252923] Parcel 102 removed from outfeed 12
# [09:02:18.292000] Parcel 114 ENTERS outfeed 10 with service_time=8.500s
# [09:02:18.404308] Parcel 119 removed from outfeed 2
# [09:02:18.533231] Parcel 124 ENTERS outfeed 4 with service_time=8.500s
# [09:02:19.593231] Parcel 125 ENTERS outfeed 4 with service_time=7.500s
# [09:02:19.810538] Parcel 117 ENTERS outfeed 9 with service_time=7.500s
# [09:02:19.826385] Parcel 111 ENTERS outfeed 13 with service_time=8.500s
# [09:02:19.918846] Parcel 95 removed from outfeed 1
# [09:02:19.980769] Parcel 127 ENTERS outfeed 3 with service_time=7.500s
# [09:02:20.234000] Parcel 116 ENTERS outfeed 10 with service_time=8.500s
# [09:02:20.452231] Parcel 126 ENTERS outfeed 4 with service_time=8.500s
# [09:02:20.987769] Parcel 128 ENTERS outfeed 3 with service_time=8.500s
# [09:02:22.094000] Parcel 118 ENTERS outfeed 10 with service_time=8.500s
# [09:02:22.310615] Parcel 123 ENTERS outfeed 7 with service_time=8.500s
# [09:02:22.521462] Parcel 108 removed from outfeed 11
# [09:02:23.901231] Parcel 129 ENTERS outfeed 4 with service_time=8.500s
# [09:02:23.988385] Parcel 115 ENTERS outfeed 13 with service_time=8.500s
# [09:02:24.182000] Parcel 120 ENTERS outfeed 10 with service_time=7.500s
# [09:02:24.628538] Parcel 122 ENTERS outfeed 9 with service_time=8.500s
# [09:02:24.743000] Parcel 112 removed from outfeed 10
# [09:02:25.515769] Parcel 132 ENTERS outfeed 3 with service_time=8.500s
# [09:02:25.686154] Parcel 99 removed from outfeed 6
# [09:02:26.060846] Parcel 136 ENTERS outfeed 1 with service_time=7.500s
# [09:02:26.340231] Parcel 131 ENTERS outfeed 4 with service_time=7.500s
# [09:02:26.531692] Parcel 130 ENTERS outfeed 5 with service_time=8.500s
# [09:02:26.752923] Parcel 107 removed from outfeed 12
# [09:02:27.033231] Parcel 124 removed from outfeed 4
# [09:02:27.158846] Parcel 137 ENTERS outfeed 1 with service_time=7.500s
# [09:02:27.251769] Parcel 134 ENTERS outfeed 3 with service_time=8.500s
# [09:02:27.310538] Parcel 117 removed from outfeed 9
# [09:02:27.480769] Parcel 127 removed from outfeed 3
# [09:02:27.962385] Parcel 139 ENTERS outfeed 0 with service_time=8.500s
# [09:02:28.002231] Parcel 133 ENTERS outfeed 4 with service_time=8.500s
# [09:02:28.326385] Parcel 111 removed from outfeed 13
# [09:02:28.607846] Parcel 138 ENTERS outfeed 1 with service_time=7.500s
# [09:02:28.992385] Parcel 140 ENTERS outfeed 0 with service_time=8.500s
# [09:02:29.962385] Parcel 141 ENTERS outfeed 0 with service_time=7.500s
# [09:02:30.810615] Parcel 123 removed from outfeed 7
# [09:02:32.186154] Parcel 100 removed from outfeed 6
# [09:02:33.243000] Parcel 114 removed from outfeed 10
# [09:02:33.560846] Parcel 136 removed from outfeed 1
# [09:02:34.255615] Parcel 135 ENTERS outfeed 7 with service_time=8.500s
# [09:02:34.533231] Parcel 125 removed from outfeed 4
# [09:02:34.818308] Parcel 143 ENTERS outfeed 2 with service_time=8.500s
# [09:02:35.031692] Parcel 130 removed from outfeed 5
# [09:02:35.810538] Parcel 122 removed from outfeed 9
# [09:02:35.980769] Parcel 128 removed from outfeed 3
# [09:02:36.462385] Parcel 139 removed from outfeed 0
# [09:02:36.826385] Parcel 115 removed from outfeed 13
# [09:02:40.333308] Parcel 148 ENTERS outfeed 2 with service_time=6.500s
# [09:02:40.686154] Parcel 101 removed from outfeed 6
# [09:02:41.060846] Parcel 137 removed from outfeed 1
# [09:02:41.743000] Parcel 116 removed from outfeed 10
# [09:02:42.755615] Parcel 135 removed from outfeed 7
# [09:02:43.033231] Parcel 126 removed from outfeed 4
# [09:02:43.318308] Parcel 143 removed from outfeed 2
# [09:02:44.480769] Parcel 132 removed from outfeed 3
# [09:02:44.937077] Parcel 144 ENTERS outfeed 8 with service_time=8.500s
# [09:02:44.962385] Parcel 140 removed from outfeed 0
# [09:02:47.294692] Parcel 151 ENTERS outfeed 5 with service_time=8.500s
# [09:02:47.526538] Parcel 145 ENTERS outfeed 9 with service_time=7.500s
# [09:02:48.186154] Parcel 103 removed from outfeed 6
# [09:02:48.496692] Parcel 152 ENTERS outfeed 5 with service_time=6.500s
# [09:02:48.560846] Parcel 138 removed from outfeed 1
# [09:02:48.736615] Parcel 149 ENTERS outfeed 7 with service_time=7.500s
# [09:02:49.443923] Parcel 142 ENTERS outfeed 12 with service_time=8.500s
# [09:02:49.529538] Parcel 147 ENTERS outfeed 9 with service_time=6.500s
# [09:02:49.818308] Parcel 148 removed from outfeed 2
# [09:02:50.243000] Parcel 118 removed from outfeed 10
# [09:02:51.533231] Parcel 129 removed from outfeed 4
# [09:02:51.672462] Parcel 146 ENTERS outfeed 11 with service_time=8.500s
# [09:02:52.091692] Parcel 156 ENTERS outfeed 5 with service_time=8.500s
# [09:02:52.462385] Parcel 141 removed from outfeed 0
# [09:02:52.980769] Parcel 134 removed from outfeed 3
# [09:02:53.437077] Parcel 144 removed from outfeed 8
# [09:02:54.699846] Parcel 166 ENTERS outfeed 1 with service_time=7.500s
# [09:02:54.760077] Parcel 154 ENTERS outfeed 8 with service_time=8.500s
# [09:02:55.026538] Parcel 145 removed from outfeed 9
# [09:02:55.407692] Parcel 160 ENTERS outfeed 5 with service_time=8.500s
# [09:02:55.482538] Parcel 153 ENTERS outfeed 9 with service_time=8.500s
# [09:02:55.621462] Parcel 150 ENTERS outfeed 11 with service_time=8.500s
# [09:02:55.794692] Parcel 151 removed from outfeed 5
# [09:02:55.890077] Parcel 155 ENTERS outfeed 8 with service_time=8.500s
# [09:02:56.236615] Parcel 149 removed from outfeed 7
# [09:02:56.686154] Parcel 104 removed from outfeed 6
# [09:02:56.847385] Parcel 170 ENTERS outfeed 0 with service_time=8.500s
# [09:02:57.066692] Parcel 162 ENTERS outfeed 5 with service_time=7.500s
# [09:02:57.743000] Parcel 120 removed from outfeed 10
# [09:02:57.943923] Parcel 142 removed from outfeed 12
# [09:02:57.960692] Parcel 163 ENTERS outfeed 5 with service_time=6.500s
# [09:02:59.033231] Parcel 131 removed from outfeed 4
# [09:02:59.069308] Parcel 169 ENTERS outfeed 2 with service_time=6.500s
# [09:02:59.285077] Parcel 159 ENTERS outfeed 8 with service_time=8.500s
# [09:02:59.320385] Parcel 172 ENTERS outfeed 0 with service_time=6.500s
# [09:02:59.941538] Parcel 158 ENTERS outfeed 9 with service_time=6.500s
# [09:03:00.172462] Parcel 146 removed from outfeed 11
# [09:03:00.424385] Parcel 173 ENTERS outfeed 0 with service_time=8.500s
# [09:03:01.526538] Parcel 147 removed from outfeed 9
# [09:03:02.199846] Parcel 166 removed from outfeed 1
# [09:03:02.271462] Parcel 157 ENTERS outfeed 11 with service_time=7.500s
# [09:03:02.294692] Parcel 152 removed from outfeed 5
# [09:03:02.574769] Parcel 171 ENTERS outfeed 3 with service_time=8.500s
# [09:03:03.260077] Parcel 154 removed from outfeed 8
# [09:03:03.959846] Parcel 175 ENTERS outfeed 1 with service_time=6.500s
# [09:03:04.498308] Parcel 174 ENTERS outfeed 2 with service_time=8.500s
# [09:03:05.186154] Parcel 105 removed from outfeed 6
# [09:03:05.347385] Parcel 170 removed from outfeed 0
# [09:03:05.416462] Parcel 161 ENTERS outfeed 11 with service_time=8.500s
# [09:03:05.569308] Parcel 169 removed from outfeed 2
# [09:03:07.533231] Parcel 133 removed from outfeed 4
# [09:03:07.780846] Parcel 179 ENTERS outfeed 1 with service_time=8.500s
# [09:03:08.672462] Parcel 150 removed from outfeed 11
# [09:03:09.042769] Parcel 177 ENTERS outfeed 3 with service_time=8.500s
# [09:03:09.171462] Parcel 165 ENTERS outfeed 11 with service_time=7.500s
# [09:03:09.923923] Parcel 164 ENTERS outfeed 12 with service_time=8.500s
# [09:03:10.026538] Parcel 153 removed from outfeed 9
# [09:03:10.459846] Parcel 175 removed from outfeed 1
# [09:03:10.794692] Parcel 156 removed from outfeed 5
# [09:03:11.041462] Parcel 167 ENTERS outfeed 11 with service_time=8.500s
# [09:03:11.074769] Parcel 171 removed from outfeed 3
# [09:03:11.760077] Parcel 155 removed from outfeed 8
# [09:03:11.847385] Parcel 172 removed from outfeed 0
# [09:03:11.955462] Parcel 168 ENTERS outfeed 11 with service_time=8.500s
# [09:03:12.686154] Parcel 106 removed from outfeed 6
# [09:03:14.054231] Parcel 181 ENTERS outfeed 4 with service_time=8.500s
# [09:03:14.069308] Parcel 174 removed from outfeed 2
# [09:03:16.172462] Parcel 157 removed from outfeed 11
# [09:03:16.526538] Parcel 158 removed from outfeed 9
# [09:03:18.423923] Parcel 164 removed from outfeed 12
# [09:03:18.818000] Parcel 176 ENTERS outfeed 10 with service_time=7.500s
# [09:03:18.959846] Parcel 179 removed from outfeed 1
# [09:03:19.294692] Parcel 160 removed from outfeed 5
# [09:03:19.574769] Parcel 177 removed from outfeed 3
# [09:03:19.924231] Parcel 187 ENTERS outfeed 4 with service_time=8.500s
# [09:03:20.260077] Parcel 159 removed from outfeed 8
# [09:03:20.347385] Parcel 173 removed from outfeed 0
# [09:03:20.627000] Parcel 178 ENTERS outfeed 10 with service_time=8.500s
# [09:03:21.515308] Parcel 192 ENTERS outfeed 2 with service_time=8.500s
# [09:03:22.500308] Parcel 193 ENTERS outfeed 2 with service_time=8.500s
# [09:03:22.554231] Parcel 181 removed from outfeed 4
# [09:03:22.823231] Parcel 190 ENTERS outfeed 4 with service_time=7.500s
# [09:03:23.487308] Parcel 194 ENTERS outfeed 2 with service_time=8.500s
# [09:03:24.672462] Parcel 161 removed from outfeed 11
# [09:03:24.779846] Parcel 197 ENTERS outfeed 1 with service_time=7.500s
# [09:03:25.089385] Parcel 199 ENTERS outfeed 0 with service_time=8.500s
# [09:03:25.129000] Parcel 183 ENTERS outfeed 10 with service_time=8.500s
# [09:03:25.374615] Parcel 188 ENTERS outfeed 7 with service_time=7.500s
# [09:03:25.724846] Parcel 198 ENTERS outfeed 1 with service_time=7.500s
# [09:03:25.902385] Parcel 200 ENTERS outfeed 0 with service_time=8.500s
# [09:03:26.263000] Parcel 184 ENTERS outfeed 10 with service_time=8.500s
# [09:03:26.318000] Parcel 176 removed from outfeed 10
# [09:03:26.743385] Parcel 201 ENTERS outfeed 0 with service_time=8.500s
# [09:03:26.794692] Parcel 162 removed from outfeed 5
# [09:03:26.985385] Parcel 180 ENTERS outfeed 13 with service_time=8.500s
# [09:03:28.143000] Parcel 186 ENTERS outfeed 10 with service_time=8.500s
# [09:03:30.015308] Parcel 192 removed from outfeed 2
# [09:03:30.338846] Parcel 182 ENTERS outfeed 14 with service_time=8.500s
# [09:03:30.405923] Parcel 185 ENTERS outfeed 12 with service_time=8.500s
# [09:03:30.650154] Parcel 195 ENTERS outfeed 6 with service_time=7.500s
# [09:03:31.054231] Parcel 187 removed from outfeed 4
# [09:03:31.387154] Parcel 196 ENTERS outfeed 6 with service_time=7.500s
# [09:03:32.172462] Parcel 165 removed from outfeed 11
# [09:03:32.279846] Parcel 197 removed from outfeed 1
# [09:03:32.845769] Parcel 202 ENTERS outfeed 3 with service_time=8.500s
# [09:03:32.874615] Parcel 188 removed from outfeed 7
# [09:03:33.031000] Parcel 191 ENTERS outfeed 10 with service_time=8.500s
# [09:03:33.294692] Parcel 163 removed from outfeed 5
# [09:03:33.589385] Parcel 199 removed from outfeed 0
# [09:03:34.818000] Parcel 178 removed from outfeed 10
# [09:03:35.394769] Parcel 205 ENTERS outfeed 3 with service_time=6.500s
# [09:03:35.485385] Parcel 180 removed from outfeed 13
# [09:03:35.610385] Parcel 189 ENTERS outfeed 13 with service_time=7.500s
# [09:03:36.320769] Parcel 206 ENTERS outfeed 3 with service_time=8.500s
# [09:03:37.330769] Parcel 207 ENTERS outfeed 3 with service_time=7.500s
# [09:03:38.150154] Parcel 195 removed from outfeed 6
# [09:03:38.515308] Parcel 193 removed from outfeed 2
# [09:03:38.554231] Parcel 190 removed from outfeed 4
# [09:03:38.838846] Parcel 182 removed from outfeed 14
# [09:03:38.905923] Parcel 185 removed from outfeed 12
# [09:03:39.779846] Parcel 198 removed from outfeed 1
# [09:03:40.672462] Parcel 167 removed from outfeed 11
# [09:03:41.122769] Parcel 211 ENTERS outfeed 3 with service_time=8.500s
# [09:03:41.345769] Parcel 202 removed from outfeed 3
# [09:03:41.864231] Parcel 210 ENTERS outfeed 4 with service_time=8.500s
# [09:03:42.089385] Parcel 200 removed from outfeed 0
# [09:03:42.355077] Parcel 204 ENTERS outfeed 8 with service_time=8.500s
# [09:03:42.918154] Parcel 208 ENTERS outfeed 6 with service_time=7.500s
# [09:03:43.001538] Parcel 203 ENTERS outfeed 9 with service_time=8.500s
# [09:03:43.110385] Parcel 189 removed from outfeed 13
# [09:03:43.318000] Parcel 183 removed from outfeed 10
# [09:03:43.525846] Parcel 217 ENTERS outfeed 1 with service_time=7.500s
# [09:03:43.703154] Parcel 209 ENTERS outfeed 6 with service_time=8.500s
# [09:03:44.660846] Parcel 218 ENTERS outfeed 1 with service_time=8.500s
# [09:03:45.463846] Parcel 219 ENTERS outfeed 1 with service_time=7.500s
# [09:03:45.650154] Parcel 196 removed from outfeed 6
# [09:03:47.015308] Parcel 194 removed from outfeed 2
# [09:03:47.330846] Parcel 221 ENTERS outfeed 1 with service_time=6.500s
# [09:03:47.721692] Parcel 215 ENTERS outfeed 5 with service_time=8.500s
# [09:03:47.845769] Parcel 205 removed from outfeed 3
# [09:03:48.419692] Parcel 216 ENTERS outfeed 5 with service_time=7.500s
# [09:03:49.172462] Parcel 168 removed from outfeed 11
# [09:03:50.364231] Parcel 210 removed from outfeed 4
# [09:03:50.589385] Parcel 201 removed from outfeed 0
# [09:03:50.855077] Parcel 204 removed from outfeed 8
# [09:03:50.871231] Parcel 220 ENTERS outfeed 4 with service_time=7.500s
# [09:03:51.025846] Parcel 217 removed from outfeed 1
# [09:03:51.218538] Parcel 212 ENTERS outfeed 9 with service_time=8.500s
# [09:03:51.501538] Parcel 203 removed from outfeed 9
# [09:03:51.818000] Parcel 184 removed from outfeed 10
# [09:03:51.821308] Parcel 224 ENTERS outfeed 2 with service_time=8.500s
# [09:03:51.919538] Parcel 213 ENTERS outfeed 9 with service_time=7.500s
# [09:03:52.920538] Parcel 214 ENTERS outfeed 9 with service_time=8.500s
# [09:03:53.150154] Parcel 208 removed from outfeed 6
# [09:03:56.221692] Parcel 215 removed from outfeed 5
# [09:03:56.312308] Parcel 229 ENTERS outfeed 2 with service_time=6.500s
# [09:03:56.345769] Parcel 206 removed from outfeed 3
# [09:03:56.765385] Parcel 233 ENTERS outfeed 0 with service_time=8.500s
# [09:03:57.385692] Parcel 225 ENTERS outfeed 5 with service_time=8.500s
# [09:03:57.546385] Parcel 234 ENTERS outfeed 0 with service_time=8.500s
# [09:03:58.169308] Parcel 231 ENTERS outfeed 2 with service_time=7.500s
# [09:03:58.371231] Parcel 220 removed from outfeed 4
# [09:03:59.525846] Parcel 218 removed from outfeed 1
# [09:04:00.001538] Parcel 212 removed from outfeed 9
# [09:04:00.318000] Parcel 186 removed from outfeed 10
# [09:04:00.321308] Parcel 224 removed from outfeed 2
# [09:04:00.425231] Parcel 230 ENTERS outfeed 4 with service_time=8.500s
# [09:04:00.643538] Parcel 222 ENTERS outfeed 9 with service_time=8.500s
# [09:04:01.650154] Parcel 209 removed from outfeed 6
# [09:04:03.721692] Parcel 216 removed from outfeed 5
# [09:04:03.845769] Parcel 207 removed from outfeed 3
# [09:04:04.356538] Parcel 226 ENTERS outfeed 9 with service_time=8.500s
# [09:04:05.265385] Parcel 233 removed from outfeed 0
# [09:04:05.990923] Parcel 223 ENTERS outfeed 12 with service_time=8.500s
# [09:04:06.821308] Parcel 229 removed from outfeed 2
# [09:04:07.025846] Parcel 219 removed from outfeed 1
# [09:04:07.501538] Parcel 213 removed from outfeed 9
# [09:04:08.818000] Parcel 191 removed from outfeed 10
# [09:04:08.925231] Parcel 230 removed from outfeed 4
# [09:04:09.138615] Parcel 235 ENTERS outfeed 7 with service_time=8.500s
# [09:04:09.920923] Parcel 227 ENTERS outfeed 12 with service_time=7.500s
# [09:04:10.018231] Parcel 241 ENTERS outfeed 4 with service_time=7.500s
# [09:04:12.221692] Parcel 225 removed from outfeed 5
# [09:04:12.345769] Parcel 211 removed from outfeed 3
# [09:04:13.064231] Parcel 244 ENTERS outfeed 4 with service_time=7.500s
# [09:04:13.525846] Parcel 221 removed from outfeed 1
# [09:04:13.765385] Parcel 234 removed from outfeed 0
# [09:04:13.810846] Parcel 228 ENTERS outfeed 14 with service_time=8.500s
# [09:04:14.321308] Parcel 231 removed from outfeed 2
# [09:04:14.490923] Parcel 223 removed from outfeed 12
# [09:04:15.072154] Parcel 243 ENTERS outfeed 6 with service_time=8.500s
# [09:04:16.001538] Parcel 214 removed from outfeed 9
# [09:04:16.164462] Parcel 236 ENTERS outfeed 11 with service_time=8.500s
# [09:04:17.514846] Parcel 232 ENTERS outfeed 14 with service_time=8.500s
# [09:04:17.518231] Parcel 241 removed from outfeed 4
# [09:04:17.638615] Parcel 235 removed from outfeed 7
# [09:04:17.886462] Parcel 238 ENTERS outfeed 11 with service_time=8.500s
# [09:04:18.070385] Parcel 256 ENTERS outfeed 0 with service_time=7.500s
# [09:04:18.850462] Parcel 239 ENTERS outfeed 11 with service_time=8.500s
# [09:04:19.034154] Parcel 247 ENTERS outfeed 6 with service_time=8.500s
# [09:04:19.918231] Parcel 251 ENTERS outfeed 4 with service_time=8.500s
# [09:04:19.974462] Parcel 240 ENTERS outfeed 11 with service_time=8.500s
# [09:04:20.096385] Parcel 258 ENTERS outfeed 0 with service_time=6.500s
# [09:04:20.116385] Parcel 237 ENTERS outfeed 13 with service_time=8.500s
# [09:04:20.274077] Parcel 245 ENTERS outfeed 8 with service_time=8.500s
# [09:04:20.503846] Parcel 257 ENTERS outfeed 1 with service_time=8.500s
# [09:04:21.805769] Parcel 255 ENTERS outfeed 3 with service_time=8.500s
# [09:04:21.897154] Parcel 250 ENTERS outfeed 6 with service_time=8.500s
# [09:04:21.951462] Parcel 242 ENTERS outfeed 11 with service_time=8.500s
# [09:04:21.990923] Parcel 227 removed from outfeed 12
# [09:04:22.310846] Parcel 228 removed from outfeed 14
# [09:04:23.226077] Parcel 248 ENTERS outfeed 8 with service_time=8.500s
# [09:04:23.503846] Parcel 260 ENTERS outfeed 1 with service_time=7.500s
# [09:04:23.572154] Parcel 243 removed from outfeed 6
# [09:04:24.501538] Parcel 222 removed from outfeed 9
# [09:04:24.664462] Parcel 236 removed from outfeed 11
# [09:04:25.018231] Parcel 244 removed from outfeed 4
# [09:04:25.375846] Parcel 262 ENTERS outfeed 1 with service_time=8.500s
# [09:04:25.570385] Parcel 256 removed from outfeed 0
# [09:04:27.731308] Parcel 263 ENTERS outfeed 2 with service_time=8.500s
# [09:04:28.616385] Parcel 237 removed from outfeed 13
# [09:04:28.774077] Parcel 245 removed from outfeed 8
# [09:04:28.843385] Parcel 246 ENTERS outfeed 13 with service_time=6.500s
# [09:04:29.003846] Parcel 257 removed from outfeed 1
# [09:04:29.834308] Parcel 265 ENTERS outfeed 2 with service_time=8.500s
# [09:04:30.107000] Parcel 252 ENTERS outfeed 10 with service_time=8.500s
# [09:04:30.305769] Parcel 255 removed from outfeed 3
# [09:04:30.542692] Parcel 261 ENTERS outfeed 5 with service_time=8.500s
# [09:04:30.810846] Parcel 232 removed from outfeed 14
# [09:04:32.070385] Parcel 258 removed from outfeed 0
# [09:04:32.072154] Parcel 247 removed from outfeed 6
# [09:04:33.001538] Parcel 226 removed from outfeed 9
# [09:04:33.024308] Parcel 268 ENTERS outfeed 2 with service_time=8.500s
# [09:04:33.151462] Parcel 254 ENTERS outfeed 11 with service_time=8.500s
# [09:04:33.164462] Parcel 238 removed from outfeed 11
# [09:04:33.315846] Parcel 249 ENTERS outfeed 14 with service_time=7.500s
# [09:04:33.518231] Parcel 251 removed from outfeed 4
# [09:04:35.343385] Parcel 246 removed from outfeed 13
# [09:04:35.494385] Parcel 274 ENTERS outfeed 0 with service_time=8.500s
# [09:04:36.231308] Parcel 263 removed from outfeed 2
# [09:04:36.503846] Parcel 260 removed from outfeed 1
# [09:04:36.671692] Parcel 267 ENTERS outfeed 5 with service_time=8.500s
# [09:04:37.065846] Parcel 253 ENTERS outfeed 14 with service_time=8.500s
# [09:04:37.274077] Parcel 248 removed from outfeed 8
# [09:04:38.456615] Parcel 266 ENTERS outfeed 7 with service_time=8.500s
# [09:04:38.607000] Parcel 252 removed from outfeed 10
# [09:04:38.621692] Parcel 269 ENTERS outfeed 5 with service_time=8.500s
# [09:04:38.807231] Parcel 271 ENTERS outfeed 4 with service_time=8.500s
# [09:04:39.042692] Parcel 261 removed from outfeed 5
# [09:04:39.249385] Parcel 278 ENTERS outfeed 0 with service_time=6.500s
# [09:04:40.572154] Parcel 250 removed from outfeed 6
# [09:04:40.815846] Parcel 249 removed from outfeed 14
# [09:04:40.961000] Parcel 264 ENTERS outfeed 10 with service_time=8.500s
# [09:04:41.041385] Parcel 259 ENTERS outfeed 13 with service_time=8.500s
# [09:04:41.664462] Parcel 239 removed from outfeed 11
# [09:04:43.596231] Parcel 276 ENTERS outfeed 4 with service_time=8.500s
# [09:04:43.994385] Parcel 274 removed from outfeed 0
# [09:04:44.731308] Parcel 265 removed from outfeed 2
# [09:04:45.003846] Parcel 262 removed from outfeed 1
# [09:04:45.327615] Parcel 273 ENTERS outfeed 7 with service_time=8.500s
# [09:04:45.687769] Parcel 280 ENTERS outfeed 3 with service_time=8.500s
# [09:04:46.956615] Parcel 266 removed from outfeed 7
# [09:04:47.190000] Parcel 270 ENTERS outfeed 10 with service_time=8.500s
# [09:04:47.307231] Parcel 271 removed from outfeed 4
# [09:04:47.542692] Parcel 267 removed from outfeed 5
# [09:04:47.620769] Parcel 282 ENTERS outfeed 3 with service_time=8.500s
# [09:04:48.210231] Parcel 281 ENTERS outfeed 4 with service_time=8.500s
# [09:04:49.073000] Parcel 272 ENTERS outfeed 10 with service_time=6.500s
# [09:04:49.315846] Parcel 253 removed from outfeed 14
# [09:04:49.461000] Parcel 264 removed from outfeed 10
# [09:04:49.541385] Parcel 259 removed from outfeed 13
# [09:04:49.625769] Parcel 284 ENTERS outfeed 3 with service_time=8.500s
# [09:04:50.164462] Parcel 240 removed from outfeed 11
# [09:04:50.462769] Parcel 285 ENTERS outfeed 3 with service_time=8.500s
# [09:04:50.494385] Parcel 278 removed from outfeed 0
# [09:04:50.906615] Parcel 279 ENTERS outfeed 7 with service_time=8.500s
# [09:04:51.072846] Parcel 288 ENTERS outfeed 1 with service_time=8.500s
# [09:04:52.021846] Parcel 289 ENTERS outfeed 1 with service_time=8.500s
# [09:04:53.142846] Parcel 290 ENTERS outfeed 1 with service_time=7.500s
# [09:04:53.231308] Parcel 268 removed from outfeed 2
# [09:04:54.187769] Parcel 280 removed from outfeed 3
# [09:04:54.219846] Parcel 291 ENTERS outfeed 1 with service_time=8.500s
# [09:04:54.708385] Parcel 293 ENTERS outfeed 0 with service_time=8.500s
# [09:04:55.200846] Parcel 292 ENTERS outfeed 1 with service_time=8.500s
# [09:04:55.456615] Parcel 273 removed from outfeed 7
# [09:04:55.807231] Parcel 276 removed from outfeed 4
# [09:04:56.042692] Parcel 269 removed from outfeed 5
# [09:04:56.284154] Parcel 286 ENTERS outfeed 6 with service_time=7.500s
# [09:04:56.431385] Parcel 295 ENTERS outfeed 0 with service_time=6.500s
# [09:04:57.340154] Parcel 287 ENTERS outfeed 6 with service_time=8.500s
# [09:04:57.961000] Parcel 270 removed from outfeed 10
# [09:04:58.131846] Parcel 275 ENTERS outfeed 14 with service_time=7.500s
# [09:04:58.664462] Parcel 242 removed from outfeed 11
# [09:04:59.310000] Parcel 283 ENTERS outfeed 10 with service_time=8.500s
# [09:04:59.572846] Parcel 288 removed from outfeed 1
# [09:05:00.396308] Parcel 296 ENTERS outfeed 2 with service_time=8.500s
# [09:05:02.687769] Parcel 282 removed from outfeed 3
# [09:05:03.208385] Parcel 293 removed from outfeed 0
# [09:05:03.784154] Parcel 286 removed from outfeed 6
# [09:05:03.956615] Parcel 279 removed from outfeed 7
# [09:05:04.307231] Parcel 281 removed from outfeed 4
# [09:05:04.413308] Parcel 300 ENTERS outfeed 2 with service_time=8.500s
# [09:05:04.461000] Parcel 272 removed from outfeed 10
# [09:05:04.736154] Parcel 294 ENTERS outfeed 6 with service_time=8.500s
# [09:05:05.631846] Parcel 275 removed from outfeed 14
# [09:05:07.164462] Parcel 254 removed from outfeed 11
# [09:05:07.456154] Parcel 297 ENTERS outfeed 6 with service_time=7.500s
# [09:05:08.072846] Parcel 289 removed from outfeed 1
# [09:05:08.098692] Parcel 299 ENTERS outfeed 5 with service_time=7.500s
# [09:05:08.659154] Parcel 298 ENTERS outfeed 6 with service_time=8.500s
# [09:05:08.896308] Parcel 296 removed from outfeed 2
# [09:05:09.708385] Parcel 295 removed from outfeed 0
# [09:05:09.803692] Parcel 301 ENTERS outfeed 5 with service_time=6.500s
# [09:05:11.187769] Parcel 284 removed from outfeed 3
# [09:05:12.284154] Parcel 287 removed from outfeed 6
# [09:05:12.961000] Parcel 283 removed from outfeed 10
# [09:05:14.079385] Parcel 314 ENTERS outfeed 0 with service_time=8.500s
# [09:05:14.418692] Parcel 306 ENTERS outfeed 5 with service_time=8.500s
# [09:05:15.572846] Parcel 290 removed from outfeed 1
# [09:05:15.598692] Parcel 299 removed from outfeed 5
# [09:05:15.675231] Parcel 309 ENTERS outfeed 4 with service_time=8.500s
# [09:05:16.136385] Parcel 316 ENTERS outfeed 0 with service_time=7.500s
# [09:05:16.430231] Parcel 310 ENTERS outfeed 4 with service_time=8.500s
# [09:05:17.043385] Parcel 317 ENTERS outfeed 0 with service_time=8.500s
# [09:05:17.396308] Parcel 300 removed from outfeed 2
# [09:05:17.679231] Parcel 311 ENTERS outfeed 4 with service_time=7.500s
# [09:05:17.775538] Parcel 303 ENTERS outfeed 9 with service_time=7.500s
# [09:05:18.654231] Parcel 312 ENTERS outfeed 4 with service_time=7.500s
# [09:05:18.764538] Parcel 304 ENTERS outfeed 9 with service_time=8.500s
# [09:05:19.430231] Parcel 313 ENTERS outfeed 4 with service_time=8.500s
# [09:05:19.687769] Parcel 285 removed from outfeed 3
# [09:05:19.766538] Parcel 305 ENTERS outfeed 9 with service_time=8.500s
# [09:05:19.872385] Parcel 320 ENTERS outfeed 0 with service_time=7.500s
# [09:05:19.982077] Parcel 307 ENTERS outfeed 8 with service_time=8.500s
# [09:05:20.784154] Parcel 294 removed from outfeed 6
# [09:05:21.122231] Parcel 315 ENTERS outfeed 4 with service_time=8.500s
# [09:05:22.098692] Parcel 301 removed from outfeed 5
# [09:05:22.408538] Parcel 308 ENTERS outfeed 9 with service_time=8.500s
# [09:05:22.579385] Parcel 314 removed from outfeed 0
# [09:05:23.029385] Parcel 302 ENTERS outfeed 13 with service_time=6.500s
# [09:05:24.072846] Parcel 291 removed from outfeed 1
# [09:05:24.102231] Parcel 318 ENTERS outfeed 4 with service_time=8.500s
# [09:05:24.175231] Parcel 309 removed from outfeed 4
# [09:05:24.684308] Parcel 322 ENTERS outfeed 2 with service_time=8.500s
# [09:05:25.044231] Parcel 319 ENTERS outfeed 4 with service_time=8.500s
# [09:05:25.275538] Parcel 303 removed from outfeed 9
# [09:05:25.577308] Parcel 323 ENTERS outfeed 2 with service_time=7.500s
# [09:05:26.384308] Parcel 324 ENTERS outfeed 2 with service_time=8.500s
# [09:05:27.231308] Parcel 325 ENTERS outfeed 2 with service_time=8.500s
# [09:05:28.074308] Parcel 326 ENTERS outfeed 2 with service_time=7.500s
# [09:05:28.284154] Parcel 297 removed from outfeed 6
# [09:05:28.482077] Parcel 307 removed from outfeed 8
# [09:05:29.128308] Parcel 327 ENTERS outfeed 2 with service_time=8.500s
# [09:05:29.529385] Parcel 302 removed from outfeed 13
# [09:05:30.079385] Parcel 316 removed from outfeed 0
# [09:05:30.598692] Parcel 306 removed from outfeed 5
# [09:05:31.579308] Parcel 330 ENTERS outfeed 2 with service_time=8.500s
# [09:05:32.572846] Parcel 292 removed from outfeed 1
# [09:05:32.675231] Parcel 310 removed from outfeed 4
# [09:05:33.184308] Parcel 322 removed from outfeed 2
# [09:05:33.775538] Parcel 304 removed from outfeed 9
# [09:05:34.732538] Parcel 321 ENTERS outfeed 9 with service_time=8.500s
# [09:05:36.784154] Parcel 298 removed from outfeed 6
# [09:05:37.632615] Parcel 328 ENTERS outfeed 7 with service_time=8.500s
# [09:05:38.140769] Parcel 335 ENTERS outfeed 3 with service_time=7.500s
# [09:05:38.385615] Parcel 329 ENTERS outfeed 7 with service_time=8.500s
# [09:05:38.579385] Parcel 317 removed from outfeed 0
# [09:05:38.588846] Parcel 339 ENTERS outfeed 1 with service_time=8.500s
# [09:05:38.886769] Parcel 336 ENTERS outfeed 3 with service_time=7.500s
# [09:05:39.625769] Parcel 337 ENTERS outfeed 3 with service_time=8.500s
# [09:05:40.175231] Parcel 311 removed from outfeed 4
# [09:05:40.684308] Parcel 323 removed from outfeed 2
# [09:05:41.311846] Parcel 342 ENTERS outfeed 1 with service_time=8.500s
# [09:05:41.493615] Parcel 332 ENTERS outfeed 7 with service_time=8.500s
# [09:05:42.275538] Parcel 305 removed from outfeed 9
# [09:05:42.697769] Parcel 340 ENTERS outfeed 3 with service_time=7.500s
# [09:05:43.642692] Parcel 338 ENTERS outfeed 5 with service_time=8.500s
# [09:05:44.909000] Parcel 331 ENTERS outfeed 10 with service_time=8.500s
# [09:05:45.640769] Parcel 335 removed from outfeed 3
# [09:05:46.079385] Parcel 320 removed from outfeed 0
# [09:05:46.132615] Parcel 328 removed from outfeed 7
# [09:05:46.709692] Parcel 341 ENTERS outfeed 5 with service_time=8.500s
# [09:05:46.797000] Parcel 333 ENTERS outfeed 10 with service_time=7.500s
# [09:05:47.088846] Parcel 339 removed from outfeed 1
# [09:05:47.675231] Parcel 312 removed from outfeed 4
# [09:05:47.974000] Parcel 334 ENTERS outfeed 10 with service_time=8.500s
# [09:05:48.392692] Parcel 343 ENTERS outfeed 5 with service_time=8.500s
# [09:05:49.184308] Parcel 324 removed from outfeed 2
# [09:05:50.052385] Parcel 353 ENTERS outfeed 0 with service_time=8.500s
# [09:05:50.775538] Parcel 308 removed from outfeed 9
# [09:05:51.554154] Parcel 345 ENTERS outfeed 6 with service_time=8.500s
# [09:05:52.142692] Parcel 338 removed from outfeed 5
# [09:05:52.409154] Parcel 346 ENTERS outfeed 6 with service_time=8.500s
# [09:05:52.838692] Parcel 348 ENTERS outfeed 5 with service_time=8.500s
# [09:05:53.140769] Parcel 336 removed from outfeed 3
# [09:05:53.409000] Parcel 331 removed from outfeed 10
# [09:05:54.632615] Parcel 329 removed from outfeed 7
# [09:05:55.588846] Parcel 342 removed from outfeed 1
# [09:05:56.175231] Parcel 313 removed from outfeed 4
# [09:05:56.397154] Parcel 350 ENTERS outfeed 6 with service_time=8.500s
# [09:05:56.931000] Parcel 344 ENTERS outfeed 10 with service_time=6.500s
# [09:05:57.549154] Parcel 351 ENTERS outfeed 6 with service_time=8.500s
# [09:05:57.684308] Parcel 325 removed from outfeed 2
# [09:05:58.398154] Parcel 352 ENTERS outfeed 6 with service_time=8.500s
# [09:05:58.512077] Parcel 349 ENTERS outfeed 8 with service_time=8.500s
# [09:05:58.552385] Parcel 353 removed from outfeed 0
# [09:05:59.054846] Parcel 361 ENTERS outfeed 1 with service_time=8.500s
# [09:05:59.275538] Parcel 321 removed from outfeed 9
# [09:05:59.629000] Parcel 347 ENTERS outfeed 10 with service_time=8.500s
# [09:06:00.054154] Parcel 345 removed from outfeed 6
# [09:06:00.171154] Parcel 354 ENTERS outfeed 6 with service_time=7.500s
# [09:06:00.642692] Parcel 341 removed from outfeed 5
# [09:06:00.909000] Parcel 333 removed from outfeed 10
# [09:06:01.105154] Parcel 355 ENTERS outfeed 6 with service_time=8.500s
# [09:06:01.640769] Parcel 337 removed from outfeed 3
# [09:06:02.050154] Parcel 356 ENTERS outfeed 6 with service_time=8.500s
# [09:06:02.390846] Parcel 364 ENTERS outfeed 1 with service_time=8.500s
# [09:06:03.132615] Parcel 332 removed from outfeed 7
# [09:06:03.417846] Parcel 365 ENTERS outfeed 1 with service_time=7.500s
# [09:06:03.724154] Parcel 358 ENTERS outfeed 6 with service_time=7.500s
# [09:06:03.998385] Parcel 367 ENTERS outfeed 0 with service_time=8.500s
# [09:06:04.675231] Parcel 315 removed from outfeed 4
# [09:06:05.184308] Parcel 326 removed from outfeed 2
# [09:06:06.180385] Parcel 369 ENTERS outfeed 0 with service_time=8.500s
# [09:06:07.012077] Parcel 349 removed from outfeed 8
# [09:06:07.554846] Parcel 361 removed from outfeed 1
# [09:06:08.554154] Parcel 346 removed from outfeed 6
# [09:06:09.140769] Parcel 340 removed from outfeed 3
# [09:06:09.142692] Parcel 343 removed from outfeed 5
# [09:06:09.409000] Parcel 334 removed from outfeed 10
# [09:06:12.451462] Parcel 359 ENTERS outfeed 11 with service_time=6.500s
# [09:06:12.498385] Parcel 367 removed from outfeed 0
# [09:06:13.175231] Parcel 318 removed from outfeed 4
# [09:06:13.684308] Parcel 327 removed from outfeed 2
# [09:06:13.737385] Parcel 357 ENTERS outfeed 13 with service_time=8.500s
# [09:06:15.909000] Parcel 344 removed from outfeed 10
# [09:06:16.054846] Parcel 364 removed from outfeed 1
# [09:06:16.400462] Parcel 363 ENTERS outfeed 11 with service_time=8.500s
# [09:06:16.646385] Parcel 360 ENTERS outfeed 13 with service_time=8.500s
# [09:06:16.757923] Parcel 362 ENTERS outfeed 12 with service_time=8.500s
# [09:06:17.054154] Parcel 350 removed from outfeed 6
# [09:06:17.642692] Parcel 348 removed from outfeed 5
# [09:06:18.771538] Parcel 368 ENTERS outfeed 9 with service_time=7.500s
# [09:06:18.951462] Parcel 359 removed from outfeed 11
# [09:06:20.998385] Parcel 369 removed from outfeed 0
# [09:06:21.675231] Parcel 319 removed from outfeed 4
# [09:06:21.881538] Parcel 371 ENTERS outfeed 9 with service_time=8.500s
# [09:06:22.184308] Parcel 330 removed from outfeed 2
# [09:06:22.237385] Parcel 357 removed from outfeed 13
# [09:06:22.646385] Parcel 386 ENTERS outfeed 0 with service_time=8.500s
# [09:06:22.837538] Parcel 372 ENTERS outfeed 9 with service_time=8.500s
# [09:06:22.910385] Parcel 366 ENTERS outfeed 13 with service_time=6.500s
# [09:06:23.218077] Parcel 374 ENTERS outfeed 8 with service_time=7.500s
# [09:06:23.554846] Parcel 365 removed from outfeed 1
# [09:06:23.808538] Parcel 373 ENTERS outfeed 9 with service_time=6.500s
# [09:06:24.045462] Parcel 370 ENTERS outfeed 11 with service_time=8.500s
# [09:06:24.409000] Parcel 347 removed from outfeed 10
# [09:06:25.257923] Parcel 362 removed from outfeed 12
# [09:06:25.454077] Parcel 376 ENTERS outfeed 8 with service_time=8.500s
# [09:06:25.525385] Parcel 389 ENTERS outfeed 0 with service_time=7.500s
# [09:06:25.554154] Parcel 351 removed from outfeed 6
# [09:06:25.641538] Parcel 375 ENTERS outfeed 9 with service_time=8.500s
# [09:06:26.114846] Parcel 388 ENTERS outfeed 1 with service_time=7.500s
# [09:06:26.271538] Parcel 368 removed from outfeed 9
# [09:06:26.404385] Parcel 390 ENTERS outfeed 0 with service_time=7.500s
# [09:06:27.451462] Parcel 363 removed from outfeed 11
# [09:06:28.268769] Parcel 387 ENTERS outfeed 3 with service_time=8.500s
# [09:06:29.975846] Parcel 392 ENTERS outfeed 1 with service_time=6.500s
# [09:06:30.718077] Parcel 374 removed from outfeed 8
# [09:06:30.737385] Parcel 360 removed from outfeed 13
# [09:06:31.049846] Parcel 393 ENTERS outfeed 1 with service_time=8.500s
# [09:06:31.108538] Parcel 380 ENTERS outfeed 9 with service_time=8.500s
# [09:06:31.146385] Parcel 386 removed from outfeed 0
# [09:06:31.751462] Parcel 378 ENTERS outfeed 11 with service_time=8.500s
# [09:06:31.822538] Parcel 381 ENTERS outfeed 9 with service_time=8.500s
# [09:06:32.893538] Parcel 382 ENTERS outfeed 9 with service_time=8.500s
# [09:06:33.558231] Parcel 391 ENTERS outfeed 4 with service_time=8.500s
# [09:06:33.599308] Parcel 394 ENTERS outfeed 2 with service_time=8.500s
# [09:06:33.614846] Parcel 388 removed from outfeed 1
# [09:06:34.054154] Parcel 352 removed from outfeed 6
# [09:06:34.422923] Parcel 379 ENTERS outfeed 12 with service_time=6.500s
# [09:06:34.598308] Parcel 395 ENTERS outfeed 2 with service_time=6.500s
# [09:06:34.724538] Parcel 384 ENTERS outfeed 9 with service_time=8.500s
# [09:06:34.771538] Parcel 371 removed from outfeed 9
# [09:06:35.374308] Parcel 396 ENTERS outfeed 2 with service_time=7.500s
# [09:06:35.578538] Parcel 385 ENTERS outfeed 9 with service_time=7.500s
# [09:06:35.597846] Parcel 377 ENTERS outfeed 14 with service_time=8.500s
# [09:06:35.951462] Parcel 370 removed from outfeed 11
# [09:06:36.355308] Parcel 397 ENTERS outfeed 2 with service_time=8.500s
# [09:06:36.768769] Parcel 387 removed from outfeed 3
# [09:06:37.237385] Parcel 366 removed from outfeed 13
# [09:06:38.515923] Parcel 383 ENTERS outfeed 12 with service_time=8.500s
# [09:06:38.646385] Parcel 389 removed from outfeed 0
# [09:06:39.218077] Parcel 376 removed from outfeed 8
# [09:06:39.301308] Parcel 400 ENTERS outfeed 2 with service_time=6.500s
# [09:06:40.114846] Parcel 392 removed from outfeed 1
# [09:06:40.553231] Parcel 398 ENTERS outfeed 4 with service_time=8.500s
# [09:06:40.922923] Parcel 379 removed from outfeed 12
# [09:06:41.554154] Parcel 354 removed from outfeed 6
# [09:06:42.058231] Parcel 391 removed from outfeed 4
# [09:06:42.099308] Parcel 394 removed from outfeed 2
# [09:06:43.271538] Parcel 372 removed from outfeed 9
# ...
# [09:30:04.303385] Parcel 1866 removed from outfeed 13
# [09:30:04.934308] Parcel 1894 ENTERS outfeed 2 with service_time=8.500s
# [09:30:05.973000] Parcel 1882 ENTERS outfeed 10 with service_time=7.500s
# [09:30:06.076154] Parcel 1841 removed from outfeed 6
# [09:30:06.459000] Parcel 1873 removed from outfeed 10
# [09:30:07.663538] Parcel 1862 removed from outfeed 9
# [09:30:07.673692] Parcel 1877 removed from outfeed 5
# [09:30:07.897385] Parcel 1879 ENTERS outfeed 13 with service_time=8.500s
# [09:30:08.084615] Parcel 1889 ENTERS outfeed 7 with service_time=6.500s
# [09:30:08.413000] Parcel 1884 ENTERS outfeed 10 with service_time=8.500s
# [09:30:09.134462] Parcel 1883 ENTERS outfeed 11 with service_time=8.500s
# [09:30:09.765231] Parcel 1896 ENTERS outfeed 4 with service_time=8.500s
# [09:30:10.610231] Parcel 1897 ENTERS outfeed 4 with service_time=7.500s
# [09:30:10.699308] Parcel 1891 removed from outfeed 2
# [09:30:10.791615] Parcel 1892 ENTERS outfeed 7 with service_time=7.500s
# [09:30:11.803385] Parcel 1888 removed from outfeed 0
# [09:30:12.313923] Parcel 1885 ENTERS outfeed 12 with service_time=8.500s
# [09:30:12.323462] Parcel 1878 removed from outfeed 11
# [09:30:12.387846] Parcel 1870 removed from outfeed 1
# [09:30:12.439231] Parcel 1899 ENTERS outfeed 4 with service_time=7.500s
# [09:30:13.299923] Parcel 1886 ENTERS outfeed 12 with service_time=8.500s
# [09:30:13.536000] Parcel 1890 ENTERS outfeed 10 with service_time=8.500s
# [09:30:13.959000] Parcel 1875 removed from outfeed 10
# [09:30:14.332231] Parcel 1901 ENTERS outfeed 4 with service_time=8.500s
# [09:30:14.576154] Parcel 1842 removed from outfeed 6
# [09:30:14.584615] Parcel 1889 removed from outfeed 7
# [09:30:14.707769] Parcel 1903 ENTERS outfeed 3 with service_time=8.500s
# [09:30:16.173692] Parcel 1880 removed from outfeed 5
# [09:30:16.193615] Parcel 1898 ENTERS outfeed 7 with service_time=6.500s
# [09:30:16.397385] Parcel 1879 removed from outfeed 13
# [09:30:16.514769] Parcel 1905 ENTERS outfeed 3 with service_time=6.500s
# [09:30:17.172385] Parcel 1911 ENTERS outfeed 0 with service_time=7.500s
# [09:30:17.457769] Parcel 1906 ENTERS outfeed 3 with service_time=7.500s
# [09:30:17.881462] Parcel 1893 ENTERS outfeed 11 with service_time=8.500s
# [09:30:18.265231] Parcel 1896 removed from outfeed 4
# [09:30:18.328385] Parcel 1912 ENTERS outfeed 0 with service_time=8.500s
# [09:30:19.199308] Parcel 1894 removed from outfeed 2
# [09:30:19.277077] Parcel 1900 ENTERS outfeed 8 with service_time=8.500s
# [09:30:19.675462] Parcel 1895 ENTERS outfeed 11 with service_time=8.500s
# [09:30:19.721231] Parcel 1907 ENTERS outfeed 4 with service_time=8.500s
# [09:30:19.792769] Parcel 1909 ENTERS outfeed 3 with service_time=6.500s
# [09:30:19.887846] Parcel 1871 removed from outfeed 1
# [09:30:20.000615] Parcel 1902 ENTERS outfeed 7 with service_time=8.500s
# [09:30:20.190385] Parcel 1914 ENTERS outfeed 0 with service_time=7.500s
# [09:30:20.813923] Parcel 1885 removed from outfeed 12
# [09:30:20.823462] Parcel 1883 removed from outfeed 11
# [09:30:21.459000] Parcel 1882 removed from outfeed 10
# [09:30:21.684615] Parcel 1904 ENTERS outfeed 7 with service_time=8.500s
# [09:30:22.084615] Parcel 1892 removed from outfeed 7
# [09:30:23.076154] Parcel 1843 removed from outfeed 6
# [09:30:23.207769] Parcel 1903 removed from outfeed 3
# [09:30:23.673692] Parcel 1881 removed from outfeed 5
# [09:30:24.672385] Parcel 1911 removed from outfeed 0
# [09:30:25.765231] Parcel 1897 removed from outfeed 4
# [09:30:26.249846] Parcel 1919 ENTERS outfeed 1 with service_time=7.500s
# [09:30:27.777077] Parcel 1900 removed from outfeed 8
# [09:30:28.584615] Parcel 1898 removed from outfeed 7
# [09:30:29.313923] Parcel 1886 removed from outfeed 12
# [09:30:29.323462] Parcel 1893 removed from outfeed 11
# [09:30:29.428846] Parcel 1922 ENTERS outfeed 1 with service_time=8.500s
# [09:30:29.707769] Parcel 1905 removed from outfeed 3
# [09:30:29.959000] Parcel 1884 removed from outfeed 10
# [09:30:30.015308] Parcel 1921 ENTERS outfeed 2 with service_time=7.500s
# [09:30:30.143538] Parcel 1910 ENTERS outfeed 9 with service_time=8.500s
# [09:30:31.423846] Parcel 1924 ENTERS outfeed 1 with service_time=8.500s
# [09:30:31.576154] Parcel 1844 removed from outfeed 6
# [09:30:31.965308] Parcel 1923 ENTERS outfeed 2 with service_time=8.500s
# [09:30:33.085538] Parcel 1913 ENTERS outfeed 9 with service_time=8.500s
# [09:30:33.172385] Parcel 1912 removed from outfeed 0
# [09:30:33.265231] Parcel 1899 removed from outfeed 4
# [09:30:33.749846] Parcel 1919 removed from outfeed 1
# [09:30:35.860538] Parcel 1916 ENTERS outfeed 9 with service_time=8.500s
# [09:30:35.978846] Parcel 1908 ENTERS outfeed 14 with service_time=8.500s
# [09:30:37.084615] Parcel 1902 removed from outfeed 7
# [09:30:37.207769] Parcel 1906 removed from outfeed 3
# [09:30:37.515308] Parcel 1921 removed from outfeed 2
# [09:30:37.689538] Parcel 1918 ENTERS outfeed 9 with service_time=8.500s
# [09:30:37.823462] Parcel 1895 removed from outfeed 11
# [09:30:38.459000] Parcel 1890 removed from outfeed 10
# [09:30:38.643538] Parcel 1910 removed from outfeed 9
# [09:30:40.076154] Parcel 1848 removed from outfeed 6
# [09:30:40.173692] Parcel 1927 ENTERS outfeed 5 with service_time=8.500s
# [09:30:40.672385] Parcel 1914 removed from outfeed 0
# [09:30:41.127385] Parcel 1915 ENTERS outfeed 13 with service_time=7.500s
# [09:30:41.765231] Parcel 1901 removed from outfeed 4
# [09:30:41.874692] Parcel 1929 ENTERS outfeed 5 with service_time=7.500s
# [09:30:42.249846] Parcel 1922 removed from outfeed 1
# [09:30:43.094385] Parcel 1917 ENTERS outfeed 13 with service_time=8.500s
# [09:30:43.707769] Parcel 1909 removed from outfeed 3
# [09:30:44.478846] Parcel 1908 removed from outfeed 14
# [09:30:44.674538] Parcel 1925 ENTERS outfeed 9 with service_time=8.500s
# [09:30:44.733154] Parcel 1930 ENTERS outfeed 6 with service_time=7.500s
# [09:30:44.905692] Parcel 1932 ENTERS outfeed 5 with service_time=6.500s
# [09:30:45.584615] Parcel 1904 removed from outfeed 7
# [09:30:45.788385] Parcel 1920 ENTERS outfeed 13 with service_time=7.500s
# [09:30:45.902385] Parcel 1941 ENTERS outfeed 0 with service_time=8.500s
# [09:30:45.988692] Parcel 1933 ENTERS outfeed 5 with service_time=7.500s
# [09:30:46.015308] Parcel 1923 removed from outfeed 2
# [09:30:46.863692] Parcel 1934 ENTERS outfeed 5 with service_time=8.500s
# [09:30:47.100538] Parcel 1928 ENTERS outfeed 9 with service_time=8.500s
# [09:30:47.143538] Parcel 1913 removed from outfeed 9
# [09:30:47.728692] Parcel 1935 ENTERS outfeed 5 with service_time=8.500s
# [09:30:48.627385] Parcel 1915 removed from outfeed 13
# [09:30:48.673692] Parcel 1927 removed from outfeed 5
# [09:30:50.265231] Parcel 1907 removed from outfeed 4
# [09:30:50.749846] Parcel 1924 removed from outfeed 1
# [09:30:51.386385] Parcel 1947 ENTERS outfeed 0 with service_time=7.500s
# [09:30:52.233154] Parcel 1930 removed from outfeed 6
# [09:30:53.710077] Parcel 1936 ENTERS outfeed 8 with service_time=8.500s
# [09:30:53.971154] Parcel 1940 ENTERS outfeed 6 with service_time=7.500s
# [09:30:54.366077] Parcel 1937 ENTERS outfeed 8 with service_time=6.500s
# [09:30:54.402385] Parcel 1941 removed from outfeed 0
# [09:30:54.537769] Parcel 1945 ENTERS outfeed 3 with service_time=8.500s
# [09:30:54.901923] Parcel 1931 ENTERS outfeed 12 with service_time=8.500s
# [09:30:55.245077] Parcel 1938 ENTERS outfeed 8 with service_time=8.500s
# [09:30:55.329769] Parcel 1946 ENTERS outfeed 3 with service_time=8.500s
# [09:30:55.643538] Parcel 1916 removed from outfeed 9
# [09:30:56.119077] Parcel 1939 ENTERS outfeed 8 with service_time=7.500s
# [09:30:56.173692] Parcel 1929 removed from outfeed 5
# [09:30:56.490308] Parcel 1949 ENTERS outfeed 2 with service_time=8.500s
# [09:30:56.951846] Parcel 1951 ENTERS outfeed 1 with service_time=8.500s
# [09:30:57.127385] Parcel 1917 removed from outfeed 13
# [09:30:57.353154] Parcel 1943 ENTERS outfeed 6 with service_time=8.500s
# [09:30:58.048846] Parcel 1952 ENTERS outfeed 1 with service_time=7.500s
# [09:30:58.926846] Parcel 1953 ENTERS outfeed 1 with service_time=8.500s
# [09:30:59.090769] Parcel 1950 ENTERS outfeed 3 with service_time=8.500s
# [09:31:00.120846] Parcel 1954 ENTERS outfeed 1 with service_time=8.500s
# [09:31:00.839538] Parcel 1942 ENTERS outfeed 9 with service_time=8.500s
# [09:31:01.471154] Parcel 1940 removed from outfeed 6
# [09:31:01.511846] Parcel 1955 ENTERS outfeed 1 with service_time=8.500s
# [09:31:01.902385] Parcel 1947 removed from outfeed 0
# [09:31:02.210077] Parcel 1936 removed from outfeed 8
# [09:31:02.261846] Parcel 1956 ENTERS outfeed 1 with service_time=8.500s
# [09:31:02.673692] Parcel 1932 removed from outfeed 5
# [09:31:03.037769] Parcel 1945 removed from outfeed 3
# [09:31:03.085615] Parcel 1948 ENTERS outfeed 7 with service_time=7.500s
# [09:31:03.401923] Parcel 1931 removed from outfeed 12
# [09:31:04.143538] Parcel 1918 removed from outfeed 9
# [09:31:04.627385] Parcel 1920 removed from outfeed 13
# [09:31:04.990308] Parcel 1949 removed from outfeed 2
# [09:31:05.451846] Parcel 1951 removed from outfeed 1
# [09:31:05.938462] Parcel 1944 ENTERS outfeed 11 with service_time=7.500s
# [09:31:06.062385] Parcel 1962 ENTERS outfeed 0 with service_time=8.500s
# [09:31:08.665231] Parcel 1958 ENTERS outfeed 4 with service_time=7.500s
# [09:31:08.710077] Parcel 1937 removed from outfeed 8
# [09:31:09.527231] Parcel 1959 ENTERS outfeed 4 with service_time=8.500s
# [09:31:09.971154] Parcel 1943 removed from outfeed 6
# [09:31:10.173692] Parcel 1933 removed from outfeed 5
# [09:31:10.585615] Parcel 1948 removed from outfeed 7
# [09:31:11.461231] Parcel 1961 ENTERS outfeed 4 with service_time=8.500s
# [09:31:11.537769] Parcel 1946 removed from outfeed 3
# [09:31:12.643538] Parcel 1925 removed from outfeed 9
# [09:31:12.868308] Parcel 1966 ENTERS outfeed 2 with service_time=8.500s
# [09:31:12.951846] Parcel 1952 removed from outfeed 1
# [09:31:13.157231] Parcel 1963 ENTERS outfeed 4 with service_time=8.500s
# [09:31:13.438462] Parcel 1944 removed from outfeed 11
# [09:31:13.843308] Parcel 1967 ENTERS outfeed 2 with service_time=7.500s
# [09:31:14.562385] Parcel 1962 removed from outfeed 0
# [09:31:16.165231] Parcel 1958 removed from outfeed 4
# [09:31:16.723308] Parcel 1970 ENTERS outfeed 2 with service_time=7.500s
# [09:31:16.951000] Parcel 1957 ENTERS outfeed 10 with service_time=8.500s
# [09:31:17.210077] Parcel 1938 removed from outfeed 8
# [09:31:17.750308] Parcel 1971 ENTERS outfeed 2 with service_time=8.500s
# [09:31:18.670615] Parcel 1964 ENTERS outfeed 7 with service_time=8.500s
# [09:31:18.673692] Parcel 1934 removed from outfeed 5
# [09:31:19.830000] Parcel 1960 ENTERS outfeed 10 with service_time=8.500s
# [09:31:20.037769] Parcel 1950 removed from outfeed 3
# [09:31:21.034385] Parcel 1978 ENTERS outfeed 0 with service_time=8.500s
# [09:31:21.143538] Parcel 1928 removed from outfeed 9
# [09:31:21.368308] Parcel 1966 removed from outfeed 2
# [09:31:21.451846] Parcel 1953 removed from outfeed 1
# [09:31:21.999385] Parcel 1979 ENTERS outfeed 0 with service_time=8.500s
# [09:31:22.934385] Parcel 1980 ENTERS outfeed 0 with service_time=8.500s
# [09:31:23.962385] Parcel 1981 ENTERS outfeed 0 with service_time=8.500s
# [09:31:24.665231] Parcel 1959 removed from outfeed 4
# [09:31:24.710077] Parcel 1939 removed from outfeed 8
# [09:31:25.451000] Parcel 1957 removed from outfeed 10
# [09:31:25.792462] Parcel 1965 ENTERS outfeed 11 with service_time=8.500s
# [09:31:26.750154] Parcel 1974 ENTERS outfeed 6 with service_time=8.500s
# [09:31:27.170615] Parcel 1964 removed from outfeed 7
# [09:31:27.173692] Parcel 1935 removed from outfeed 5
# [09:31:27.762154] Parcel 1975 ENTERS outfeed 6 with service_time=7.500s
# [09:31:28.868308] Parcel 1967 removed from outfeed 2
# [09:31:29.508769] Parcel 1982 ENTERS outfeed 3 with service_time=8.500s
# [09:31:29.534385] Parcel 1978 removed from outfeed 0
# [09:31:29.559154] Parcel 1977 ENTERS outfeed 6 with service_time=8.500s
# [09:31:29.643538] Parcel 1942 removed from outfeed 9
# [09:31:29.951846] Parcel 1954 removed from outfeed 1
# [09:31:30.166923] Parcel 1968 ENTERS outfeed 12 with service_time=7.500s
# [09:31:30.628769] Parcel 1983 ENTERS outfeed 3 with service_time=7.500s
# [09:31:30.880000] Parcel 1972 ENTERS outfeed 10 with service_time=8.500s
# [09:31:31.203923] Parcel 1969 ENTERS outfeed 12 with service_time=7.500s
# [09:31:31.877000] Parcel 1973 ENTERS outfeed 10 with service_time=8.500s
# [09:31:33.165231] Parcel 1961 removed from outfeed 4
# [09:31:33.569769] Parcel 1986 ENTERS outfeed 3 with service_time=8.500s
# [09:31:33.951000] Parcel 1960 removed from outfeed 10
# [09:31:34.292462] Parcel 1965 removed from outfeed 11
# [09:31:34.826000] Parcel 1976 ENTERS outfeed 10 with service_time=8.500s
# [09:31:35.250154] Parcel 1974 removed from outfeed 6
# [09:31:36.368308] Parcel 1970 removed from outfeed 2
# [09:31:37.076154] Parcel 1985 ENTERS outfeed 6 with service_time=8.500s
# [09:31:37.666923] Parcel 1968 removed from outfeed 12
# [09:31:38.008769] Parcel 1982 removed from outfeed 3
# [09:31:38.034385] Parcel 1979 removed from outfeed 0
# [09:31:38.451846] Parcel 1955 removed from outfeed 1
# [09:31:38.816692] Parcel 1988 ENTERS outfeed 5 with service_time=8.500s
# [09:31:39.065154] Parcel 1987 ENTERS outfeed 6 with service_time=8.500s
# [09:31:41.665231] Parcel 1963 removed from outfeed 4
# [09:31:42.139692] Parcel 1991 ENTERS outfeed 5 with service_time=8.500s
# [09:31:42.451000] Parcel 1972 removed from outfeed 10
# [09:31:42.750154] Parcel 1975 removed from outfeed 6
# [09:31:42.857615] Parcel 1989 ENTERS outfeed 7 with service_time=8.500s
# [09:31:43.951462] Parcel 1984 ENTERS outfeed 11 with service_time=8.500s
# [09:31:44.868308] Parcel 1971 removed from outfeed 2
# [09:31:44.981692] Parcel 1994 ENTERS outfeed 5 with service_time=8.500s
# [09:31:45.166923] Parcel 1969 removed from outfeed 12
# [09:31:45.508769] Parcel 1983 removed from outfeed 3
# [09:31:46.534385] Parcel 1980 removed from outfeed 0
# [09:31:46.951846] Parcel 1956 removed from outfeed 1
# [09:31:47.164615] Parcel 1993 ENTERS outfeed 7 with service_time=8.500s
# [09:31:47.229692] Parcel 1996 ENTERS outfeed 5 with service_time=7.500s
# [09:31:47.316692] Parcel 1988 removed from outfeed 5
# [09:31:47.375538] Parcel 1990 ENTERS outfeed 9 with service_time=7.500s
# [09:31:49.148538] Parcel 1992 ENTERS outfeed 9 with service_time=8.500s
# [09:31:50.951000] Parcel 1973 removed from outfeed 10
# [09:31:51.250154] Parcel 1977 removed from outfeed 6
# [09:31:51.357615] Parcel 1989 removed from outfeed 7
# [09:31:52.451462] Parcel 1984 removed from outfeed 11
# [09:31:54.008769] Parcel 1986 removed from outfeed 3
# [09:31:54.875538] Parcel 1990 removed from outfeed 9
# [09:31:54.908538] Parcel 1997 ENTERS outfeed 9 with service_time=8.500s
# [09:31:55.034385] Parcel 1981 removed from outfeed 0
# [09:31:55.231077] Parcel 1999 ENTERS outfeed 8 with service_time=8.500s
# [09:31:55.816692] Parcel 1991 removed from outfeed 5
# [09:31:55.831538] Parcel 1998 ENTERS outfeed 9 with service_time=8.500s
# [09:31:57.696538] Parcel 2000 ENTERS outfeed 9 with service_time=8.500s
# [09:31:59.451000] Parcel 1976 removed from outfeed 10
# [09:31:59.750154] Parcel 1985 removed from outfeed 6
# [09:31:59.857615] Parcel 1993 removed from outfeed 7
# [09:32:00.244846] Parcel 1995 ENTERS outfeed 14 with service_time=8.500s
# [09:32:03.375538] Parcel 1992 removed from outfeed 9
# [09:32:03.731077] Parcel 1999 removed from outfeed 8
# [09:32:04.316692] Parcel 1994 removed from outfeed 5
# [09:32:08.250154] Parcel 1987 removed from outfeed 6
# [09:32:08.744846] Parcel 1995 removed from outfeed 14
# [09:32:11.816692] Parcel 1996 removed from outfeed 5
# [09:32:11.875538] Parcel 1997 removed from outfeed 9
# [09:32:20.375538] Parcel 1998 removed from outfeed 9
# [09:32:28.875538] Parcel 2000 removed from outfeed 9
#
# Total parcels: 1994
# Recirculated: 2
# Success rate: 99.90%
# Outfeed 0: 185 parcels, 9.28%
# Outfeed 1: 194 parcels, 9.73%
# Outfeed 2: 172 parcels, 8.63%
# Outfeed 3: 168 parcels, 8.43%
# Outfeed 4: 180 parcels, 9.03%
# Outfeed 5: 151 parcels, 7.57%
# Outfeed 6: 174 parcels, 8.73%
# Outfeed 7: 70 parcels, 3.51%
# Outfeed 8: 104 parcels, 5.22%
# Outfeed 9: 153 parcels, 7.67%
# Outfeed 10: 139 parcels, 6.97%
# Outfeed 11: 120 parcels, 6.02%
# Outfeed 12: 71 parcels, 3.56%
# Outfeed 13: 70 parcels, 3.51%
# Outfeed 14: 43 parcels, 2.16%
# Throughput: 1996
