# %% [markdown]
# PosiSorterSystem:
# -

# %% [markdown]
# Import packages:

# %%
import pandas as pd
from datetime import timedelta
import random

# %% [markdown]
# System parameters:

# %%
base_time       =   4.5
delay_small     =   0
delay_medium    =   1  
delay_large     =   2

# %% [markdown]
# Parcel information:

# %%
class Parcel:
    def __init__(self, parcel_id, arrival_time, length, width, height, weight, feasible_outfeeds):
        self.id = parcel_id                 #Stores parcel number
        self.arrival_time = arrival_time    #Stores arrival time
        self.length = length                #Stores length
        self.width = width                  #Stores width
        self.height = height                #Stores height
        self.weight = weight                #Stores weight
        self.feasible_outfeeds = feasible_outfeeds  #Stores the possible outfeeds
        self.sorted = False                 #Checks if a package gets sorted 
        self.recirculated = False           #Counts if a package gets recirculated 
        self.travel_time = None             #Time it takes to get from the scanner to the outfeed
        self.outfeed_entry_time = None      #Time it takes to get for a parcel to get to the outfeed
        self.removal_time = None            #Time it takes for a parcel to get removed from the outfeed
        self.time_in_system = None          #Total time the parcel spends in the system, so travel time + time in outfeed
        self.orientation_length = 0.0
    
    def effective_length(self):         #Determines in which way the packages go into the outfeed
          if self.orientation == 'sequential':     
            return self.width
          elif self.orientation == 'parallel':
            return self.length
        
    def get_volume(self):               #Calculates volume of the packages 
        return self.length * self.width * self.height
    
def compute_outfeed_time(parcel):       #Determines the amount of time it costs to get unloaded from the outfeeed
    volume = parcel.get_volume()        #Get the volume of parcels and catergorize it
    if volume < 0.303:
        volume_delay = delay_small
    elif volume < 0.375:
        volume_delay = delay_medium
    else:
        volume_delay = delay_large

    weight = parcel.weight              #Get the weight of parcels and catergorize it
    if weight < 2826:
        weight_delay = delay_small
    elif weight < 3817:
        weight_delay = delay_medium
    else:
        weight_delay = delay_large

    return base_time + volume_delay + weight_delay

# %% [markdown]
# Outfeed:

# %%
class Outfeed:
    def __init__(self, max_length=3.0):
        self.max_length = max_length            # Maximum lenght of the outfeed
        self.current_parcels = []               # Stores the occupied length of the outfeed 
        self.current_length = 0.0               # Current length set to 0 at start
        self.time_until_next_discharge = 0.0    # Current waiting time, before package gets unloaded, set to 0 at start

    def can_accept(self, parcel):               # Determines if package can be execpted in a outfeed
        fits = self.current_length + parcel.orientation_length <= self.max_length
        print(f"[DEBUG] Parcel {parcel.id} → needed: {parcel.orientation_length:.2f}, used: {self.current_length:.2f}, fits: {fits}")
        return fits

    def add_parcel(self, parcel):                                               # Adds parcel at certain outfeed
        self.current_parcels.append((parcel, compute_outfeed_time(parcel)))     
        self.current_length += parcel.orientation_length
        if len(self.current_parcels) == 1:
            self.time_until_next_discharge = self.current_parcels[0][1]         # Discharge timer for the parcel    

    def update(self, time_step, system_time):  # Keeping track of all timings in the system      
        if self.current_parcels:
            self.time_until_next_discharge -= time_step
            if self.time_until_next_discharge <= 0:
                parcel, _ = self.current_parcels.pop(0)
                self.current_length -= parcel.orientation_length       
                parcel.removal_time = system_time                   # Time in outfeed
                parcel.time_in_system = parcel.travel_time + (parcel.removal_time - parcel.outfeed_entry_time) # Time parcel spend in system
                print(f"Parcel {parcel.id} removed from outfeed"
                    f"(total system time: {parcel.time_in_system.total_seconds():.2f} s)")
                if self.current_parcels:
                    self.time_until_next_discharge = self.current_parcels[0][1] # Timer for the next parcel in line

# %% [markdown]
# The PosiSorterSystem with the algorithm:

# %%
class PosiSorterSystem:
    def __init__(self, layout_df, num_outfeeds, sorting_method, outfeed_distances, time_step):                # Collects all data/variables of the PosiSorter
        self.belt_speed = layout_df.loc[layout_df['Layout property'] == 'Belt Speed', 'Value'].values[0]  # Belt speed  
        self.num_outfeeds = num_outfeeds                       #Amount of outfeeds
        self.outfeeds = [Outfeed(max_length=3.0) for _ in range(self.num_outfeeds)] #Outfeed information
        self.recirculation_belt = []                # Stores recirculated packages
        self.processed_parcels = []                 # Tracks all parcels that go into the system
        self.sorting_method = sorting_method        # Sorting orientation
        self.outfeed_distances = outfeed_distances  # Distances to outfeeds
        self.time_step = time_step                  # Time step
    
    def calculate_travel_time(self, parcel, outfeed_index):     # Travel time calculation
        distance = self.outfeed_distances[outfeed_index]        # Distance to be travelled
        travel_seconds = distance / self.belt_speed             # Time takes to travel
        parcel.travel_time = timedelta(seconds=travel_seconds)  # Store the time it takes to travel 
     
    def set_parcel_timing(self, parcel, outfeed_index):         # Parcel timings
        parcel.outfeed_entry_time = self.current_time           # Record time parcel enters outfeed
        self.calculate_travel_time(parcel, outfeed_index)       # Calculate travel time to outfeed
        parcel.sorted = True                                     
 
    def get_feasible_allocation(self, parcel):
        min_load = float('inf')  # Initialize with an infinite value 
        selected_outfeed = None # No outfeed selected yet
        for outfeed_index in parcel.feasible_outfeeds:   # Iterate through each outfeed the parcel could go to
            outfeed = self.outfeeds[outfeed_index]       # Retrieve outfeed
            projected_load = outfeed.current_length + parcel.orientation_length # Make a load projection for outfeed with parcel
            if projected_load <= outfeed.max_length and projected_load < min_load: # If the projected load fits and is less than the current minimum, update the best choice
               min_load = projected_load
               selected_outfeed = outfeed_index
        return selected_outfeed # Return the chosen outfeed index

    def build_initial_allocations(self, lookahead_parcels):
        allocations = {}  # Dictionary to store (parcel, assigned outfeed) for each parcel
        for parcel in lookahead_parcels:    # Iterate through all parcels in the lookahead window
            parcel.orientation = self.sorting_method
            parcel.orientation_length = parcel.effective_length()
            outfeed_index = self.get_feasible_allocation(parcel)
            allocations[parcel.id] = (parcel, outfeed_index) # Save the allocation in the dictionary
        return allocations # Return dictionary with allocations for the aprcels

    def project_loads(self, allocations):
        projection = {i: self.outfeeds[i].current_length for i in range(self.num_outfeeds)} # Start with the current length of each outfeed (before adding any parcels)
        for parcel, outfeed_index in allocations.values(): # Go through each (parcel, assigned outfeed)
            if outfeed_index is not None:
               projection[outfeed_index] += parcel.orientation_length # Add the parcel's length to the projected load
        return projection

    def rebalance_allocations(self, allocations, buffer_projection):
        i_max = max(buffer_projection, key=buffer_projection.get) # Identify the outfeed with the highest projected load
        i_min = min(buffer_projection, key=buffer_projection.get) # Identify the outfeed with the lowest projected load

        for pid, (parcel, outfeed_index) in allocations.items():    # Iterate over each parcel and its assigned outfeed, pid -> parcel id
            if outfeed_index == i_max and i_min in parcel.feasible_outfeeds: # Consider parcels assigned to most loaded outfeed, and eligible to go to the least loaded one
               if buffer_projection[i_min] + parcel.orientation_length <= self.outfeeds[i_min].max_length: # Check if the least loaded outfeed can accept this parcel without exceeding max lengt
                  allocations[pid] = (parcel, i_min)  # Reassign to the less loaded outfeed
                  buffer_projection[i_max] -= parcel.orientation_length # Adjust the projections
                  buffer_projection[i_min] += parcel.orientation_length


    def finalize_sorting(self, parcel, outfeed_index):
        if outfeed_index is not None:
           outfeed = self.outfeeds[outfeed_index]
           if outfeed.can_accept(parcel): # Check if outfeed can accept
              outfeed.add_parcel(parcel) # Add parcel to outfeed
              self.set_parcel_timing(parcel, outfeed_index) # Print info and mark as sorted
              print(f"Parcel {parcel.id} sorted to outfeed {outfeed_index} (travel time: {parcel.travel_time.total_seconds():.2f} seconds)")
              parcel.sorted = True
              return
        parcel.recirculated = True   # Recirculate if no outfeed was accepted 
        self.recirculation_belt.append(parcel)
        print(f"Parcel {parcel.id} could not be sorted and was recirculated.")
   
    def sort_parcels_with_lookahead(self, lookahead_parcels):
        if not lookahead_parcels:
           return

        allocations = self.build_initial_allocations(lookahead_parcels) # Compute initial best outfeed for each parce
        buffer_projection = self.project_loads(allocations)             # Simulate future loads on each outfeed
        self.rebalance_allocations(allocations, buffer_projection)      # Try to balance load by reassigning some parcels

        first_parcel = lookahead_parcels[0] # Only actually sort the first parcel, the rest are projections
        _, chosen_outfeed = allocations.get(first_parcel.id, (first_parcel, None)) # Get the chosen outfeed
        self.finalize_sorting(first_parcel, chosen_outfeed) # Sort or recirculate package


    def remove_from_outfeeds(self, time_step):                  # Update each outfeed with the current time and timestep
        for outfeed in self.outfeeds:
            outfeed.update(time_step, self.current_time)

    def run_simulation(self, parcels, lookahead_size):                              # Run the simulation
        current_time = parcels[0].arrival_time                      # Set current time
        self.current_time = current_time                         
        end_time = parcels[-1].arrival_time + timedelta(seconds=30) # Buffer to make sure all packages are sorted
        parcel_index = 0                                            # To track next parcel that must be processed

        while current_time <= end_time:
            print(f"\n--- Time: {current_time.time()} ---")

            # Check for arrivals
            while parcel_index < len(parcels) and parcels[parcel_index].arrival_time <= current_time:
                parcel = parcels[parcel_index]
                parcel_index += 1
                self.processed_parcels.append(parcel)
                print(f"Parcel {parcel.id} arrived – feasible outfeeds: {parcel.feasible_outfeeds}")
                # Look-ahead buffer of upcoming parcels
                start = max(0, parcel_index - 1)
                end = min(len(parcels), start + lookahead_size)
                buffered_parcels = parcels[start:end]

                self.sort_parcels_with_lookahead(buffered_parcels)


            self.remove_from_outfeeds(self.time_step)
            current_time += timedelta(seconds = self.time_step)

        self.print_summary()  # Print summary                                  

    def print_summary(self):                                        # Get summary of simulation
        total = len(self.processed_parcels)                         # Get total length
        sorted_count = sum(p.sorted for p in self.processed_parcels)# Get count of amount of packages that are sorted
        recirculated_count = sum(p.recirculated for p in self.processed_parcels) # Get count of amount of packages that are recirculated
        total_time = [p.time_in_system for p in self.processed_parcels if p.time_in_system is not None] # Calculate the total time spent in the system for all parcels that were sorted
        if total_time:  # Calculate the average time spent in the system for all parcels that were sorted
            avg_total_time = sum(t.total_seconds() for t in total_time) / len(total_time)
        print("\n--- Simulation Summary ---") # Print everything 
        print(f"Total parcels processed: {total}")
        print(f"Parcels sorted: {sorted_count}")
        print(f"Parcels recirculated: {recirculated_count}")
        print(f"Sorting success rate: {sorted_count / total:.2%}")
        print(f"Average total system time per parcel: {avg_total_time:.2f} seconds")
        if hasattr(self, 'drop_info'):
           print("\n--- Removed Parcels ---")
           print(f"Initial amount of parcels: {self.drop_info['initial']}")
           print(f"Removed due to NaNs: {self.drop_info['na_dropped']}")
           print(f"Removed due to extreme outliers (data entry errors): {self.drop_info['outliers_dropped']}")
           print(f"Removed due to no feasible outfeeds: {self.drop_info['no_outfeeds_dropped']}")
           print(f"Removed due to non-chronological arrival times (scanning error): {self.drop_info.get('non_chrono_dropped', 0)}")
           print(f"Total parcels removed before processing: {self.drop_info['total_dropped']}")
        return

# %% [markdown]
# Excel data cleaning and loading:

# %%
def drop_non_chronological_arrivals(df):                  # Remove rows with non-chronological arrival times
    valid_times = []
    last_time = pd.Timestamp.min                          # Initialize with the earliest possible timestamp

    for i, time in enumerate(df["Arrival Time"]):         # Loop through each arrival time in the DataFrame
        if time >= last_time:
            valid_times.append(True)                      # If not chronogica, append
            last_time = time
        else:
            valid_times.append(False)                     # If not chronogical, don't append

    return df[valid_times].reset_index(drop=True)

def remove_outliers_iqr(df, columns):                       # Remove outliers from colums using IQR
    for col in columns:                                     
        Q1 = df[col].quantile(0.25)                         # First quartile
        Q3 = df[col].quantile(0.75)                         # Last quartile
        IQR = Q3 - Q1                                       # Interquertile range
        lower_bound = Q1 - 7 * IQR                          # Lower bound for outlier detection 
        upper_bound = Q3 + 7 * IQR                          # Upper bound for outlier detection 
        df = df[df[col].between(lower_bound, upper_bound)]  # Keep only rows that are in bound
    return df


def drop_rows_without_true_outfeed(df, prefix="Outfeed"):               # Removes columns that have no possible outfeed
    outfeed_cols = [col for col in df.columns if col.startswith(prefix)]# Get all columns
    if not outfeed_cols:                                                # Remove columns that have no outfeed
        return df        
    mask = df[outfeed_cols].any(axis=1)                                 # Store columns with outfeed                    
    return df[mask]                                                     


def clean_parcel_data(parcels_df):                              # Cleans the data
    drop_info = {}                                              # Store removed rows
    drop_info['initial'] = initial_count = len(parcels_df)      # Initialize count
 
    parcels_df = parcels_df.dropna().reset_index(drop=True)     # Remove rows with NaNs
    after_na = len(parcels_df) 
    drop_info['na_dropped'] = initial_count - after_na          # Track amount of rows dropped due to NaNs

    before_outliers = len(parcels_df)                                           # Remove rows with outliers
    parcels_df = remove_outliers_iqr(parcels_df, ["Length", "Width", "Height"])
    after_outliers = len(parcels_df)
    drop_info['outliers_dropped'] = before_outliers - after_outliers            # Track amount of rows dropped due to outlying values
 
    before_outfeeds = len(parcels_df)                                           # Remove rows with no feasible outfeeds
    parcels_df = drop_rows_without_true_outfeed(parcels_df)                      
    after_outfeeds = len(parcels_df) 
    drop_info['no_outfeeds_dropped'] = before_outfeeds - after_outfeeds         # Track amount of rows dropped due to no feasible outfeeds
 
    before_chrono = len(parcels_df)                                             # Remove rows with non-chronological arrival times
    parcels_df = drop_non_chronological_arrivals(parcels_df)
    after_chrono = len(parcels_df)
    drop_info['non_chrono_dropped'] = before_chrono - after_chrono              # Track amount of rows dropped due to no non-chronological arrival time
 

    drop_info['total_dropped'] = drop_info['na_dropped'] + drop_info['outliers_dropped'] + drop_info['no_outfeeds_dropped'] + drop_info['non_chrono_dropped']

    return parcels_df, drop_info

def load_parcels_from_clean_df(df, num_outfeeds):                             # Load the data from the excel sheet 
    parcels = []                                                # Store parcel information
    for _, row in df.iterrows():                                 
        parcel_id = int(row['Parcel Number'])                   # Parcel number
        arrival_time = pd.to_datetime(row['Arrival Time'])      # Arrival time package
        length = float(row['Length'])                           # Lenght of package
        width = float(row['Width'])                             # Width of package
        height = float(row['Height'])                           # Height of package
        weight = float(row['Weight'])                           # Weight of package
        feasible_outfeeds = [i for i in range(num_outfeeds) if row.get(f'Outfeed {i+1}', False)] # Feasible outfeeds
        parcels.append(Parcel(parcel_id, arrival_time, length, width, height, weight, feasible_outfeeds))
    return sorted(parcels, key=lambda p: p.arrival_time)

# %% [markdown]
# Main:

# %%
def main():
    xls = pd.ExcelFile("PosiSorterData_3.xlsx")              # Load excel sheet with parcel data
    parcels_df = xls.parse('Parcels')                       # Gets Parcels sheet of Excel file
    layout_df = xls.parse('Layout')                         # Gets Layout sheet of Excel file
 
    
    # Code parameters
    sorting_method = 'parallel'                 # Choose sorting method: 'parallel' or 'sequential'
    num_outfeeds = 51                          # Number of outfeeds
    lookahead_size = 5                         # Lookahead size
    time_step = 0.1                           # Time step

    
    parcels_df, drop_info = clean_parcel_data(parcels_df)   # Clear the data
 
    parcels = load_parcels_from_clean_df(parcels_df, num_outfeeds)        # Configurate the clean data into a list with parcel objects
    # Calculate outfeed distances
    outfeed_distances = {i: 5.5 + i * 2.5 for i in range(num_outfeeds)}
    # Gives all necessery information to PosiSorterSystem
    system = PosiSorterSystem(layout_df, sorting_method = sorting_method, num_outfeeds = num_outfeeds, outfeed_distances = outfeed_distances, time_step = time_step)
    system.drop_info = drop_info    # Get information for the removed parcels
    system.run_simulation(parcels, lookahead_size)  # Runs the simulation    

# Entry point of the code    
if __name__ == "__main__":
    main()
# Out:
# --- Time: 09:00:01.236000 ---
# Parcel 1 arrived – feasible outfeeds: [17, 29]
# [DEBUG] Parcel 1 → needed: 1.23, used: 0.00, fits: True
# Parcel 1 sorted to outfeed 17 (travel time: 42.86 seconds)
#
# --- Time: 09:00:01.336000 ---
#
# --- Time: 09:00:01.436000 ---
#
# --- Time: 09:00:01.536000 ---
#
# --- Time: 09:00:01.636000 ---
#
# --- Time: 09:00:01.736000 ---
#
# --- Time: 09:00:01.836000 ---
# Parcel 2 arrived – feasible outfeeds: [0, 1, 3, 4, 12, 13, 14, 19, 24, 27, 28, 29, 30, 32, 35, 37, 39, 41, 43, 48]
# [DEBUG] Parcel 2 → needed: 1.12, used: 0.00, fits: True
# Parcel 2 sorted to outfeed 0 (travel time: 4.91 seconds)
#
# --- Time: 09:00:01.936000 ---
#
# --- Time: 09:00:02.036000 ---
#
# --- Time: 09:00:02.136000 ---
#
# --- Time: 09:00:02.236000 ---
#
# --- Time: 09:00:02.336000 ---
# Parcel 3 arrived – feasible outfeeds: [0, 1, 4, 5, 14, 16, 19, 22, 30, 32, 49]
# [DEBUG] Parcel 3 → needed: 0.84, used: 0.00, fits: True
# Parcel 3 sorted to outfeed 1 (travel time: 7.14 seconds)
#
# --- Time: 09:00:02.436000 ---
#
# --- Time: 09:00:02.536000 ---
#
# --- Time: 09:00:02.636000 ---
#
# --- Time: 09:00:02.736000 ---
#
# --- Time: 09:00:02.836000 ---
# Parcel 4 arrived – feasible outfeeds: [2, 7, 8, 13, 16, 27, 37, 40, 50]
# [DEBUG] Parcel 4 → needed: 1.17, used: 0.00, fits: True
# Parcel 4 sorted to outfeed 2 (travel time: 9.38 seconds)
#
# --- Time: 09:00:02.936000 ---
#
# --- Time: 09:00:03.036000 ---
#
# --- Time: 09:00:03.136000 ---
#
# --- Time: 09:00:03.236000 ---
#
# --- Time: 09:00:03.336000 ---
# Parcel 5 arrived – feasible outfeeds: [2, 4, 5, 7, 8, 16, 18, 20, 22, 25, 26, 28, 29, 31, 32, 40, 44, 47, 48, 49]
# [DEBUG] Parcel 5 → needed: 1.14, used: 0.00, fits: True
# Parcel 5 sorted to outfeed 4 (travel time: 13.84 seconds)
#
# --- Time: 09:00:03.436000 ---
#
# --- Time: 09:00:03.536000 ---
#
# --- Time: 09:00:03.636000 ---
#
# --- Time: 09:00:03.736000 ---
#
# --- Time: 09:00:03.836000 ---
#
# --- Time: 09:00:03.936000 ---
#
# --- Time: 09:00:04.036000 ---
#
# --- Time: 09:00:04.136000 ---
#
# --- Time: 09:00:04.236000 ---
#
# --- Time: 09:00:04.336000 ---
#
# --- Time: 09:00:04.436000 ---
#
# --- Time: 09:00:04.536000 ---
#
# --- Time: 09:00:04.636000 ---
#
# --- Time: 09:00:04.736000 ---
#
# --- Time: 09:00:04.836000 ---
#
# --- Time: 09:00:04.936000 ---
#
# --- Time: 09:00:05.036000 ---
#
# --- Time: 09:00:05.136000 ---
#
# --- Time: 09:00:05.236000 ---
#
# --- Time: 09:00:05.336000 ---
#
# --- Time: 09:00:05.436000 ---
#
# --- Time: 09:00:05.536000 ---
#
# --- Time: 09:00:05.636000 ---
# Parcel 6 arrived – feasible outfeeds: [1, 3, 6, 9, 12, 13, 18, 22, 41]
# [DEBUG] Parcel 6 → needed: 1.50, used: 0.00, fits: True
# Parcel 6 sorted to outfeed 3 (travel time: 11.61 seconds)
#
# --- Time: 09:00:05.736000 ---
#
# --- Time: 09:00:05.836000 ---
#
# --- Time: 09:00:05.936000 ---
#
# --- Time: 09:00:06.036000 ---
#
# --- Time: 09:00:06.136000 ---
#
# --- Time: 09:00:06.236000 ---
# Parcel 2 removed from outfeed(total system time: 4.91 s)
#
# --- Time: 09:00:06.336000 ---
#
# --- Time: 09:00:06.436000 ---
#
# --- Time: 09:00:06.536000 ---
# Parcel 7 arrived – feasible outfeeds: [5, 12, 16, 21, 36, 44, 46, 50]
# [DEBUG] Parcel 7 → needed: 0.96, used: 0.00, fits: True
# Parcel 7 sorted to outfeed 5 (travel time: 16.07 seconds)
#
# --- Time: 09:00:06.636000 ---
#
# --- Time: 09:00:06.736000 ---
#
# --- Time: 09:00:06.836000 ---
# Parcel 8 arrived – feasible outfeeds: [11, 24, 32]
# [DEBUG] Parcel 8 → needed: 1.51, used: 0.00, fits: True
# Parcel 8 sorted to outfeed 11 (travel time: 29.46 seconds)
#
# --- Time: 09:00:06.936000 ---
#
# --- Time: 09:00:07.036000 ---
#
# --- Time: 09:00:07.136000 ---
#
# --- Time: 09:00:07.236000 ---
# Parcel 4 removed from outfeed(total system time: 9.38 s)
#
# --- Time: 09:00:07.336000 ---
#
# --- Time: 09:00:07.436000 ---
#
# --- Time: 09:00:07.536000 ---
#
# --- Time: 09:00:07.636000 ---
#
# --- Time: 09:00:07.736000 ---
# Parcel 1 removed from outfeed(total system time: 42.86 s)
#
# --- Time: 09:00:07.836000 ---
#
# --- Time: 09:00:07.936000 ---
#
# --- Time: 09:00:08.036000 ---
#
# --- Time: 09:00:08.136000 ---
#
# --- Time: 09:00:08.236000 ---
#
# --- Time: 09:00:08.336000 ---
#
# --- Time: 09:00:08.436000 ---
#
# --- Time: 09:00:08.536000 ---
#
# --- Time: 09:00:08.636000 ---
#
# --- Time: 09:00:08.736000 ---
#
# --- Time: 09:00:08.836000 ---
# Parcel 3 removed from outfeed(total system time: 7.14 s)
#
# --- Time: 09:00:08.936000 ---
# Parcel 9 arrived – feasible outfeeds: [1, 16, 24, 36]
# [DEBUG] Parcel 9 → needed: 1.21, used: 0.00, fits: True
# Parcel 9 sorted to outfeed 1 (travel time: 7.14 seconds)
#
# --- Time: 09:00:09.036000 ---
#
# --- Time: 09:00:09.136000 ---
#
# --- Time: 09:00:09.236000 ---
#
# --- Time: 09:00:09.336000 ---
# Parcel 10 arrived – feasible outfeeds: [1, 2, 4, 5, 8, 11, 13, 17, 18, 25, 26, 27, 32, 35, 37, 38, 40, 45, 46, 49]
# [DEBUG] Parcel 10 → needed: 1.09, used: 0.00, fits: True
# Parcel 10 sorted to outfeed 2 (travel time: 9.38 seconds)
#
# --- Time: 09:00:09.436000 ---
#
# --- Time: 09:00:09.536000 ---
#
# --- Time: 09:00:09.636000 ---
#
# --- Time: 09:00:09.736000 ---
#
# --- Time: 09:00:09.836000 ---
# Parcel 5 removed from outfeed(total system time: 13.84 s)
#
# --- Time: 09:00:09.936000 ---
#
# --- Time: 09:00:10.036000 ---
# Parcel 6 removed from outfeed(total system time: 11.61 s)
#
# --- Time: 09:00:10.136000 ---
#
# --- Time: 09:00:10.236000 ---
#
# --- Time: 09:00:10.336000 ---
#
# --- Time: 09:00:10.436000 ---
#
# --- Time: 09:00:10.536000 ---
#
# --- Time: 09:00:10.636000 ---
#
# --- Time: 09:00:10.736000 ---
#
# --- Time: 09:00:10.836000 ---
#
# --- Time: 09:00:10.936000 ---
#
# --- Time: 09:00:11.036000 ---
#
# --- Time: 09:00:11.136000 ---
#
# --- Time: 09:00:11.236000 ---
# Parcel 8 removed from outfeed(total system time: 29.46 s)
#
# --- Time: 09:00:11.336000 ---
#
# --- Time: 09:00:11.436000 ---
#
# --- Time: 09:00:11.536000 ---
#
# --- Time: 09:00:11.636000 ---
#
# --- Time: 09:00:11.736000 ---
#
# --- Time: 09:00:11.836000 ---
#
# --- Time: 09:00:11.936000 ---
#
# --- Time: 09:00:12.036000 ---
#
# --- Time: 09:00:12.136000 ---
#
# --- Time: 09:00:12.236000 ---
#
# --- Time: 09:00:12.336000 ---
#
# --- Time: 09:00:12.436000 ---
#
# --- Time: 09:00:12.536000 ---
#
# --- Time: 09:00:12.636000 ---
#
# --- Time: 09:00:12.736000 ---
#
# --- Time: 09:00:12.836000 ---
#
# --- Time: 09:00:12.936000 ---
#
# --- Time: 09:00:13.036000 ---
# Parcel 7 removed from outfeed(total system time: 16.07 s)
#
# --- Time: 09:00:13.136000 ---
#
# --- Time: 09:00:13.236000 ---
#
# --- Time: 09:00:13.336000 ---
# Parcel 9 removed from outfeed(total system time: 7.14 s)
#
# --- Time: 09:00:13.436000 ---
#
# --- Time: 09:00:13.536000 ---
#
# --- Time: 09:00:13.636000 ---
#
# --- Time: 09:00:13.736000 ---
# Parcel 10 removed from outfeed(total system time: 9.38 s)
#
# --- Time: 09:00:13.836000 ---
#
# --- Time: 09:00:13.936000 ---
#
# --- Time: 09:00:14.036000 ---
#
# --- Time: 09:00:14.136000 ---
#
# --- Time: 09:00:14.236000 ---
#
# --- Time: 09:00:14.336000 ---
#
# --- Time: 09:00:14.436000 ---
# Parcel 12 arrived – feasible outfeeds: [5, 13, 18, 19, 25, 26, 27, 28, 31, 32, 33, 43]
# [DEBUG] Parcel 12 → needed: 1.42, used: 0.00, fits: True
# Parcel 12 sorted to outfeed 5 (travel time: 16.07 seconds)
#
# --- Time: 09:00:14.536000 ---
#
# --- Time: 09:00:14.636000 ---
#
# --- Time: 09:00:14.736000 ---
#
# --- Time: 09:00:14.836000 ---
#
# --- Time: 09:00:14.936000 ---
#
# --- Time: 09:00:15.036000 ---
#
# --- Time: 09:00:15.136000 ---
#
# --- Time: 09:00:15.236000 ---
# Parcel 13 arrived – feasible outfeeds: [2, 9, 16, 17, 30]
# [DEBUG] Parcel 13 → needed: 0.98, used: 0.00, fits: True
# Parcel 13 sorted to outfeed 2 (travel time: 9.38 seconds)
#
# --- Time: 09:00:15.336000 ---
#
# --- Time: 09:00:15.436000 ---
#
# --- Time: 09:00:15.536000 ---
#
# --- Time: 09:00:15.636000 ---
#
# --- Time: 09:00:15.736000 ---
#
# --- Time: 09:00:15.836000 ---
#
# --- Time: 09:00:15.936000 ---
#
# --- Time: 09:00:16.036000 ---
# Parcel 14 arrived – feasible outfeeds: [3, 5, 6, 10, 15, 17, 27, 29, 30, 31, 32, 34, 40, 42, 45, 49]
# [DEBUG] Parcel 14 → needed: 1.43, used: 0.00, fits: True
# Parcel 14 sorted to outfeed 3 (travel time: 11.61 seconds)
#
# --- Time: 09:00:16.136000 ---
#
# --- Time: 09:00:16.236000 ---
#
# --- Time: 09:00:16.336000 ---
#
# --- Time: 09:00:16.436000 ---
#
# --- Time: 09:00:16.536000 ---
#
# --- Time: 09:00:16.636000 ---
#
# --- Time: 09:00:16.736000 ---
#
# --- Time: 09:00:16.836000 ---
#
# --- Time: 09:00:16.936000 ---
#
# --- Time: 09:00:17.036000 ---
#
# --- Time: 09:00:17.136000 ---
#
# --- Time: 09:00:17.236000 ---
#
# --- Time: 09:00:17.336000 ---
#
# --- Time: 09:00:17.436000 ---
#
# --- Time: 09:00:17.536000 ---
#
# --- Time: 09:00:17.636000 ---
#
# --- Time: 09:00:17.736000 ---
#
# --- Time: 09:00:17.836000 ---
#
# --- Time: 09:00:17.936000 ---
#
# --- Time: 09:00:18.036000 ---
#
# --- Time: 09:00:18.136000 ---
#
# --- Time: 09:00:18.236000 ---
# Parcel 15 arrived – feasible outfeeds: [23, 38, 40]
# [DEBUG] Parcel 15 → needed: 1.13, used: 0.00, fits: True
# Parcel 15 sorted to outfeed 23 (travel time: 56.25 seconds)
#
# --- Time: 09:00:18.336000 ---
#
# --- Time: 09:00:18.436000 ---
#
# --- Time: 09:00:18.536000 ---
#
# --- Time: 09:00:18.636000 ---
#
# --- Time: 09:00:18.736000 ---
#
# --- Time: 09:00:18.836000 ---
#
# --- Time: 09:00:18.936000 ---
#
# --- Time: 09:00:19.036000 ---
#
# --- Time: 09:00:19.136000 ---
#
# --- Time: 09:00:19.236000 ---
#
# --- Time: 09:00:19.336000 ---
#
# --- Time: 09:00:19.436000 ---
# Parcel 16 arrived – feasible outfeeds: [15]
# [DEBUG] Parcel 16 → needed: 1.20, used: 0.00, fits: True
# Parcel 16 sorted to outfeed 15 (travel time: 38.39 seconds)
#
# --- Time: 09:00:19.536000 ---
#
# --- Time: 09:00:19.636000 ---
#
# --- Time: 09:00:19.736000 ---
#
# --- Time: 09:00:19.836000 ---
# Parcel 17 arrived – feasible outfeeds: [1, 13, 29, 34, 35, 47]
# [DEBUG] Parcel 17 → needed: 1.36, used: 0.00, fits: True
# Parcel 17 sorted to outfeed 1 (travel time: 7.14 seconds)
#
# --- Time: 09:00:19.936000 ---
#
# --- Time: 09:00:20.036000 ---
#
# --- Time: 09:00:20.136000 ---
#
# --- Time: 09:00:20.236000 ---
#
# --- Time: 09:00:20.336000 ---
#
# --- Time: 09:00:20.436000 ---
#
# --- Time: 09:00:20.536000 ---
#
# --- Time: 09:00:20.636000 ---
#
# --- Time: 09:00:20.736000 ---
#
# --- Time: 09:00:20.836000 ---
#
# --- Time: 09:00:20.936000 ---
# Parcel 12 removed from outfeed(total system time: 16.07 s)
#
# --- Time: 09:00:21.036000 ---
#
# --- Time: 09:00:21.136000 ---
#
# --- Time: 09:00:21.236000 ---
#
# --- Time: 09:00:21.336000 ---
#
# --- Time: 09:00:21.436000 ---
#
# --- Time: 09:00:21.536000 ---
#
# --- Time: 09:00:21.636000 ---
#
# --- Time: 09:00:21.736000 ---
# Parcel 13 removed from outfeed(total system time: 9.38 s)
#
# --- Time: 09:00:21.836000 ---
#
# --- Time: 09:00:21.936000 ---
#
# --- Time: 09:00:22.036000 ---
# Parcel 18 arrived – feasible outfeeds: [2, 7, 12, 16, 24, 36, 42, 43]
# [DEBUG] Parcel 18 → needed: 1.68, used: 0.00, fits: True
# Parcel 18 sorted to outfeed 2 (travel time: 9.38 seconds)
#
# --- Time: 09:00:22.136000 ---
#
# --- Time: 09:00:22.236000 ---
#
# --- Time: 09:00:22.336000 ---
#
# --- Time: 09:00:22.436000 ---
#
# --- Time: 09:00:22.536000 ---
# Parcel 14 removed from outfeed(total system time: 11.61 s)
#
# --- Time: 09:00:22.636000 ---
# Parcel 15 removed from outfeed(total system time: 56.25 s)
#
# --- Time: 09:00:22.736000 ---
# Parcel 19 arrived – feasible outfeeds: [0, 3, 4, 7, 13, 17, 18, 19, 23, 33, 34, 36, 37, 40, 41, 42, 43, 48]
# [DEBUG] Parcel 19 → needed: 1.16, used: 0.00, fits: True
# Parcel 19 sorted to outfeed 0 (travel time: 4.91 seconds)
#
# --- Time: 09:00:22.836000 ---
#
# --- Time: 09:00:22.936000 ---
#
# --- Time: 09:00:23.036000 ---
#
# --- Time: 09:00:23.136000 ---
#
# --- Time: 09:00:23.236000 ---
#
# --- Time: 09:00:23.336000 ---
#
# --- Time: 09:00:23.436000 ---
#
# --- Time: 09:00:23.536000 ---
#
# --- Time: 09:00:23.636000 ---
#
# --- Time: 09:00:23.736000 ---
#
# --- Time: 09:00:23.836000 ---
#
# --- Time: 09:00:23.936000 ---
#
# --- Time: 09:00:24.036000 ---
#
# --- Time: 09:00:24.136000 ---
#
# --- Time: 09:00:24.236000 ---
# Parcel 17 removed from outfeed(total system time: 7.14 s)
#
# --- Time: 09:00:24.336000 ---
#
# --- Time: 09:00:24.436000 ---
#
# --- Time: 09:00:24.536000 ---
#
# --- Time: 09:00:24.636000 ---
#
# --- Time: 09:00:24.736000 ---
#
# --- Time: 09:00:24.836000 ---
#
# --- Time: 09:00:24.936000 ---
#
# --- Time: 09:00:25.036000 ---
#
# --- Time: 09:00:25.136000 ---
#
# --- Time: 09:00:25.236000 ---
#
# --- Time: 09:00:25.336000 ---
# Parcel 20 arrived – feasible outfeeds: [3, 4, 6, 8, 10, 12, 13, 15, 18, 20, 21, 31, 35, 36, 39, 41, 43, 44, 48, 49]
# [DEBUG] Parcel 20 → needed: 1.31, used: 0.00, fits: True
# Parcel 20 sorted to outfeed 3 (travel time: 11.61 seconds)
#
# --- Time: 09:00:25.436000 ---
#
# --- Time: 09:00:25.536000 ---
# Parcel 21 arrived – feasible outfeeds: [33, 41]
# [DEBUG] Parcel 21 → needed: 1.12, used: 0.00, fits: True
# Parcel 21 sorted to outfeed 33 (travel time: 78.57 seconds)
#
# --- Time: 09:00:25.636000 ---
#
# --- Time: 09:00:25.736000 ---
#
# --- Time: 09:00:25.836000 ---
#
# --- Time: 09:00:25.936000 ---
# Parcel 16 removed from outfeed(total system time: 38.39 s)
#
# --- Time: 09:00:26.036000 ---
#
# --- Time: 09:00:26.136000 ---
#
# --- Time: 09:00:26.236000 ---
#
# --- Time: 09:00:26.336000 ---
#
# --- Time: 09:00:26.436000 ---
# Parcel 18 removed from outfeed(total system time: 9.38 s)
#
# --- Time: 09:00:26.536000 ---
#
# --- Time: 09:00:26.636000 ---
#
# --- Time: 09:00:26.736000 ---
#
# --- Time: 09:00:26.836000 ---
#
# --- Time: 09:00:26.936000 ---
#
# --- Time: 09:00:27.036000 ---
#
# --- Time: 09:00:27.136000 ---
# Parcel 22 arrived – feasible outfeeds: [2, 3, 5, 6, 10, 11, 18, 19, 20, 23, 25, 27, 28, 32, 33, 36, 40, 41, 43, 45]
# [DEBUG] Parcel 22 → needed: 1.28, used: 0.00, fits: True
# Parcel 22 sorted to outfeed 2 (travel time: 9.38 seconds)
#
# --- Time: 09:00:27.236000 ---
#
# --- Time: 09:00:27.336000 ---
#
# --- Time: 09:00:27.436000 ---
#
# --- Time: 09:00:27.536000 ---
#
# --- Time: 09:00:27.636000 ---
#
# --- Time: 09:00:27.736000 ---
#
# --- Time: 09:00:27.836000 ---
#
# --- Time: 09:00:27.936000 ---
#
# --- Time: 09:00:28.036000 ---
#
# --- Time: 09:00:28.136000 ---
#
# --- Time: 09:00:28.236000 ---
#
# --- Time: 09:00:28.336000 ---
#
# --- Time: 09:00:28.436000 ---
#
# --- Time: 09:00:28.536000 ---
#
# --- Time: 09:00:28.636000 ---
#
# --- Time: 09:00:28.736000 ---
#
# --- Time: 09:00:28.836000 ---
# Parcel 23 arrived – feasible outfeeds: [8, 9, 21, 25, 27, 35, 37, 47]
# [DEBUG] Parcel 23 → needed: 1.00, used: 0.00, fits: True
# Parcel 23 sorted to outfeed 8 (travel time: 22.77 seconds)
#
# --- Time: 09:00:28.936000 ---
#
# --- Time: 09:00:29.036000 ---
# Parcel 24 arrived – feasible outfeeds: [7, 15, 17, 27, 35, 39, 41, 46, 50]
# [DEBUG] Parcel 24 → needed: 1.07, used: 0.00, fits: True
# Parcel 24 sorted to outfeed 7 (travel time: 20.54 seconds)
#
# --- Time: 09:00:29.136000 ---
#
# --- Time: 09:00:29.236000 ---
# Parcel 19 removed from outfeed(total system time: 4.91 s)
#
# --- Time: 09:00:29.336000 ---
#
# --- Time: 09:00:29.436000 ---
#
# --- Time: 09:00:29.536000 ---
#
# --- Time: 09:00:29.636000 ---
#
# --- Time: 09:00:29.736000 ---
#
# --- Time: 09:00:29.836000 ---
# Parcel 25 arrived – feasible outfeeds: [1, 6, 7, 9, 13, 20, 21, 25, 26, 34, 35, 36, 38, 39, 47, 49, 50]
# [DEBUG] Parcel 25 → needed: 0.66, used: 0.00, fits: True
# Parcel 25 sorted to outfeed 1 (travel time: 7.14 seconds)
#
# --- Time: 09:00:29.936000 ---
# Parcel 21 removed from outfeed(total system time: 78.57 s)
#
# --- Time: 09:00:30.036000 ---
#
# --- Time: 09:00:30.136000 ---
#
# --- Time: 09:00:30.236000 ---
#
# --- Time: 09:00:30.336000 ---
#
# --- Time: 09:00:30.436000 ---
#
# --- Time: 09:00:30.536000 ---
#
# --- Time: 09:00:30.636000 ---
#
# --- Time: 09:00:30.736000 ---
#
# --- Time: 09:00:30.836000 ---
#
# --- Time: 09:00:30.936000 ---
#
# --- Time: 09:00:31.036000 ---
#
# --- Time: 09:00:31.136000 ---
#
# --- Time: 09:00:31.236000 ---
#
# --- Time: 09:00:31.336000 ---
#
# --- Time: 09:00:31.436000 ---
#
# --- Time: 09:00:31.536000 ---
#
# --- Time: 09:00:31.636000 ---
#
# --- Time: 09:00:31.736000 ---
#
# --- Time: 09:00:31.836000 ---
# Parcel 20 removed from outfeed(total system time: 11.61 s)
#
# --- Time: 09:00:31.936000 ---
#
# --- Time: 09:00:32.036000 ---
#
# --- Time: 09:00:32.136000 ---
#
# --- Time: 09:00:32.236000 ---
#
# --- Time: 09:00:32.336000 ---
#
# --- Time: 09:00:32.436000 ---
#
# --- Time: 09:00:32.536000 ---
# Parcel 26 arrived – feasible outfeeds: [2, 3, 7, 8, 14, 20, 23, 27, 28, 29, 31, 32, 34, 38, 39, 43, 49]
# [DEBUG] Parcel 26 → needed: 0.77, used: 0.00, fits: True
# Parcel 26 sorted to outfeed 3 (travel time: 11.61 seconds)
#
# --- Time: 09:00:32.636000 ---
#
# --- Time: 09:00:32.736000 ---
#
# --- Time: 09:00:32.836000 ---
#
# --- Time: 09:00:32.936000 ---
#
# --- Time: 09:00:33.036000 ---
#
# --- Time: 09:00:33.136000 ---
#
# --- Time: 09:00:33.236000 ---
# Parcel 23 removed from outfeed(total system time: 22.77 s)
#
# --- Time: 09:00:33.336000 ---
#
# --- Time: 09:00:33.436000 ---
# Parcel 24 removed from outfeed(total system time: 20.54 s)
#
# --- Time: 09:00:33.536000 ---
#
# --- Time: 09:00:33.636000 ---
# Parcel 22 removed from outfeed(total system time: 9.38 s)
#
# --- Time: 09:00:33.736000 ---
#
# --- Time: 09:00:33.836000 ---
#
# --- Time: 09:00:33.936000 ---
#
# --- Time: 09:00:34.036000 ---
#
# --- Time: 09:00:34.136000 ---
#
# --- Time: 09:00:34.236000 ---
#
# --- Time: 09:00:34.336000 ---
#
# --- Time: 09:00:34.436000 ---
#
# --- Time: 09:00:34.536000 ---
#
# --- Time: 09:00:34.636000 ---
#
# --- Time: 09:00:34.736000 ---
#
# --- Time: 09:00:34.836000 ---
#
# --- Time: 09:00:34.936000 ---
#
# --- Time: 09:00:35.036000 ---
#
# --- Time: 09:00:35.136000 ---
#
# --- Time: 09:00:35.236000 ---
# Parcel 27 arrived – feasible outfeeds: [1, 2, 8, 11, 15, 19, 21, 25, 26, 29, 35, 36, 37, 42]
# [DEBUG] Parcel 27 → needed: 1.38, used: 0.00, fits: True
# Parcel 27 sorted to outfeed 2 (travel time: 9.38 seconds)
#
# --- Time: 09:00:35.336000 ---
#
# --- Time: 09:00:35.436000 ---
#
# --- Time: 09:00:35.536000 ---
#
# --- Time: 09:00:35.636000 ---
#
# --- Time: 09:00:35.736000 ---
#
# --- Time: 09:00:35.836000 ---
#
# --- Time: 09:00:35.936000 ---
#
# --- Time: 09:00:36.036000 ---
#
# --- Time: 09:00:36.136000 ---
#
# --- Time: 09:00:36.236000 ---
#
# --- Time: 09:00:36.336000 ---
# Parcel 25 removed from outfeed(total system time: 7.14 s)
#
# --- Time: 09:00:36.436000 ---
#
# --- Time: 09:00:36.536000 ---
#
# --- Time: 09:00:36.636000 ---
#
# --- Time: 09:00:36.736000 ---
#
# --- Time: 09:00:36.836000 ---
#
# --- Time: 09:00:36.936000 ---
#
# --- Time: 09:00:37.036000 ---
#
# --- Time: 09:00:37.136000 ---
#
# --- Time: 09:00:37.236000 ---
#
# --- Time: 09:00:37.336000 ---
#
# --- Time: 09:00:37.436000 ---
#
# --- Time: 09:00:37.536000 ---
#
# --- Time: 09:00:37.636000 ---
# Parcel 28 arrived – feasible outfeeds: [3, 6, 7, 12, 13, 23, 26, 28, 30, 33, 38, 42]
# [DEBUG] Parcel 28 → needed: 1.85, used: 0.00, fits: True
# Parcel 28 sorted to outfeed 6 (travel time: 18.30 seconds)
#
# --- Time: 09:00:37.736000 ---
#
# --- Time: 09:00:37.836000 ---
#
# --- Time: 09:00:37.936000 ---
#
# --- Time: 09:00:38.036000 ---
#
# --- Time: 09:00:38.136000 ---
#
# --- Time: 09:00:38.236000 ---
#
# --- Time: 09:00:38.336000 ---
#
# --- Time: 09:00:38.436000 ---
#
# --- Time: 09:00:38.536000 ---
#
# --- Time: 09:00:38.636000 ---
#
# --- Time: 09:00:38.736000 ---
#
# --- Time: 09:00:38.836000 ---
#
# --- Time: 09:00:38.936000 ---
#
# --- Time: 09:00:39.036000 ---
# Parcel 26 removed from outfeed(total system time: 11.61 s)
#
# --- Time: 09:00:39.136000 ---
#
# --- Time: 09:00:39.236000 ---
#
# --- Time: 09:00:39.336000 ---
#
# --- Time: 09:00:39.436000 ---
#
# --- Time: 09:00:39.536000 ---
#
# --- Time: 09:00:39.636000 ---
#
# --- Time: 09:00:39.736000 ---
#
# --- Time: 09:00:39.836000 ---
#
# --- Time: 09:00:39.936000 ---
#
# --- Time: 09:00:40.036000 ---
#
# --- Time: 09:00:40.136000 ---
#
# --- Time: 09:00:40.236000 ---
#
# --- Time: 09:00:40.336000 ---
# Parcel 29 arrived – feasible outfeeds: [8, 9, 12, 15, 20, 21, 22, 23, 24, 36, 47, 50]
# [DEBUG] Parcel 29 → needed: 1.31, used: 0.00, fits: True
# Parcel 29 sorted to outfeed 8 (travel time: 22.77 seconds)
#
# --- Time: 09:00:40.436000 ---
#
# --- Time: 09:00:40.536000 ---
#
# --- Time: 09:00:40.636000 ---
#
# --- Time: 09:00:40.736000 ---
#
# --- Time: 09:00:40.836000 ---
#
# --- Time: 09:00:40.936000 ---
#
# --- Time: 09:00:41.036000 ---
#
# --- Time: 09:00:41.136000 ---
#
# --- Time: 09:00:41.236000 ---
#
# --- Time: 09:00:41.336000 ---
#
# --- Time: 09:00:41.436000 ---
#
# --- Time: 09:00:41.536000 ---
#
# --- Time: 09:00:41.636000 ---
#
# --- Time: 09:00:41.736000 ---
# Parcel 27 removed from outfeed(total system time: 9.38 s)
#
# --- Time: 09:00:41.836000 ---
#
# --- Time: 09:00:41.936000 ---
#
# --- Time: 09:00:42.036000 ---
# Parcel 28 removed from outfeed(total system time: 18.30 s)
#
# --- Time: 09:00:42.136000 ---
#
# --- Time: 09:00:42.236000 ---
#
# --- Time: 09:00:42.336000 ---
#
# --- Time: 09:00:42.436000 ---
#
# --- Time: 09:00:42.536000 ---
#
# --- Time: 09:00:42.636000 ---
#
# --- Time: 09:00:42.736000 ---
#
# --- Time: 09:00:42.836000 ---
#
# --- Time: 09:00:42.936000 ---
#
# --- Time: 09:00:43.036000 ---
#
# --- Time: 09:00:43.136000 ---
# Parcel 30 arrived – feasible outfeeds: [2, 5, 8, 19, 26, 31, 34, 35, 41, 43]
# [DEBUG] Parcel 30 → needed: 1.52, used: 0.00, fits: True
# Parcel 30 sorted to outfeed 2 (travel time: 9.38 seconds)
#
# --- Time: 09:00:43.236000 ---
#
# --- Time: 09:00:43.336000 ---
#
# --- Time: 09:00:43.436000 ---
# Parcel 31 arrived – feasible outfeeds: [1, 4, 8, 11, 15, 17, 18, 19, 24, 26, 34, 36, 38, 41, 42, 45, 46, 47]
# [DEBUG] Parcel 31 → needed: 1.29, used: 0.00, fits: True
# Parcel 31 sorted to outfeed 1 (travel time: 7.14 seconds)
#
# --- Time: 09:00:43.536000 ---
#
# --- Time: 09:00:43.636000 ---
#
# --- Time: 09:00:43.736000 ---
#
# --- Time: 09:00:43.836000 ---
#
# --- Time: 09:00:43.936000 ---
#
# --- Time: 09:00:44.036000 ---
#
# --- Time: 09:00:44.136000 ---
#
# --- Time: 09:00:44.236000 ---
#
# --- Time: 09:00:44.336000 ---
#
# --- Time: 09:00:44.436000 ---
#
# --- Time: 09:00:44.536000 ---
#
# --- Time: 09:00:44.636000 ---
#
# --- Time: 09:00:44.736000 ---
#
# --- Time: 09:00:44.836000 ---
#
# --- Time: 09:00:44.936000 ---
#
# --- Time: 09:00:45.036000 ---
#
# --- Time: 09:00:45.136000 ---
#
# --- Time: 09:00:45.236000 ---
#
# --- Time: 09:00:45.336000 ---
#
# --- Time: 09:00:45.436000 ---
#
# --- Time: 09:00:45.536000 ---
#
# --- Time: 09:00:45.636000 ---
# Parcel 32 arrived – feasible outfeeds: [1, 2, 9, 17, 20, 24, 28, 34, 43, 49]
# [DEBUG] Parcel 32 → needed: 1.01, used: 0.00, fits: True
# Parcel 32 sorted to outfeed 9 (travel time: 25.00 seconds)
#
# --- Time: 09:00:45.736000 ---
#
# --- Time: 09:00:45.836000 ---
#
# --- Time: 09:00:45.936000 ---
#
# --- Time: 09:00:46.036000 ---
#
# --- Time: 09:00:46.136000 ---
#
# --- Time: 09:00:46.236000 ---
#
# --- Time: 09:00:46.336000 ---
#
# --- Time: 09:00:46.436000 ---
#
# --- Time: 09:00:46.536000 ---
#
# --- Time: 09:00:46.636000 ---
#
# --- Time: 09:00:46.736000 ---
#
# --- Time: 09:00:46.836000 ---
# Parcel 29 removed from outfeed(total system time: 22.77 s)
#
# --- Time: 09:00:46.936000 ---
#
# --- Time: 09:00:47.036000 ---
#
# --- Time: 09:00:47.136000 ---
#
# --- Time: 09:00:47.236000 ---
#
# --- Time: 09:00:47.336000 ---
#
# --- Time: 09:00:47.436000 ---
#
# --- Time: 09:00:47.536000 ---
# Parcel 30 removed from outfeed(total system time: 9.38 s)
#
# --- Time: 09:00:47.636000 ---
#
# --- Time: 09:00:47.736000 ---
#
# --- Time: 09:00:47.836000 ---
#
# --- Time: 09:00:47.936000 ---
#
# --- Time: 09:00:48.036000 ---
#
# --- Time: 09:00:48.136000 ---
#
# --- Time: 09:00:48.236000 ---
#
# --- Time: 09:00:48.336000 ---
#
# --- Time: 09:00:48.436000 ---
# Parcel 33 arrived – feasible outfeeds: [1, 11, 14, 19, 23, 40, 42, 45, 46, 50]
# [DEBUG] Parcel 33 → needed: 1.21, used: 0.00, fits: True
# Parcel 33 sorted to outfeed 11 (travel time: 29.46 seconds)
#
# --- Time: 09:00:48.536000 ---
#
# --- Time: 09:00:48.636000 ---
#
# --- Time: 09:00:48.736000 ---
#
# --- Time: 09:00:48.836000 ---
#
# --- Time: 09:00:48.936000 ---
#
# --- Time: 09:00:49.036000 ---
#
# --- Time: 09:00:49.136000 ---
#
# --- Time: 09:00:49.236000 ---
#
# --- Time: 09:00:49.336000 ---
#
# --- Time: 09:00:49.436000 ---
#
# --- Time: 09:00:49.536000 ---
#
# --- Time: 09:00:49.636000 ---
#
# --- Time: 09:00:49.736000 ---
#
# --- Time: 09:00:49.836000 ---
#
# --- Time: 09:00:49.936000 ---
# Parcel 31 removed from outfeed(total system time: 7.14 s)
#
# --- Time: 09:00:50.036000 ---
#
# --- Time: 09:00:50.136000 ---
#
# --- Time: 09:00:50.236000 ---
#
# --- Time: 09:00:50.336000 ---
#
# --- Time: 09:00:50.436000 ---
#
# --- Time: 09:00:50.536000 ---
#
# --- Time: 09:00:50.636000 ---
#
# --- Time: 09:00:50.736000 ---
# Parcel 35 arrived – feasible outfeeds: [2, 6, 8, 11, 18, 19, 22, 24, 27, 28, 29, 32, 33, 39, 41, 42, 43, 45, 49, 50]
# [DEBUG] Parcel 35 → needed: 1.16, used: 0.00, fits: True
# Parcel 35 sorted to outfeed 2 (travel time: 9.38 seconds)
#
# --- Time: 09:00:50.836000 ---
#
# --- Time: 09:00:50.936000 ---
#
# --- Time: 09:00:51.036000 ---
#
# --- Time: 09:00:51.136000 ---
#
# --- Time: 09:00:51.236000 ---
#
# --- Time: 09:00:51.336000 ---
#
# --- Time: 09:00:51.436000 ---
#
# --- Time: 09:00:51.536000 ---
#
# --- Time: 09:00:51.636000 ---
#
# --- Time: 09:00:51.736000 ---
#
# --- Time: 09:00:51.836000 ---
#
# --- Time: 09:00:51.936000 ---
#
# --- Time: 09:00:52.036000 ---
#
# --- Time: 09:00:52.136000 ---
# Parcel 32 removed from outfeed(total system time: 25.00 s)
#
# --- Time: 09:00:52.236000 ---
#
# --- Time: 09:00:52.336000 ---
#
# --- Time: 09:00:52.436000 ---
#
# --- Time: 09:00:52.536000 ---
#
# --- Time: 09:00:52.636000 ---
# Parcel 36 arrived – feasible outfeeds: [0, 6, 7, 8, 10, 12, 15, 17, 27, 28, 32, 33, 36, 40, 41, 42, 45, 47, 48, 49]
# [DEBUG] Parcel 36 → needed: 0.72, used: 0.00, fits: True
# Parcel 36 sorted to outfeed 0 (travel time: 4.91 seconds)
#
# --- Time: 09:00:52.736000 ---
#
# --- Time: 09:00:52.836000 ---
#
# --- Time: 09:00:52.936000 ---
#
# --- Time: 09:00:53.036000 ---
#
# --- Time: 09:00:53.136000 ---
# Parcel 37 arrived – feasible outfeeds: [0, 2, 7, 8, 11, 12, 13, 14, 27, 35, 37, 39, 43, 45, 50]
# [DEBUG] Parcel 37 → needed: 1.42, used: 0.00, fits: True
# Parcel 37 sorted to outfeed 7 (travel time: 20.54 seconds)
#
# --- Time: 09:00:53.236000 ---
#
# --- Time: 09:00:53.336000 ---
#
# --- Time: 09:00:53.436000 ---
#
# --- Time: 09:00:53.536000 ---
#
# --- Time: 09:00:53.636000 ---
#
# --- Time: 09:00:53.736000 ---
#
# --- Time: 09:00:53.836000 ---
#
# --- Time: 09:00:53.936000 ---
# Parcel 33 removed from outfeed(total system time: 29.46 s)
#
# --- Time: 09:00:54.036000 ---
#
# --- Time: 09:00:54.136000 ---
#
# --- Time: 09:00:54.236000 ---
#
# --- Time: 09:00:54.336000 ---
#
# --- Time: 09:00:54.436000 ---
#
# --- Time: 09:00:54.536000 ---
#
# --- Time: 09:00:54.636000 ---
#
# --- Time: 09:00:54.736000 ---
#
# --- Time: 09:00:54.836000 ---
#
# --- Time: 09:00:54.936000 ---
#
# --- Time: 09:00:55.036000 ---
#
# --- Time: 09:00:55.136000 ---
# Parcel 35 removed from outfeed(total system time: 9.38 s)
#
# --- Time: 09:00:55.236000 ---
# Parcel 38 arrived – feasible outfeeds: [17, 25, 27, 48]
# [DEBUG] Parcel 38 → needed: 1.05, used: 0.00, fits: True
# Parcel 38 sorted to outfeed 17 (travel time: 42.86 seconds)
#
# --- Time: 09:00:55.336000 ---
#
# --- Time: 09:00:55.436000 ---
#
# --- Time: 09:00:55.536000 ---
#
# --- Time: 09:00:55.636000 ---
#
# --- Time: 09:00:55.736000 ---
#
# --- Time: 09:00:55.836000 ---
#
# --- Time: 09:00:55.936000 ---
#
# --- Time: 09:00:56.036000 ---
#
# --- Time: 09:00:56.136000 ---
#
# --- Time: 09:00:56.236000 ---
#
# --- Time: 09:00:56.336000 ---
#
# --- Time: 09:00:56.436000 ---
#
# --- Time: 09:00:56.536000 ---
#
# --- Time: 09:00:56.636000 ---
#
# --- Time: 09:00:56.736000 ---
# Parcel 39 arrived – feasible outfeeds: [8, 10, 16, 22, 23, 28, 42, 46]
# [DEBUG] Parcel 39 → needed: 1.44, used: 0.00, fits: True
# Parcel 39 sorted to outfeed 8 (travel time: 22.77 seconds)
#
# --- Time: 09:00:56.836000 ---
#
# --- Time: 09:00:56.936000 ---
#
# --- Time: 09:00:57.036000 ---
# Parcel 36 removed from outfeed(total system time: 4.91 s)
#
# --- Time: 09:00:57.136000 ---
#
# --- Time: 09:00:57.236000 ---
#
# --- Time: 09:00:57.336000 ---
#
# --- Time: 09:00:57.436000 ---
#
# --- Time: 09:00:57.536000 ---
#
# --- Time: 09:00:57.636000 ---
# Parcel 40 arrived – feasible outfeeds: [4, 5, 9, 18, 20, 24, 25, 26, 28, 30, 39, 43, 47, 48, 50]
# [DEBUG] Parcel 40 → needed: 1.43, used: 0.00, fits: True
# Parcel 40 sorted to outfeed 4 (travel time: 13.84 seconds)
#
# --- Time: 09:00:57.736000 ---
#
# --- Time: 09:00:57.836000 ---
#
# --- Time: 09:00:57.936000 ---
#
# --- Time: 09:00:58.036000 ---
#
# --- Time: 09:00:58.136000 ---
# Parcel 41 arrived – feasible outfeeds: [8, 13, 17, 22, 31, 39, 48, 49]
# [DEBUG] Parcel 41 → needed: 1.50, used: 0.00, fits: True
# Parcel 41 sorted to outfeed 13 (travel time: 33.93 seconds)
#
# --- Time: 09:00:58.236000 ---
#
# --- Time: 09:00:58.336000 ---
# Parcel 42 arrived – feasible outfeeds: [0, 1, 4, 5, 6, 8, 32, 44]
# [DEBUG] Parcel 42 → needed: 0.47, used: 0.00, fits: True
# Parcel 42 sorted to outfeed 0 (travel time: 4.91 seconds)
#
# --- Time: 09:00:58.436000 ---
#
# --- Time: 09:00:58.536000 ---
#
# --- Time: 09:00:58.636000 ---
#
# --- Time: 09:00:58.736000 ---
#
# --- Time: 09:00:58.836000 ---
#
# --- Time: 09:00:58.936000 ---
#
# --- Time: 09:00:59.036000 ---
#
# --- Time: 09:00:59.136000 ---
#
# --- Time: 09:00:59.236000 ---
#
# --- Time: 09:00:59.336000 ---
#
# --- Time: 09:00:59.436000 ---
#
# --- Time: 09:00:59.536000 ---
#
# --- Time: 09:00:59.636000 ---
# Parcel 37 removed from outfeed(total system time: 20.54 s)
#
# --- Time: 09:00:59.736000 ---
#
# --- Time: 09:00:59.836000 ---
#
# --- Time: 09:00:59.936000 ---
#
# --- Time: 09:01:00.036000 ---
#
# --- Time: 09:01:00.136000 ---
#
# --- Time: 09:01:00.236000 ---
#
# --- Time: 09:01:00.336000 ---
# Parcel 43 arrived – feasible outfeeds: [8, 15]
# [DEBUG] Parcel 43 → needed: 1.62, used: 0.00, fits: True
# Parcel 43 sorted to outfeed 15 (travel time: 38.39 seconds)
#
# --- Time: 09:01:00.436000 ---
#
# --- Time: 09:01:00.536000 ---
#
# --- Time: 09:01:00.636000 ---
#
# --- Time: 09:01:00.736000 ---
#
# --- Time: 09:01:00.836000 ---
#
# --- Time: 09:01:00.936000 ---
#
# --- Time: 09:01:01.036000 ---
#
# --- Time: 09:01:01.136000 ---
#
# --- Time: 09:01:01.236000 ---
#
# --- Time: 09:01:01.336000 ---
#
# --- Time: 09:01:01.436000 ---
#
# --- Time: 09:01:01.536000 ---
#
# --- Time: 09:01:01.636000 ---
#
# --- Time: 09:01:01.736000 ---
# Parcel 38 removed from outfeed(total system time: 42.86 s)
#
# --- Time: 09:01:01.836000 ---
#
# --- Time: 09:01:01.936000 ---
#
# --- Time: 09:01:02.036000 ---
# Parcel 44 arrived – feasible outfeeds: [2, 5, 8, 9, 13, 15, 25, 29, 31, 32, 35, 36, 38, 43, 44, 45, 47, 49, 50]
# [DEBUG] Parcel 44 → needed: 0.96, used: 0.00, fits: True
# Parcel 44 sorted to outfeed 2 (travel time: 9.38 seconds)
# Parcel 40 removed from outfeed(total system time: 13.84 s)
#
# --- Time: 09:01:02.136000 ---
#
# --- Time: 09:01:02.236000 ---
#
# --- Time: 09:01:02.336000 ---
#
# --- Time: 09:01:02.436000 ---
#
# --- Time: 09:01:02.536000 ---
# Parcel 41 removed from outfeed(total system time: 33.93 s)
#
# --- Time: 09:01:02.636000 ---
#
# --- Time: 09:01:02.736000 ---
# Parcel 42 removed from outfeed(total system time: 4.91 s)
#
# --- Time: 09:01:02.836000 ---
#
# --- Time: 09:01:02.936000 ---
#
# --- Time: 09:01:03.036000 ---
# Parcel 45 arrived – feasible outfeeds: [0, 2, 4, 7, 10, 12, 13, 14, 15, 17, 18, 21, 30, 39, 41, 42, 49]
# [DEBUG] Parcel 45 → needed: 0.81, used: 0.00, fits: True
# Parcel 45 sorted to outfeed 0 (travel time: 4.91 seconds)
#
# --- Time: 09:01:03.136000 ---
#
# --- Time: 09:01:03.236000 ---
# Parcel 39 removed from outfeed(total system time: 22.77 s)
#
# --- Time: 09:01:03.336000 ---
#
# --- Time: 09:01:03.436000 ---
#
# --- Time: 09:01:03.536000 ---
#
# --- Time: 09:01:03.636000 ---
#
# --- Time: 09:01:03.736000 ---
#
# --- Time: 09:01:03.836000 ---
#
# --- Time: 09:01:03.936000 ---
#
# --- Time: 09:01:04.036000 ---
#
# --- Time: 09:01:04.136000 ---
#
# --- Time: 09:01:04.236000 ---
#
# --- Time: 09:01:04.336000 ---
# Parcel 46 arrived – feasible outfeeds: [12, 13, 28, 39, 41, 47, 48, 49]
# [DEBUG] Parcel 46 → needed: 0.57, used: 0.00, fits: True
# Parcel 46 sorted to outfeed 12 (travel time: 31.70 seconds)
#
# --- Time: 09:01:04.436000 ---
#
# --- Time: 09:01:04.536000 ---
#
# --- Time: 09:01:04.636000 ---
#
# --- Time: 09:01:04.736000 ---
#
# --- Time: 09:01:04.836000 ---
#
# --- Time: 09:01:04.936000 ---
#
# --- Time: 09:01:05.036000 ---
#
# --- Time: 09:01:05.136000 ---
#
# --- Time: 09:01:05.236000 ---
#
# --- Time: 09:01:05.336000 ---
#
# --- Time: 09:01:05.436000 ---
#
# --- Time: 09:01:05.536000 ---
#
# --- Time: 09:01:05.636000 ---
#
# --- Time: 09:01:05.736000 ---
#
# --- Time: 09:01:05.836000 ---
#
# --- Time: 09:01:05.936000 ---
#
# --- Time: 09:01:06.036000 ---
#
# --- Time: 09:01:06.136000 ---
#
# --- Time: 09:01:06.236000 ---
#
# --- Time: 09:01:06.336000 ---
#
# --- Time: 09:01:06.436000 ---
# Parcel 44 removed from outfeed(total system time: 9.38 s)
#
# --- Time: 09:01:06.536000 ---
#
# --- Time: 09:01:06.636000 ---
#
# --- Time: 09:01:06.736000 ---
#
# --- Time: 09:01:06.836000 ---
# Parcel 43 removed from outfeed(total system time: 38.39 s)
#
# --- Time: 09:01:06.936000 ---
#
# --- Time: 09:01:07.036000 ---
# Parcel 47 arrived – feasible outfeeds: [15, 17, 27, 28, 39, 44]
# [DEBUG] Parcel 47 → needed: 0.50, used: 0.00, fits: True
# Parcel 47 sorted to outfeed 15 (travel time: 38.39 seconds)
#
# --- Time: 09:01:07.136000 ---
#
# --- Time: 09:01:07.236000 ---
#
# --- Time: 09:01:07.336000 ---
#
# --- Time: 09:01:07.436000 ---
#
# --- Time: 09:01:07.536000 ---
#
# --- Time: 09:01:07.636000 ---
#
# --- Time: 09:01:07.736000 ---
#
# --- Time: 09:01:07.836000 ---
# Parcel 48 arrived – feasible outfeeds: [1, 3, 6, 7, 8, 10, 19, 20, 21, 24, 27, 32, 33, 35, 38, 40, 41, 43, 45, 47]
# [DEBUG] Parcel 48 → needed: 1.24, used: 0.00, fits: True
# Parcel 48 sorted to outfeed 1 (travel time: 7.14 seconds)
#
# --- Time: 09:01:07.936000 ---
#
# --- Time: 09:01:08.036000 ---
#
# --- Time: 09:01:08.136000 ---
#
# --- Time: 09:01:08.236000 ---
#
# --- Time: 09:01:08.336000 ---
#
# --- Time: 09:01:08.436000 ---
#
# --- Time: 09:01:08.536000 ---
# Parcel 45 removed from outfeed(total system time: 4.91 s)
#
# --- Time: 09:01:08.636000 ---
#
# --- Time: 09:01:08.736000 ---
# Parcel 46 removed from outfeed(total system time: 31.70 s)
#
# --- Time: 09:01:08.836000 ---
#
# --- Time: 09:01:08.936000 ---
#
# --- Time: 09:01:09.036000 ---
#
# --- Time: 09:01:09.136000 ---
#
# --- Time: 09:01:09.236000 ---
#
# --- Time: 09:01:09.336000 ---
#
# --- Time: 09:01:09.436000 ---
#
# --- Time: 09:01:09.536000 ---
#
# --- Time: 09:01:09.636000 ---
#
# --- Time: 09:01:09.736000 ---
#
# --- Time: 09:01:09.836000 ---
#
# --- Time: 09:01:09.936000 ---
# Parcel 49 arrived – feasible outfeeds: [5, 16, 17, 22, 26, 27, 30, 32, 42]
# [DEBUG] Parcel 49 → needed: 1.43, used: 0.00, fits: True
# Parcel 49 sorted to outfeed 5 (travel time: 16.07 seconds)
#
# --- Time: 09:01:10.036000 ---
#
# --- Time: 09:01:10.136000 ---
#
# --- Time: 09:01:10.236000 ---
#
# --- Time: 09:01:10.336000 ---
#
# --- Time: 09:01:10.436000 ---
#
# --- Time: 09:01:10.536000 ---
#
# --- Time: 09:01:10.636000 ---
#
# --- Time: 09:01:10.736000 ---
#
# --- Time: 09:01:10.836000 ---
#
# --- Time: 09:01:10.936000 ---
#
# --- Time: 09:01:11.036000 ---
#
# --- Time: 09:01:11.136000 ---
#
# --- Time: 09:01:11.236000 ---
#
# --- Time: 09:01:11.336000 ---
#
# --- Time: 09:01:11.436000 ---
# Parcel 47 removed from outfeed(total system time: 38.39 s)
#
# --- Time: 09:01:11.536000 ---
#
# --- Time: 09:01:11.636000 ---
#
# --- Time: 09:01:11.736000 ---
# Parcel 50 arrived – feasible outfeeds: [1, 4, 13, 16, 23, 24, 46, 50]
# [DEBUG] Parcel 50 → needed: 1.56, used: 0.00, fits: True
# Parcel 50 sorted to outfeed 4 (travel time: 13.84 seconds)
#
# --- Time: 09:01:11.836000 ---
#
# --- Time: 09:01:11.936000 ---
#
# --- Time: 09:01:12.036000 ---
#
# --- Time: 09:01:12.136000 ---
#
# --- Time: 09:01:12.236000 ---
# Parcel 48 removed from outfeed(total system time: 7.14 s)
#
# --- Time: 09:01:12.336000 ---
#
# --- Time: 09:01:12.436000 ---
# Parcel 51 arrived – feasible outfeeds: [1, 4, 10, 15, 21, 24, 26, 28, 34, 38, 40, 46]
# [DEBUG] Parcel 51 → needed: 0.74, used: 0.00, fits: True
# Parcel 51 sorted to outfeed 1 (travel time: 7.14 seconds)
#
# --- Time: 09:01:12.536000 ---
#
# --- Time: 09:01:12.636000 ---
#
# --- Time: 09:01:12.736000 ---
#
# --- Time: 09:01:12.836000 ---
#
# --- Time: 09:01:12.936000 ---
#
# --- Time: 09:01:13.036000 ---
#
# --- Time: 09:01:13.136000 ---
#
# --- Time: 09:01:13.236000 ---
#
# --- Time: 09:01:13.336000 ---
#
# --- Time: 09:01:13.436000 ---
#
# --- Time: 09:01:13.536000 ---
#
# --- Time: 09:01:13.636000 ---
#
# --- Time: 09:01:13.736000 ---
#
# --- Time: 09:01:13.836000 ---
#
# --- Time: 09:01:13.936000 ---
#
# --- Time: 09:01:14.036000 ---
#
# --- Time: 09:01:14.136000 ---
#
# --- Time: 09:01:14.236000 ---
#
# --- Time: 09:01:14.336000 ---
#
# --- Time: 09:01:14.436000 ---
#
# --- Time: 09:01:14.536000 ---
#
# --- Time: 09:01:14.636000 ---
#
# --- Time: 09:01:14.736000 ---
# Parcel 52 arrived – feasible outfeeds: [1, 20, 22]
# [DEBUG] Parcel 52 → needed: 1.39, used: 0.00, fits: True
# Parcel 52 sorted to outfeed 20 (travel time: 49.55 seconds)
#
# --- Time: 09:01:14.836000 ---
#
# --- Time: 09:01:14.936000 ---
#
# --- Time: 09:01:15.036000 ---
#
# --- Time: 09:01:15.136000 ---
#
# --- Time: 09:01:15.236000 ---
#
# --- Time: 09:01:15.336000 ---
#
# --- Time: 09:01:15.436000 ---
#
# --- Time: 09:01:15.536000 ---
#
# --- Time: 09:01:15.636000 ---
#
# --- Time: 09:01:15.736000 ---
#
# --- Time: 09:01:15.836000 ---
#
# --- Time: 09:01:15.936000 ---
#
# --- Time: 09:01:16.036000 ---
#
# --- Time: 09:01:16.136000 ---
#
# --- Time: 09:01:16.236000 ---
#
# --- Time: 09:01:16.336000 ---
#
# --- Time: 09:01:16.436000 ---
# Parcel 49 removed from outfeed(total system time: 16.07 s)
#
# --- Time: 09:01:16.536000 ---
#
# --- Time: 09:01:16.636000 ---
# Parcel 53 arrived – feasible outfeeds: [1, 3, 9, 23, 43, 46, 47, 49]
# [DEBUG] Parcel 53 → needed: 1.98, used: 0.00, fits: True
# Parcel 53 sorted to outfeed 3 (travel time: 11.61 seconds)
#
# --- Time: 09:01:16.736000 ---
#
# --- Time: 09:01:16.836000 ---
#
# --- Time: 09:01:16.936000 ---
#
# --- Time: 09:01:17.036000 ---
#
# --- Time: 09:01:17.136000 ---
#
# --- Time: 09:01:17.236000 ---
#
# --- Time: 09:01:17.336000 ---
#
# --- Time: 09:01:17.436000 ---
#
# --- Time: 09:01:17.536000 ---
#
# --- Time: 09:01:17.636000 ---
#
# --- Time: 09:01:17.736000 ---
#
# --- Time: 09:01:17.836000 ---
#
# --- Time: 09:01:17.936000 ---
#
# --- Time: 09:01:18.036000 ---
#
# --- Time: 09:01:18.136000 ---
#
# --- Time: 09:01:18.236000 ---
# Parcel 50 removed from outfeed(total system time: 13.84 s)
#
# --- Time: 09:01:18.336000 ---
#
# --- Time: 09:01:18.436000 ---
#
# --- Time: 09:01:18.536000 ---
#
# --- Time: 09:01:18.636000 ---
#
# --- Time: 09:01:18.736000 ---
#
# --- Time: 09:01:18.836000 ---
#
# --- Time: 09:01:18.936000 ---
# Parcel 51 removed from outfeed(total system time: 7.14 s)
#
# --- Time: 09:01:19.036000 ---
#
# --- Time: 09:01:19.136000 ---
#
# --- Time: 09:01:19.236000 ---
# Parcel 54 arrived – feasible outfeeds: [7, 28]
# [DEBUG] Parcel 54 → needed: 1.24, used: 0.00, fits: True
# Parcel 54 sorted to outfeed 7 (travel time: 20.54 seconds)
#
# --- Time: 09:01:19.336000 ---
#
# --- Time: 09:01:19.436000 ---
#
# --- Time: 09:01:19.536000 ---
#
# --- Time: 09:01:19.636000 ---
#
# --- Time: 09:01:19.736000 ---
#
# --- Time: 09:01:19.836000 ---
#
# --- Time: 09:01:19.936000 ---
#
# --- Time: 09:01:20.036000 ---
# Parcel 55 arrived – feasible outfeeds: [0, 4, 7, 9, 13, 15, 18, 19, 20, 24, 30, 46]
# [DEBUG] Parcel 55 → needed: 0.72, used: 0.00, fits: True
# Parcel 55 sorted to outfeed 0 (travel time: 4.91 seconds)
#
# --- Time: 09:01:20.136000 ---
#
# --- Time: 09:01:20.236000 ---
#
# --- Time: 09:01:20.336000 ---
#
# --- Time: 09:01:20.436000 ---
#
# --- Time: 09:01:20.536000 ---
#
# --- Time: 09:01:20.636000 ---
#
# --- Time: 09:01:20.736000 ---
#
# --- Time: 09:01:20.836000 ---
#
# --- Time: 09:01:20.936000 ---
#
# --- Time: 09:01:21.036000 ---
#
# --- Time: 09:01:21.136000 ---
#
# --- Time: 09:01:21.236000 ---
# Parcel 52 removed from outfeed(total system time: 49.55 s)
#
# --- Time: 09:01:21.336000 ---
#
# --- Time: 09:01:21.436000 ---
#
# --- Time: 09:01:21.536000 ---
#
# --- Time: 09:01:21.636000 ---
#
# --- Time: 09:01:21.736000 ---
#
# --- Time: 09:01:21.836000 ---
#
# --- Time: 09:01:21.936000 ---
#
# --- Time: 09:01:22.036000 ---
#
# --- Time: 09:01:22.136000 ---
#
# --- Time: 09:01:22.236000 ---
#
# --- Time: 09:01:22.336000 ---
#
# --- Time: 09:01:22.436000 ---
#
# --- Time: 09:01:22.536000 ---
# Parcel 56 arrived – feasible outfeeds: [2, 5, 7, 10, 12, 13, 15, 16, 18, 20, 27, 29, 38, 39, 42, 43, 44, 45, 46, 48]
# [DEBUG] Parcel 56 → needed: 0.52, used: 0.00, fits: True
# Parcel 56 sorted to outfeed 2 (travel time: 9.38 seconds)
#
# --- Time: 09:01:22.636000 ---
#
# --- Time: 09:01:22.736000 ---
#
# --- Time: 09:01:22.836000 ---
#
# --- Time: 09:01:22.936000 ---
#
# --- Time: 09:01:23.036000 ---
#
# --- Time: 09:01:23.136000 ---
# Parcel 53 removed from outfeed(total system time: 11.61 s)
#
# --- Time: 09:01:23.236000 ---
#
# --- Time: 09:01:23.336000 ---
#
# --- Time: 09:01:23.436000 ---
#
# --- Time: 09:01:23.536000 ---
#
# --- Time: 09:01:23.636000 ---
# Parcel 54 removed from outfeed(total system time: 20.54 s)
#
# --- Time: 09:01:23.736000 ---
#
# --- Time: 09:01:23.836000 ---
#
# --- Time: 09:01:23.936000 ---
#
# --- Time: 09:01:24.036000 ---
#
# --- Time: 09:01:24.136000 ---
#
# --- Time: 09:01:24.236000 ---
#
# --- Time: 09:01:24.336000 ---
#
# --- Time: 09:01:24.436000 ---
# Parcel 55 removed from outfeed(total system time: 4.91 s)
#
# --- Time: 09:01:24.536000 ---
# Parcel 57 arrived – feasible outfeeds: [6, 9, 23, 24, 25, 33, 35, 41, 45, 50]
# [DEBUG] Parcel 57 → needed: 1.13, used: 0.00, fits: True
# Parcel 57 sorted to outfeed 6 (travel time: 18.30 seconds)
#
# --- Time: 09:01:24.636000 ---
#
# --- Time: 09:01:24.736000 ---
#
# --- Time: 09:01:24.836000 ---
#
# --- Time: 09:01:24.936000 ---
#
# --- Time: 09:01:25.036000 ---
#
# --- Time: 09:01:25.136000 ---
#
# --- Time: 09:01:25.236000 ---
#
# --- Time: 09:01:25.336000 ---
#
# --- Time: 09:01:25.436000 ---
#
# --- Time: 09:01:25.536000 ---
#
# --- Time: 09:01:25.636000 ---
#
# --- Time: 09:01:25.736000 ---
#
# --- Time: 09:01:25.836000 ---
#
# --- Time: 09:01:25.936000 ---
#
# --- Time: 09:01:26.036000 ---
#
# --- Time: 09:01:26.136000 ---
#
# --- Time: 09:01:26.236000 ---
#
# --- Time: 09:01:26.336000 ---
# Parcel 58 arrived – feasible outfeeds: [0, 3, 17, 18, 23, 24, 25, 26, 27, 29, 32, 34, 37, 38, 39, 40, 43, 45, 47]
# [DEBUG] Parcel 58 → needed: 1.36, used: 0.00, fits: True
# Parcel 58 sorted to outfeed 0 (travel time: 4.91 seconds)
#
# --- Time: 09:01:26.436000 ---
#
# --- Time: 09:01:26.536000 ---
#
# --- Time: 09:01:26.636000 ---
#
# --- Time: 09:01:26.736000 ---
#
# --- Time: 09:01:26.836000 ---
#
# --- Time: 09:01:26.936000 ---
# Parcel 56 removed from outfeed(total system time: 9.38 s)
#
# --- Time: 09:01:27.036000 ---
#
# --- Time: 09:01:27.136000 ---
# Parcel 59 arrived – feasible outfeeds: [9, 10, 13, 14, 16, 17, 20, 24, 28, 32, 34, 36, 37, 40, 41, 49, 50]
# [DEBUG] Parcel 59 → needed: 1.93, used: 0.00, fits: True
# Parcel 59 sorted to outfeed 9 (travel time: 25.00 seconds)
#
# --- Time: 09:01:27.236000 ---
#
# --- Time: 09:01:27.336000 ---
#
# --- Time: 09:01:27.436000 ---
#
# --- Time: 09:01:27.536000 ---
#
# --- Time: 09:01:27.636000 ---
#
# --- Time: 09:01:27.736000 ---
#
# --- Time: 09:01:27.836000 ---
#
# --- Time: 09:01:27.936000 ---
#
# --- Time: 09:01:28.036000 ---
#
# --- Time: 09:01:28.136000 ---
#
# --- Time: 09:01:28.236000 ---
#
# --- Time: 09:01:28.336000 ---
#
# --- Time: 09:01:28.436000 ---
#
# --- Time: 09:01:28.536000 ---
#
# --- Time: 09:01:28.636000 ---
#
# --- Time: 09:01:28.736000 ---
#
# --- Time: 09:01:28.836000 ---
#
# --- Time: 09:01:28.936000 ---
# Parcel 57 removed from outfeed(total system time: 18.30 s)
#
# --- Time: 09:01:29.036000 ---
#
# --- Time: 09:01:29.136000 ---
# Parcel 60 arrived – feasible outfeeds: [0, 2, 11, 12, 14, 15, 16, 20, 21, 22, 24, 25, 28, 35, 37, 40, 41, 42, 49]
# [DEBUG] Parcel 60 → needed: 1.28, used: 0.00, fits: True
# Parcel 60 sorted to outfeed 2 (travel time: 9.38 seconds)
#
# --- Time: 09:01:29.236000 ---
#
# --- Time: 09:01:29.336000 ---
#
# --- Time: 09:01:29.436000 ---
# Parcel 61 arrived – feasible outfeeds: [8, 11, 13, 17, 20, 21, 22, 25, 29, 36, 45]
# [DEBUG] Parcel 61 → needed: 0.98, used: 0.00, fits: True
# Parcel 61 sorted to outfeed 8 (travel time: 22.77 seconds)
#
# --- Time: 09:01:29.536000 ---
#
# --- Time: 09:01:29.636000 ---
#
# --- Time: 09:01:29.736000 ---
#
# --- Time: 09:01:29.836000 ---
#
# --- Time: 09:01:29.936000 ---
#
# --- Time: 09:01:30.036000 ---
#
# --- Time: 09:01:30.136000 ---
#
# --- Time: 09:01:30.236000 ---
#
# --- Time: 09:01:30.336000 ---
#
# --- Time: 09:01:30.436000 ---
#
# --- Time: 09:01:30.536000 ---
#
# --- Time: 09:01:30.636000 ---
#
# --- Time: 09:01:30.736000 ---
# Parcel 62 arrived – feasible outfeeds: [0, 5, 14, 16, 17, 18, 20, 24, 26, 27, 39, 40, 41, 44, 45, 46]
# [DEBUG] Parcel 62 → needed: 0.62, used: 0.00, fits: True
# Parcel 62 sorted to outfeed 5 (travel time: 16.07 seconds)
#
# --- Time: 09:01:30.836000 ---
#
# --- Time: 09:01:30.936000 ---
#
# --- Time: 09:01:31.036000 ---
#
# --- Time: 09:01:31.136000 ---
#
# --- Time: 09:01:31.236000 ---
#
# --- Time: 09:01:31.336000 ---
#
# --- Time: 09:01:31.436000 ---
#
# --- Time: 09:01:31.536000 ---
#
# --- Time: 09:01:31.636000 ---
#
# --- Time: 09:01:31.736000 ---
#
# --- Time: 09:01:31.836000 ---
#
# --- Time: 09:01:31.936000 ---
#
# --- Time: 09:01:32.036000 ---
#
# --- Time: 09:01:32.136000 ---
#
# --- Time: 09:01:32.236000 ---
#
# --- Time: 09:01:32.336000 ---
#
# --- Time: 09:01:32.436000 ---
#
# --- Time: 09:01:32.536000 ---
#
# --- Time: 09:01:32.636000 ---
#
# --- Time: 09:01:32.736000 ---
#
# --- Time: 09:01:32.836000 ---
# Parcel 58 removed from outfeed(total system time: 4.91 s)
#
# --- Time: 09:01:32.936000 ---
#
# --- Time: 09:01:33.036000 ---
# Parcel 63 arrived – feasible outfeeds: [37, 45]
# [DEBUG] Parcel 63 → needed: 1.14, used: 0.00, fits: True
# Parcel 63 sorted to outfeed 37 (travel time: 87.50 seconds)
#
# --- Time: 09:01:33.136000 ---
#
# --- Time: 09:01:33.236000 ---
#
# --- Time: 09:01:33.336000 ---
#
# --- Time: 09:01:33.436000 ---
#
# --- Time: 09:01:33.536000 ---
#
# --- Time: 09:01:33.636000 ---
# Parcel 59 removed from outfeed(total system time: 25.00 s)
#
# --- Time: 09:01:33.736000 ---
#
# --- Time: 09:01:33.836000 ---
#
# --- Time: 09:01:33.936000 ---
#
# --- Time: 09:01:34.036000 ---
#
# --- Time: 09:01:34.136000 ---
#
# --- Time: 09:01:34.236000 ---
#
# --- Time: 09:01:34.336000 ---
#
# --- Time: 09:01:34.436000 ---
#
# --- Time: 09:01:34.536000 ---
#
# --- Time: 09:01:34.636000 ---
#
# --- Time: 09:01:34.736000 ---
#
# --- Time: 09:01:34.836000 ---
#
# --- Time: 09:01:34.936000 ---
#
# --- Time: 09:01:35.036000 ---
#
# --- Time: 09:01:35.136000 ---
# Parcel 62 removed from outfeed(total system time: 16.07 s)
#
# --- Time: 09:01:35.236000 ---
#
# --- Time: 09:01:35.336000 ---
#
# --- Time: 09:01:35.436000 ---
#
# --- Time: 09:01:35.536000 ---
#
# --- Time: 09:01:35.636000 ---
# Parcel 60 removed from outfeed(total system time: 9.38 s)
#
# --- Time: 09:01:35.736000 ---
#
# --- Time: 09:01:35.836000 ---
#
# --- Time: 09:01:35.936000 ---
# Parcel 64 arrived – feasible outfeeds: [0, 12, 34, 35, 39]
# [DEBUG] Parcel 64 → needed: 1.07, used: 0.00, fits: True
# Parcel 64 sorted to outfeed 0 (travel time: 4.91 seconds)
# Parcel 61 removed from outfeed(total system time: 22.77 s)
#
# --- Time: 09:01:36.036000 ---
#
# --- Time: 09:01:36.136000 ---
#
# --- Time: 09:01:36.236000 ---
#
# --- Time: 09:01:36.336000 ---
#
# --- Time: 09:01:36.436000 ---
#
# --- Time: 09:01:36.536000 ---
#
# --- Time: 09:01:36.636000 ---
#
# --- Time: 09:01:36.736000 ---
#
# --- Time: 09:01:36.836000 ---
#
# --- Time: 09:01:36.936000 ---
#
# --- Time: 09:01:37.036000 ---
#
# --- Time: 09:01:37.136000 ---
#
# --- Time: 09:01:37.236000 ---
#
# --- Time: 09:01:37.336000 ---
#
# --- Time: 09:01:37.436000 ---
# Parcel 63 removed from outfeed(total system time: 87.50 s)
#
# --- Time: 09:01:37.536000 ---
#
# --- Time: 09:01:37.636000 ---
#
# --- Time: 09:01:37.736000 ---
#
# --- Time: 09:01:37.836000 ---
#
# --- Time: 09:01:37.936000 ---
# Parcel 65 arrived – feasible outfeeds: [0, 4, 7, 9, 11, 17, 24, 28, 29, 33, 34, 37, 40]
# [DEBUG] Parcel 65 → needed: 0.96, used: 0.00, fits: True
# Parcel 65 sorted to outfeed 4 (travel time: 13.84 seconds)
#
# --- Time: 09:01:38.036000 ---
#
# --- Time: 09:01:38.136000 ---
#
# --- Time: 09:01:38.236000 ---
#
# --- Time: 09:01:38.336000 ---
#
# --- Time: 09:01:38.436000 ---
#
# --- Time: 09:01:38.536000 ---
#
# --- Time: 09:01:38.636000 ---
#
# --- Time: 09:01:38.736000 ---
#
# --- Time: 09:01:38.836000 ---
#
# --- Time: 09:01:38.936000 ---
#
# --- Time: 09:01:39.036000 ---
#
# --- Time: 09:01:39.136000 ---
#
# --- Time: 09:01:39.236000 ---
#
# --- Time: 09:01:39.336000 ---
#
# --- Time: 09:01:39.436000 ---
#
# --- Time: 09:01:39.536000 ---
#
# --- Time: 09:01:39.636000 ---
#
# --- Time: 09:01:39.736000 ---
#
# --- Time: 09:01:39.836000 ---
#
# --- Time: 09:01:39.936000 ---
#
# --- Time: 09:01:40.036000 ---
#
# --- Time: 09:01:40.136000 ---
#
# --- Time: 09:01:40.236000 ---
#
# --- Time: 09:01:40.336000 ---
#
# --- Time: 09:01:40.436000 ---
#
# --- Time: 09:01:40.536000 ---
# Parcel 66 arrived – feasible outfeeds: [0, 5, 9, 10, 11, 15, 24, 26, 28, 32, 34, 35, 38, 40, 41, 43, 46, 47, 48, 50]
# [DEBUG] Parcel 66 → needed: 1.64, used: 0.00, fits: True
# Parcel 66 sorted to outfeed 5 (travel time: 16.07 seconds)
#
# --- Time: 09:01:40.636000 ---
#
# --- Time: 09:01:40.736000 ---
#
# --- Time: 09:01:40.836000 ---
#
# --- Time: 09:01:40.936000 ---
#
# --- Time: 09:01:41.036000 ---
#
# --- Time: 09:01:41.136000 ---
#
# --- Time: 09:01:41.236000 ---
#
# --- Time: 09:01:41.336000 ---
#
# --- Time: 09:01:41.436000 ---
#
# --- Time: 09:01:41.536000 ---
#
# --- Time: 09:01:41.636000 ---
# Parcel 67 arrived – feasible outfeeds: [43]
# [DEBUG] Parcel 67 → needed: 1.40, used: 0.00, fits: True
# Parcel 67 sorted to outfeed 43 (travel time: 100.89 seconds)
#
# --- Time: 09:01:41.736000 ---
#
# --- Time: 09:01:41.836000 ---
#
# --- Time: 09:01:41.936000 ---
#
# --- Time: 09:01:42.036000 ---
#
# --- Time: 09:01:42.136000 ---
#
# --- Time: 09:01:42.236000 ---
#
# --- Time: 09:01:42.336000 ---
#
# --- Time: 09:01:42.436000 ---
# Parcel 64 removed from outfeed(total system time: 4.91 s)
#
# --- Time: 09:01:42.536000 ---
#
# --- Time: 09:01:42.636000 ---
# ...
# Parcel 1637 sorted to outfeed 9 (travel time: 25.00 seconds)
#
# --- Time: 09:42:11.636000 ---
#
# --- Time: 09:42:11.736000 ---
# Parcel 1633 removed from outfeed(total system time: 4.91 s)
#
# --- Time: 09:42:11.836000 ---
#
# --- Time: 09:42:11.936000 ---
#
# --- Time: 09:42:12.036000 ---
#
# --- Time: 09:42:12.136000 ---
#
# --- Time: 09:42:12.236000 ---
#
# --- Time: 09:42:12.336000 ---
#
# --- Time: 09:42:12.436000 ---
#
# --- Time: 09:42:12.536000 ---
#
# --- Time: 09:42:12.636000 ---
#
# --- Time: 09:42:12.736000 ---
#
# --- Time: 09:42:12.836000 ---
#
# --- Time: 09:42:12.936000 ---
#
# --- Time: 09:42:13.036000 ---
#
# --- Time: 09:42:13.136000 ---
#
# --- Time: 09:42:13.236000 ---
#
# --- Time: 09:42:13.336000 ---
#
# --- Time: 09:42:13.436000 ---
#
# --- Time: 09:42:13.536000 ---
#
# --- Time: 09:42:13.636000 ---
#
# --- Time: 09:42:13.736000 ---
# Parcel 1638 arrived – feasible outfeeds: [1, 3, 5, 7, 8, 9, 10, 19, 21, 24, 30, 33, 34, 35, 36, 38, 43, 47]
# [DEBUG] Parcel 1638 → needed: 1.51, used: 0.00, fits: True
# Parcel 1638 sorted to outfeed 1 (travel time: 7.14 seconds)
#
# --- Time: 09:42:13.836000 ---
#
# --- Time: 09:42:13.936000 ---
#
# --- Time: 09:42:14.036000 ---
#
# --- Time: 09:42:14.136000 ---
#
# --- Time: 09:42:14.236000 ---
#
# --- Time: 09:42:14.336000 ---
#
# --- Time: 09:42:14.436000 ---
#
# --- Time: 09:42:14.536000 ---
# Parcel 1635 removed from outfeed(total system time: 13.84 s)
#
# --- Time: 09:42:14.636000 ---
#
# --- Time: 09:42:14.736000 ---
# Parcel 1634 removed from outfeed(total system time: 9.38 s)
#
# --- Time: 09:42:14.836000 ---
#
# --- Time: 09:42:14.936000 ---
#
# --- Time: 09:42:15.036000 ---
#
# --- Time: 09:42:15.136000 ---
# Parcel 1639 arrived – feasible outfeeds: [4, 5, 8, 45, 46, 47]
# [DEBUG] Parcel 1639 → needed: 1.07, used: 0.00, fits: True
# Parcel 1639 sorted to outfeed 4 (travel time: 13.84 seconds)
# Parcel 1636 removed from outfeed(total system time: 42.86 s)
#
# --- Time: 09:42:15.236000 ---
#
# --- Time: 09:42:15.336000 ---
#
# --- Time: 09:42:15.436000 ---
#
# --- Time: 09:42:15.536000 ---
#
# --- Time: 09:42:15.636000 ---
#
# --- Time: 09:42:15.736000 ---
#
# --- Time: 09:42:15.836000 ---
#
# --- Time: 09:42:15.936000 ---
# Parcel 1637 removed from outfeed(total system time: 25.00 s)
#
# --- Time: 09:42:16.036000 ---
#
# --- Time: 09:42:16.136000 ---
#
# --- Time: 09:42:16.236000 ---
#
# --- Time: 09:42:16.336000 ---
#
# --- Time: 09:42:16.436000 ---
# Parcel 1640 arrived – feasible outfeeds: [0, 1, 3, 4, 6, 9, 10, 11, 16, 17, 25, 30, 36, 38, 40, 46]
# [DEBUG] Parcel 1640 → needed: 1.32, used: 0.00, fits: True
# Parcel 1640 sorted to outfeed 3 (travel time: 11.61 seconds)
#
# --- Time: 09:42:16.536000 ---
#
# --- Time: 09:42:16.636000 ---
#
# --- Time: 09:42:16.736000 ---
#
# --- Time: 09:42:16.836000 ---
#
# --- Time: 09:42:16.936000 ---
#
# --- Time: 09:42:17.036000 ---
#
# --- Time: 09:42:17.136000 ---
#
# --- Time: 09:42:17.236000 ---
#
# --- Time: 09:42:17.336000 ---
#
# --- Time: 09:42:17.436000 ---
#
# --- Time: 09:42:17.536000 ---
#
# --- Time: 09:42:17.636000 ---
#
# --- Time: 09:42:17.736000 ---
#
# --- Time: 09:42:17.836000 ---
#
# --- Time: 09:42:17.936000 ---
#
# --- Time: 09:42:18.036000 ---
#
# --- Time: 09:42:18.136000 ---
# Parcel 1638 removed from outfeed(total system time: 7.14 s)
#
# --- Time: 09:42:18.236000 ---
#
# --- Time: 09:42:18.336000 ---
#
# --- Time: 09:42:18.436000 ---
#
# --- Time: 09:42:18.536000 ---
#
# --- Time: 09:42:18.636000 ---
#
# --- Time: 09:42:18.736000 ---
#
# --- Time: 09:42:18.836000 ---
#
# --- Time: 09:42:18.936000 ---
#
# --- Time: 09:42:19.036000 ---
#
# --- Time: 09:42:19.136000 ---
#
# --- Time: 09:42:19.236000 ---
# Parcel 1641 arrived – feasible outfeeds: [0, 7, 8, 11, 15, 17, 18, 19, 20, 22, 26, 32, 33, 38, 42, 44, 48, 50]
# [DEBUG] Parcel 1641 → needed: 1.28, used: 0.00, fits: True
# Parcel 1641 sorted to outfeed 0 (travel time: 4.91 seconds)
#
# --- Time: 09:42:19.336000 ---
#
# --- Time: 09:42:19.436000 ---
#
# --- Time: 09:42:19.536000 ---
# Parcel 1639 removed from outfeed(total system time: 13.84 s)
#
# --- Time: 09:42:19.636000 ---
#
# --- Time: 09:42:19.736000 ---
#
# --- Time: 09:42:19.836000 ---
#
# --- Time: 09:42:19.936000 ---
#
# --- Time: 09:42:20.036000 ---
#
# --- Time: 09:42:20.136000 ---
#
# --- Time: 09:42:20.236000 ---
#
# --- Time: 09:42:20.336000 ---
#
# --- Time: 09:42:20.436000 ---
#
# --- Time: 09:42:20.536000 ---
#
# --- Time: 09:42:20.636000 ---
#
# --- Time: 09:42:20.736000 ---
#
# --- Time: 09:42:20.836000 ---
#
# --- Time: 09:42:20.936000 ---
#
# --- Time: 09:42:21.036000 ---
#
# --- Time: 09:42:21.136000 ---
#
# --- Time: 09:42:21.236000 ---
#
# --- Time: 09:42:21.336000 ---
#
# --- Time: 09:42:21.436000 ---
#
# --- Time: 09:42:21.536000 ---
#
# --- Time: 09:42:21.636000 ---
#
# --- Time: 09:42:21.736000 ---
#
# --- Time: 09:42:21.836000 ---
# Parcel 1642 arrived – feasible outfeeds: [2, 9, 14, 17, 22, 24, 26, 27, 28, 30, 34, 36, 41, 47, 49, 50]
# [DEBUG] Parcel 1642 → needed: 1.04, used: -0.00, fits: True
# Parcel 1642 sorted to outfeed 2 (travel time: 9.38 seconds)
#
# --- Time: 09:42:21.936000 ---
#
# --- Time: 09:42:22.036000 ---
#
# --- Time: 09:42:22.136000 ---
#
# --- Time: 09:42:22.236000 ---
#
# --- Time: 09:42:22.336000 ---
#
# --- Time: 09:42:22.436000 ---
# Parcel 1643 arrived – feasible outfeeds: [7, 9, 12, 14, 15, 19, 22, 23, 26, 30, 33, 37, 40, 41, 44, 45, 49]
# [DEBUG] Parcel 1643 → needed: 1.46, used: 0.00, fits: True
# Parcel 1643 sorted to outfeed 7 (travel time: 20.54 seconds)
#
# --- Time: 09:42:22.536000 ---
#
# --- Time: 09:42:22.636000 ---
#
# --- Time: 09:42:22.736000 ---
#
# --- Time: 09:42:22.836000 ---
#
# --- Time: 09:42:22.936000 ---
# Parcel 1640 removed from outfeed(total system time: 11.61 s)
#
# --- Time: 09:42:23.036000 ---
#
# --- Time: 09:42:23.136000 ---
#
# --- Time: 09:42:23.236000 ---
#
# --- Time: 09:42:23.336000 ---
#
# --- Time: 09:42:23.436000 ---
#
# --- Time: 09:42:23.536000 ---
#
# --- Time: 09:42:23.636000 ---
#
# --- Time: 09:42:23.736000 ---
#
# --- Time: 09:42:23.836000 ---
#
# --- Time: 09:42:23.936000 ---
#
# --- Time: 09:42:24.036000 ---
#
# --- Time: 09:42:24.136000 ---
# Parcel 1644 arrived – feasible outfeeds: [2, 3, 5, 8, 10, 11, 13, 15, 17, 36, 38, 39, 43, 45]
# [DEBUG] Parcel 1644 → needed: 1.17, used: 0.00, fits: True
# Parcel 1644 sorted to outfeed 3 (travel time: 11.61 seconds)
#
# --- Time: 09:42:24.236000 ---
#
# --- Time: 09:42:24.336000 ---
#
# --- Time: 09:42:24.436000 ---
#
# --- Time: 09:42:24.536000 ---
#
# --- Time: 09:42:24.636000 ---
#
# --- Time: 09:42:24.736000 ---
#
# --- Time: 09:42:24.836000 ---
#
# --- Time: 09:42:24.936000 ---
#
# --- Time: 09:42:25.036000 ---
#
# --- Time: 09:42:25.136000 ---
#
# --- Time: 09:42:25.236000 ---
#
# --- Time: 09:42:25.336000 ---
#
# --- Time: 09:42:25.436000 ---
#
# --- Time: 09:42:25.536000 ---
#
# --- Time: 09:42:25.636000 ---
#
# --- Time: 09:42:25.736000 ---
# Parcel 1641 removed from outfeed(total system time: 4.91 s)
#
# --- Time: 09:42:25.836000 ---
#
# --- Time: 09:42:25.936000 ---
#
# --- Time: 09:42:26.036000 ---
#
# --- Time: 09:42:26.136000 ---
#
# --- Time: 09:42:26.236000 ---
#
# --- Time: 09:42:26.336000 ---
#
# --- Time: 09:42:26.436000 ---
#
# --- Time: 09:42:26.536000 ---
#
# --- Time: 09:42:26.636000 ---
#
# --- Time: 09:42:26.736000 ---
#
# --- Time: 09:42:26.836000 ---
# Parcel 1643 removed from outfeed(total system time: 20.54 s)
#
# --- Time: 09:42:26.936000 ---
#
# --- Time: 09:42:27.036000 ---
#
# --- Time: 09:42:27.136000 ---
#
# --- Time: 09:42:27.236000 ---
#
# --- Time: 09:42:27.336000 ---
#
# --- Time: 09:42:27.436000 ---
#
# --- Time: 09:42:27.536000 ---
#
# --- Time: 09:42:27.636000 ---
#
# --- Time: 09:42:27.736000 ---
#
# --- Time: 09:42:27.836000 ---
#
# --- Time: 09:42:27.936000 ---
#
# --- Time: 09:42:28.036000 ---
#
# --- Time: 09:42:28.136000 ---
#
# --- Time: 09:42:28.236000 ---
#
# --- Time: 09:42:28.336000 ---
# Parcel 1642 removed from outfeed(total system time: 9.38 s)
#
# --- Time: 09:42:28.436000 ---
#
# --- Time: 09:42:28.536000 ---
# Parcel 1644 removed from outfeed(total system time: 11.61 s)
#
# --- Time: 09:42:28.636000 ---
#
# --- Time: 09:42:28.736000 ---
#
# --- Time: 09:42:28.836000 ---
#
# --- Time: 09:42:28.936000 ---
#
# --- Time: 09:42:29.036000 ---
#
# --- Time: 09:42:29.136000 ---
#
# --- Time: 09:42:29.236000 ---
#
# --- Time: 09:42:29.336000 ---
#
# --- Time: 09:42:29.436000 ---
#
# --- Time: 09:42:29.536000 ---
#
# --- Time: 09:42:29.636000 ---
#
# --- Time: 09:42:29.736000 ---
#
# --- Time: 09:42:29.836000 ---
#
# --- Time: 09:42:29.936000 ---
#
# --- Time: 09:42:30.036000 ---
#
# --- Time: 09:42:30.136000 ---
#
# --- Time: 09:42:30.236000 ---
#
# --- Time: 09:42:30.336000 ---
#
# --- Time: 09:42:30.436000 ---
#
# --- Time: 09:42:30.536000 ---
#
# --- Time: 09:42:30.636000 ---
#
# --- Time: 09:42:30.736000 ---
#
# --- Time: 09:42:30.836000 ---
#
# --- Time: 09:42:30.936000 ---
#
# --- Time: 09:42:31.036000 ---
#
# --- Time: 09:42:31.136000 ---
#
# --- Time: 09:42:31.236000 ---
#
# --- Time: 09:42:31.336000 ---
#
# --- Time: 09:42:31.436000 ---
#
# --- Time: 09:42:31.536000 ---
#
# --- Time: 09:42:31.636000 ---
#
# --- Time: 09:42:31.736000 ---
#
# --- Time: 09:42:31.836000 ---
#
# --- Time: 09:42:31.936000 ---
#
# --- Time: 09:42:32.036000 ---
#
# --- Time: 09:42:32.136000 ---
#
# --- Time: 09:42:32.236000 ---
#
# --- Time: 09:42:32.336000 ---
#
# --- Time: 09:42:32.436000 ---
#
# --- Time: 09:42:32.536000 ---
#
# --- Time: 09:42:32.636000 ---
#
# --- Time: 09:42:32.736000 ---
#
# --- Time: 09:42:32.836000 ---
#
# --- Time: 09:42:32.936000 ---
#
# --- Time: 09:42:33.036000 ---
#
# --- Time: 09:42:33.136000 ---
#
# --- Time: 09:42:33.236000 ---
#
# --- Time: 09:42:33.336000 ---
#
# --- Time: 09:42:33.436000 ---
#
# --- Time: 09:42:33.536000 ---
#
# --- Time: 09:42:33.636000 ---
#
# --- Time: 09:42:33.736000 ---
#
# --- Time: 09:42:33.836000 ---
#
# --- Time: 09:42:33.936000 ---
#
# --- Time: 09:42:34.036000 ---
#
# --- Time: 09:42:34.136000 ---
#
# --- Time: 09:42:34.236000 ---
#
# --- Time: 09:42:34.336000 ---
#
# --- Time: 09:42:34.436000 ---
#
# --- Time: 09:42:34.536000 ---
#
# --- Time: 09:42:34.636000 ---
#
# --- Time: 09:42:34.736000 ---
#
# --- Time: 09:42:34.836000 ---
#
# --- Time: 09:42:34.936000 ---
#
# --- Time: 09:42:35.036000 ---
#
# --- Time: 09:42:35.136000 ---
#
# --- Time: 09:42:35.236000 ---
#
# --- Time: 09:42:35.336000 ---
#
# --- Time: 09:42:35.436000 ---
#
# --- Time: 09:42:35.536000 ---
#
# --- Time: 09:42:35.636000 ---
#
# --- Time: 09:42:35.736000 ---
#
# --- Time: 09:42:35.836000 ---
#
# --- Time: 09:42:35.936000 ---
#
# --- Time: 09:42:36.036000 ---
#
# --- Time: 09:42:36.136000 ---
#
# --- Time: 09:42:36.236000 ---
#
# --- Time: 09:42:36.336000 ---
#
# --- Time: 09:42:36.436000 ---
#
# --- Time: 09:42:36.536000 ---
#
# --- Time: 09:42:36.636000 ---
#
# --- Time: 09:42:36.736000 ---
#
# --- Time: 09:42:36.836000 ---
#
# --- Time: 09:42:36.936000 ---
#
# --- Time: 09:42:37.036000 ---
#
# --- Time: 09:42:37.136000 ---
#
# --- Time: 09:42:37.236000 ---
#
# --- Time: 09:42:37.336000 ---
#
# --- Time: 09:42:37.436000 ---
#
# --- Time: 09:42:37.536000 ---
#
# --- Time: 09:42:37.636000 ---
#
# --- Time: 09:42:37.736000 ---
#
# --- Time: 09:42:37.836000 ---
#
# --- Time: 09:42:37.936000 ---
#
# --- Time: 09:42:38.036000 ---
#
# --- Time: 09:42:38.136000 ---
#
# --- Time: 09:42:38.236000 ---
#
# --- Time: 09:42:38.336000 ---
#
# --- Time: 09:42:38.436000 ---
#
# --- Time: 09:42:38.536000 ---
#
# --- Time: 09:42:38.636000 ---
#
# --- Time: 09:42:38.736000 ---
#
# --- Time: 09:42:38.836000 ---
#
# --- Time: 09:42:38.936000 ---
#
# --- Time: 09:42:39.036000 ---
#
# --- Time: 09:42:39.136000 ---
#
# --- Time: 09:42:39.236000 ---
#
# --- Time: 09:42:39.336000 ---
#
# --- Time: 09:42:39.436000 ---
#
# --- Time: 09:42:39.536000 ---
#
# --- Time: 09:42:39.636000 ---
#
# --- Time: 09:42:39.736000 ---
#
# --- Time: 09:42:39.836000 ---
#
# --- Time: 09:42:39.936000 ---
#
# --- Time: 09:42:40.036000 ---
#
# --- Time: 09:42:40.136000 ---
#
# --- Time: 09:42:40.236000 ---
#
# --- Time: 09:42:40.336000 ---
#
# --- Time: 09:42:40.436000 ---
#
# --- Time: 09:42:40.536000 ---
#
# --- Time: 09:42:40.636000 ---
#
# --- Time: 09:42:40.736000 ---
#
# --- Time: 09:42:40.836000 ---
#
# --- Time: 09:42:40.936000 ---
#
# --- Time: 09:42:41.036000 ---
#
# --- Time: 09:42:41.136000 ---
#
# --- Time: 09:42:41.236000 ---
#
# --- Time: 09:42:41.336000 ---
#
# --- Time: 09:42:41.436000 ---
#
# --- Time: 09:42:41.536000 ---
#
# --- Time: 09:42:41.636000 ---
#
# --- Time: 09:42:41.736000 ---
#
# --- Time: 09:42:41.836000 ---
#
# --- Time: 09:42:41.936000 ---
#
# --- Time: 09:42:42.036000 ---
#
# --- Time: 09:42:42.136000 ---
#
# --- Time: 09:42:42.236000 ---
#
# --- Time: 09:42:42.336000 ---
#
# --- Time: 09:42:42.436000 ---
#
# --- Time: 09:42:42.536000 ---
#
# --- Time: 09:42:42.636000 ---
#
# --- Time: 09:42:42.736000 ---
#
# --- Time: 09:42:42.836000 ---
#
# --- Time: 09:42:42.936000 ---
#
# --- Time: 09:42:43.036000 ---
#
# --- Time: 09:42:43.136000 ---
#
# --- Time: 09:42:43.236000 ---
#
# --- Time: 09:42:43.336000 ---
#
# --- Time: 09:42:43.436000 ---
#
# --- Time: 09:42:43.536000 ---
#
# --- Time: 09:42:43.636000 ---
#
# --- Time: 09:42:43.736000 ---
#
# --- Time: 09:42:43.836000 ---
#
# --- Time: 09:42:43.936000 ---
#
# --- Time: 09:42:44.036000 ---
#
# --- Time: 09:42:44.136000 ---
#
# --- Time: 09:42:44.236000 ---
#
# --- Time: 09:42:44.336000 ---
#
# --- Time: 09:42:44.436000 ---
#
# --- Time: 09:42:44.536000 ---
#
# --- Time: 09:42:44.636000 ---
#
# --- Time: 09:42:44.736000 ---
#
# --- Time: 09:42:44.836000 ---
#
# --- Time: 09:42:44.936000 ---
#
# --- Time: 09:42:45.036000 ---
#
# --- Time: 09:42:45.136000 ---
#
# --- Time: 09:42:45.236000 ---
#
# --- Time: 09:42:45.336000 ---
#
# --- Time: 09:42:45.436000 ---
#
# --- Time: 09:42:45.536000 ---
#
# --- Time: 09:42:45.636000 ---
#
# --- Time: 09:42:45.736000 ---
#
# --- Time: 09:42:45.836000 ---
#
# --- Time: 09:42:45.936000 ---
#
# --- Time: 09:42:46.036000 ---
#
# --- Time: 09:42:46.136000 ---
#
# --- Time: 09:42:46.236000 ---
#
# --- Time: 09:42:46.336000 ---
#
# --- Time: 09:42:46.436000 ---
#
# --- Time: 09:42:46.536000 ---
#
# --- Time: 09:42:46.636000 ---
#
# --- Time: 09:42:46.736000 ---
#
# --- Time: 09:42:46.836000 ---
#
# --- Time: 09:42:46.936000 ---
#
# --- Time: 09:42:47.036000 ---
#
# --- Time: 09:42:47.136000 ---
#
# --- Time: 09:42:47.236000 ---
#
# --- Time: 09:42:47.336000 ---
#
# --- Time: 09:42:47.436000 ---
#
# --- Time: 09:42:47.536000 ---
#
# --- Time: 09:42:47.636000 ---
#
# --- Time: 09:42:47.736000 ---
#
# --- Time: 09:42:47.836000 ---
#
# --- Time: 09:42:47.936000 ---
#
# --- Time: 09:42:48.036000 ---
#
# --- Time: 09:42:48.136000 ---
#
# --- Time: 09:42:48.236000 ---
#
# --- Time: 09:42:48.336000 ---
#
# --- Time: 09:42:48.436000 ---
#
# --- Time: 09:42:48.536000 ---
#
# --- Time: 09:42:48.636000 ---
#
# --- Time: 09:42:48.736000 ---
#
# --- Time: 09:42:48.836000 ---
#
# --- Time: 09:42:48.936000 ---
#
# --- Time: 09:42:49.036000 ---
#
# --- Time: 09:42:49.136000 ---
#
# --- Time: 09:42:49.236000 ---
#
# --- Time: 09:42:49.336000 ---
#
# --- Time: 09:42:49.436000 ---
#
# --- Time: 09:42:49.536000 ---
#
# --- Time: 09:42:49.636000 ---
#
# --- Time: 09:42:49.736000 ---
#
# --- Time: 09:42:49.836000 ---
#
# --- Time: 09:42:49.936000 ---
#
# --- Time: 09:42:50.036000 ---
#
# --- Time: 09:42:50.136000 ---
#
# --- Time: 09:42:50.236000 ---
#
# --- Time: 09:42:50.336000 ---
#
# --- Time: 09:42:50.436000 ---
#
# --- Time: 09:42:50.536000 ---
#
# --- Time: 09:42:50.636000 ---
#
# --- Time: 09:42:50.736000 ---
#
# --- Time: 09:42:50.836000 ---
#
# --- Time: 09:42:50.936000 ---
#
# --- Time: 09:42:51.036000 ---
#
# --- Time: 09:42:51.136000 ---
#
# --- Time: 09:42:51.236000 ---
#
# --- Time: 09:42:51.336000 ---
#
# --- Time: 09:42:51.436000 ---
#
# --- Time: 09:42:51.536000 ---
#
# --- Time: 09:42:51.636000 ---
#
# --- Time: 09:42:51.736000 ---
#
# --- Time: 09:42:51.836000 ---
#
# --- Time: 09:42:51.936000 ---
#
# --- Time: 09:42:52.036000 ---
#
# --- Time: 09:42:52.136000 ---
#
# --- Time: 09:42:52.236000 ---
#
# --- Time: 09:42:52.336000 ---
#
# --- Time: 09:42:52.436000 ---
#
# --- Time: 09:42:52.536000 ---
#
# --- Time: 09:42:52.636000 ---
#
# --- Time: 09:42:52.736000 ---
#
# --- Time: 09:42:52.836000 ---
#
# --- Time: 09:42:52.936000 ---
#
# --- Time: 09:42:53.036000 ---
#
# --- Time: 09:42:53.136000 ---
#
# --- Time: 09:42:53.236000 ---
#
# --- Time: 09:42:53.336000 ---
#
# --- Time: 09:42:53.436000 ---
#
# --- Time: 09:42:53.536000 ---
#
# --- Time: 09:42:53.636000 ---
#
# --- Time: 09:42:53.736000 ---
#
# --- Time: 09:42:53.836000 ---
#
# --- Time: 09:42:53.936000 ---
#
# --- Time: 09:42:54.036000 ---
#
# --- Simulation Summary ---
# Total parcels processed: 1552
# Parcels sorted: 1552
# Parcels recirculated: 0
# Sorting success rate: 100.00%
# Average total system time per parcel: 21.54 seconds
#
# --- Removed Parcels ---
# Initial amount of parcels: 1644
# Removed due to NaNs: 0
# Removed due to extreme outliers (data entry errors): 0
# Removed due to no feasible outfeeds: 92
# Removed due to non-chronological arrival times (scanning error): 0
# Total parcels removed before processing: 92
